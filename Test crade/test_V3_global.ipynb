# %%
# refacto V3 :
import os
import glob
import pandas as pd
import xml.etree.ElementTree as ET
import csv

ns = {"ns": "http://schemas.assemblee-nationale.fr/referentiel"}

def extraire_donnees_v3(fichier_xml: str) -> pd.DataFrame:
    try:
        tree = ET.parse(fichier_xml)
        root = tree.getroot()
    except Exception as e:
        print(f"❌ Erreur de parsing {fichier_xml} : {e}")
        return pd.DataFrame()

    def get_text(path):
        elem = root.find(path, ns)
        return elem.text.strip() if elem is not None and elem.text else ""

    # Métadonnées
    metadata = {
        "UID": get_text(".//ns:uid"),
        "SeanceRef": get_text(".//ns:seanceRef"),
        "SessionRef": get_text(".//ns:sessionRef"),
        "DateSeance": get_text(".//ns:dateSeance"),
        "DateSeanceJour": get_text(".//ns:dateSeanceJour"),
        "NumSeanceJour": get_text(".//ns:numSeanceJour"),
        "NumSeance": get_text(".//ns:numSeance"),
        "TypeAssemblee": get_text(".//ns:typeAssemblee"),
        "Legislature": get_text(".//ns:legislature"),
        "Session": get_text(".//ns:session"),
        "NomFichierJO": get_text(".//ns:nomFichierJo"),
        "President": get_text(".//ns:presidentSeance"),
    }

    rows = []
    titre_general = ""
    sous_titre = ""

    contenu = root.find("ns:contenu", ns)
    if contenu is None:
        return pd.DataFrame()

    for elem in contenu.iter():
        tag = elem.tag.split("}")[-1]
        code_grammaire = elem.attrib.get("code_grammaire", "")
        code_style = elem.attrib.get("code_style", "")

        if code_grammaire == "TITRE_TEXTE_DISCUSSION" and code_style == "Titre":
            texte = elem.find("ns:texte", ns)
            titre_general = texte.text.strip() if texte is not None and texte.text else ""

        elif code_grammaire == "SOUS_TITRE_TEXTE_DISCUSSION" and code_style == "Sous-tit_info":
            texte = elem.find("ns:texte", ns)
            sous_titre = texte.text.strip() if texte is not None and texte.text else ""

        elif tag == "paragraphe":
            texte_elem = elem.find("ns:texte", ns)
            if texte_elem is None:
                continue

            texte = "".join(texte_elem.itertext()).strip()
            stime = texte_elem.attrib.get("stime", "")

            orateur_elem = elem.find(".//ns:orateur", ns)
            nom, qualite, id_orateur = "", "", ""
            if orateur_elem is not None:
                nom = orateur_elem.find("ns:nom", ns)
                qualite = orateur_elem.find("ns:qualite", ns)
                id_elem = orateur_elem.find("ns:id", ns)

                nom = nom.text.strip() if nom is not None and nom.text else ""
                qualite = qualite.text.strip() if qualite is not None and qualite.text else ""
                id_orateur = id_elem.text.strip() if id_elem is not None and id_elem.text else ""

            rows.append({
                **metadata,
                "Titre_general": titre_general,
                "Sous_titre": sous_titre,
                "ID_paragraphe": elem.attrib.get("id_syceron", ""),
                "Ordre_seance": elem.attrib.get("ordre_absolu_seance", ""),
                "Code_grammaire": code_grammaire,
                "Code_style": code_style,
                "Code_parole": elem.attrib.get("code_parole", ""),
                "Role_debat": elem.attrib.get("roledebat", ""),
                "Nom_orateur": nom,
                "Qualite_orateur": qualite,
                "ID_orateur": id_orateur,
                "stime": stime,
                "Texte": texte,
                "Fichier_source": os.path.basename(fichier_xml),
            })

    return pd.DataFrame(rows)

# %%
def traiter_dossier_v3(dossier_path: str, pattern="*.xml", output_csv="export_v3.csv"):
    fichiers = glob.glob(os.path.join(dossier_path, pattern))
    if not fichiers:
        print("❌ Aucun fichier XML trouvé.")
        return

    print(f"🔍 Traitement de {len(fichiers)} fichiers XML dans le dossier...")

    dfs = []
    for fichier in fichiers:
        print(f"➡️  {os.path.basename(fichier)}")
        df = extraire_donnees_v3(fichier)
        if not df.empty:
            dfs.append(df)

    if dfs:
        df_concat = pd.concat(dfs, ignore_index=True)
        df_concat.to_csv(output_csv, index=False, quoting=csv.QUOTE_ALL, encoding="utf-8")
        print(f"\n✅ Export CSV : {output_csv} ({df_concat.shape[0]} lignes)")
    else:
        print("⚠️ Aucun paragraphe extrait.")

# %%
traiter_dossier_v3("../data/16-xml/compteRendu/")
# Out:
# 🔍 Traitement de 605 fichiers XML dans le dossier...
# ➡️  CRSANR5L16S2023O1N173.xml
# ➡️  CRSANR5L16S2023O1N167.xml
# ➡️  CRSANR5L16S2023O1N198.xml
# ➡️  CRSANR5L16S2023E1N010.xml
# ➡️  CRSANR5L16S2024O1N117.xml
# ➡️  CRSANR5L16S2024O1N103.xml
# ➡️  CRSANR5L16S2023E1N004.xml
# ➡️  CRSANR5L16S2023O1N239.xml
# ➡️  CRSANR5L16S2023O1N205.xml
# ➡️  CRSANR5L16S2023O1N211.xml
# ➡️  CRSANR5L16S2024O1N088.xml
# ➡️  CRSANR5L16S2023O1N007.xml
# ➡️  CRSANR5L16S2023O1N013.xml
# ➡️  CRSANR5L16S2024O1N063.xml
# ➡️  CRSANR5L16S2024O1N077.xml
# ➡️  CRSANR5L16S2024O1N076.xml
# ➡️  CRSANR5L16S2024O1N062.xml
# ➡️  CRSANR5L16S2023O1N012.xml
# ➡️  CRSANR5L16S2023O1N006.xml
# ➡️  CRSANR5L16S2024O1N089.xml
# ➡️  CRSANR5L16S2023O1N210.xml
# ➡️  CRSANR5L16S2023O1N204.xml
# ➡️  CRSANR5L16S2023O1N238.xml
# ➡️  CRSANR5L16S2023E1N005.xml
# ➡️  CRSANR5L16S2024O1N102.xml
# ➡️  CRSANR5L16S2024O1N116.xml
# ➡️  CRSANR5L16S2023E1N011.xml
# ➡️  CRSANR5L16S2023O1N199.xml
# ➡️  CRSANR5L16S2023O1N166.xml
# ➡️  CRSANR5L16S2023O1N172.xml
# ➡️  CRSANR5L16S2023O1N158.xml
# ➡️  CRSANR5L16S2023O1N164.xml
# ➡️  CRSANR5L16S2023O1N170.xml
# ➡️  CRSANR5L16S2024O1N128.xml
# ➡️  CRSANR5L16S2024O1N100.xml
# ➡️  CRSANR5L16S2023E1N007.xml
# ➡️  CRSANR5L16S2023E1N013.xml
# ➡️  CRSANR5L16S2024O1N114.xml
# ➡️  CRSANR5L16S2023O1N212.xml
# ➡️  CRSANR5L16S2023O1N206.xml
# ➡️  CRSANR5L16S2023O1N038.xml
# ➡️  CRSANR5L16S2023O1N010.xml
# ➡️  CRSANR5L16S2023O1N004.xml
# ➡️  CRSANR5L16S2024O1N048.xml
# ➡️  CRSANR5L16S2024O1N074.xml
# ➡️  CRSANR5L16S2024O1N060.xml
# ➡️  CRSANR5L16S2024O1N061.xml
# ➡️  CRSANR5L16S2024O1N075.xml
# ➡️  CRSANR5L16S2024O1N049.xml
# ➡️  CRSANR5L16S2023O1N005.xml
# ➡️  CRSANR5L16S2023O1N011.xml
# ➡️  CRSANR5L16S2023O1N039.xml
# ➡️  CRSANR5L16S2023O1N207.xml
# ➡️  CRSANR5L16S2023O1N213.xml
# ➡️  CRSANR5L16S2024O1N115.xml
# ➡️  CRSANR5L16S2023E1N012.xml
# ➡️  CRSANR5L16S2023E1N006.xml
# ➡️  CRSANR5L16S2024O1N101.xml
# ➡️  CRSANR5L16S2024O1N129.xml
# ➡️  CRSANR5L16S2023O1N171.xml
# ➡️  CRSANR5L16S2023O1N165.xml
# ➡️  CRSANR5L16S2023O1N159.xml
# ➡️  CRSANR5L16S2023O1N161.xml
# ➡️  CRSANR5L16S2023O1N175.xml
# ➡️  CRSANR5L16S2023O1N149.xml
# ➡️  CRSANR5L16S2024O1N105.xml
# ➡️  CRSANR5L16S2023E1N002.xml
# ➡️  CRSANR5L16S2023E1N016.xml
# ➡️  CRSANR5L16S2024O1N111.xml
# ➡️  CRSANR5L16S2024O1N139.xml
# ➡️  CRSANR5L16S2023O1N217.xml
# ➡️  CRSANR5L16S2023O1N203.xml
# ➡️  CRSANR5L16S2023O1N015.xml
# ➡️  CRSANR5L16S2023O1N001.xml
# ➡️  CRSANR5L16S2023O1N029.xml
# ➡️  CRSANR5L16S2024O1N071.xml
# ➡️  CRSANR5L16S2024O1N065.xml
# ➡️  CRSANR5L16S2024O1N059.xml
# ➡️  CRSANR5L16S2024O1N058.xml
# ➡️  CRSANR5L16S2024O1N064.xml
# ➡️  CRSANR5L16S2024O1N070.xml
# ➡️  CRSANR5L16S2023O1N028.xml
# ➡️  CRSANR5L16S2023O1N014.xml
# ➡️  CRSANR5L16S2023O1N202.xml
# ➡️  CRSANR5L16S2023O1N216.xml
# ➡️  CRSANR5L16S2024O1N138.xml
# ➡️  CRSANR5L16S2024O1N110.xml
# ➡️  CRSANR5L16S2023E1N017.xml
# ➡️  CRSANR5L16S2023E1N003.xml
# ➡️  CRSANR5L16S2024O1N104.xml
# ➡️  CRSANR5L16S2023O1N148.xml
# ➡️  CRSANR5L16S2023O1N174.xml
# ➡️  CRSANR5L16S2023O1N160.xml
# ➡️  CRSANR5L16S2023O1N176.xml
# ➡️  CRSANR5L16S2023O1N162.xml
# ➡️  CRSANR5L16S2023E1N015.xml
# ➡️  CRSANR5L16S2024O1N112.xml
# ➡️  CRSANR5L16S2024O1N106.xml
# ➡️  CRSANR5L16S2023E1N001.xml
# ➡️  CRSANR5L16S2023O1N189.xml
# ➡️  CRSANR5L16S2023E1N029.xml
# ➡️  CRSANR5L16S2023O1N200.xml
# ➡️  CRSANR5L16S2023O1N214.xml
# ➡️  CRSANR5L16S2023O1N228.xml
# ➡️  CRSANR5L16S2023O1N002.xml
# ➡️  CRSANR5L16S2023O1N016.xml
# ➡️  CRSANR5L16S2024O1N099.xml
# ➡️  CRSANR5L16S2024O1N066.xml
# ➡️  CRSANR5L16S2024O1N072.xml
# ➡️  CRSANR5L16S2024O1N073.xml
# ➡️  CRSANR5L16S2024O1N067.xml
# ➡️  CRSANR5L16S2024O1N098.xml
# ➡️  CRSANR5L16S2023O1N017.xml
# ➡️  CRSANR5L16S2023O1N003.xml
# ➡️  CRSANR5L16S2023O1N229.xml
# ➡️  CRSANR5L16S2023O1N215.xml
# ➡️  CRSANR5L16S2023O1N201.xml
# ➡️  CRSANR5L16S2023E1N028.xml
# ➡️  CRSANR5L16S2023O1N188.xml
# ➡️  CRSANR5L16S2024O1N107.xml
# ➡️  CRSANR5L16S2024O1N113.xml
# ➡️  CRSANR5L16S2023E1N014.xml
# ➡️  CRSANR5L16S2023O1N163.xml
# ➡️  CRSANR5L16S2023O1N177.xml
# ➡️  CRSANR5L16S2023O1N138.xml
# ➡️  CRSANR5L16S2023O1N110.xml
# ➡️  CRSANR5L16S2023O1N104.xml
# ➡️  CRSANR5L16S2024O1N148.xml
# ➡️  CRSANR5L16S2024O1N174.xml
# ➡️  CRSANR5L16S2024O1N160.xml
# ➡️  CRSANR5L16S2023O1N266.xml
# ➡️  CRSANR5L16S2023O1N272.xml
# ➡️  CRSANR5L16S2022E1N010.xml
# ➡️  CRSANR5L16S2022E1N004.xml
# ➡️  CRSANR5L16S2024O1N202.xml
# ➡️  CRSANR5L16S2024O1N216.xml
# ➡️  CRSANR5L16S2023O1N058.xml
# ➡️  CRSANR5L16S2023O1N064.xml
# ➡️  CRSANR5L16S2023E2N007.xml
# ➡️  CRSANR5L16S2023O1N070.xml
# ➡️  CRSANR5L16S2024O1N028.xml
# ➡️  CRSANR5L16S2024O1N014.xml
# ➡️  CRSANR5L16S2024O1N015.xml
# ➡️  CRSANR5L16S2024O1N001.xml
# ➡️  CRSANR5L16S2024O1N029.xml
# ➡️  CRSANR5L16S2023E2N012.xml
# ➡️  CRSANR5L16S2023O1N071.xml
# ➡️  CRSANR5L16S2023E2N006.xml
# ➡️  CRSANR5L16S2023O1N065.xml
# ➡️  CRSANR5L16S2023O1N059.xml
# ➡️  CRSANR5L16S2024O1N217.xml
# ➡️  CRSANR5L16S2024O1N203.xml
# ➡️  CRSANR5L16S2022E1N005.xml
# ➡️  CRSANR5L16S2022E1N011.xml
# ➡️  CRSANR5L16S2023O1N273.xml
# ➡️  CRSANR5L16S2023O1N267.xml
# ➡️  CRSANR5L16S2024O1N161.xml
# ➡️  CRSANR5L16S2024O1N175.xml
# ➡️  CRSANR5L16S2024O1N149.xml
# ➡️  CRSANR5L16S2023O1N105.xml
# ➡️  CRSANR5L16S2023O1N111.xml
# ➡️  CRSANR5L16S2023O1N139.xml
# ➡️  CRSANR5L16S2024O1N188.xml
# ➡️  CRSANR5L16S2023O1N107.xml
# ➡️  CRSANR5L16S2023O1N113.xml
# ➡️  CRSANR5L16S2024O1N163.xml
# ➡️  CRSANR5L16S2024O1N177.xml
# ➡️  CRSANR5L16S2023O1N259.xml
# ➡️  CRSANR5L16S2022O1N170.xml
# ➡️  CRSANR5L16S2023O1N271.xml
# ➡️  CRSANR5L16S2023O1N265.xml
# ➡️  CRSANR5L16S2022E1N007.xml
# ➡️  CRSANR5L16S2024O1N229.xml
# ➡️  CRSANR5L16S2022E1N013.xml
# ➡️  CRSANR5L16S2024O1N215.xml
# ➡️  CRSANR5L16S2024O1N201.xml
# ➡️  CRSANR5L16S2021O1N144.xml
# ➡️  CRSANR5L16S2023O1N073.xml
# ➡️  CRSANR5L16S2023E2N010.xml
# ➡️  CRSANR5L16S2023O1N067.xml
# ➡️  CRSANR5L16S2023E2N004.xml
# ➡️  CRSANR5L16S2023O1N098.xml
# ➡️  CRSANR5L16S2024O1N017.xml
# ➡️  CRSANR5L16S2024O1N003.xml
# ➡️  CRSANR5L16S2024O1N002.xml
# ➡️  CRSANR5L16S2024O1N016.xml
# ➡️  CRSANR5L16S2023O1N099.xml
# ➡️  CRSANR5L16S2023E2N005.xml
# ➡️  CRSANR5L16S2023O1N066.xml
# ➡️  CRSANR5L16S2023E2N011.xml
# ➡️  CRSANR5L16S2023O1N072.xml
# ➡️  CRSANR5L16S2024O1N200.xml
# ➡️  CRSANR5L16S2024O1N214.xml
# ➡️  CRSANR5L16S2022E1N012.xml
# ➡️  CRSANR5L16S2024O1N228.xml
# ➡️  CRSANR5L16S2022E1N006.xml
# ➡️  CRSANR5L16S2023O1N264.xml
# ➡️  CRSANR5L16S2023O1N270.xml
# ➡️  CRSANR5L16S2023O1N258.xml
# ➡️  CRSANR5L16S2024O1N176.xml
# ➡️  CRSANR5L16S2024O1N162.xml
# ➡️  CRSANR5L16S2023O1N112.xml
# ➡️  CRSANR5L16S2023O1N106.xml
# ➡️  CRSANR5L16S2024O1N189.xml
# ➡️  CRSANR5L16S2023O1N102.xml
# ➡️  CRSANR5L16S2023O1N116.xml
# ➡️  CRSANR5L16S2024O1N199.xml
# ➡️  CRSANR5L16S2024O1N166.xml
# ➡️  CRSANR5L16S2024O1N172.xml
# ➡️  CRSANR5L16S2023O1N274.xml
# ➡️  CRSANR5L16S2023O1N260.xml
# ➡️  CRSANR5L16S2023O1N248.xml
# ➡️  CRSANR5L16S2024O1N210.xml
# ➡️  CRSANR5L16S2024O1N204.xml
# ➡️  CRSANR5L16S2022E1N002.xml
# ➡️  CRSANR5L16S2022E1N016.xml
# ➡️  CRSANR5L16S2023O1N076.xml
# ➡️  CRSANR5L16S2023O1N062.xml
# ➡️  CRSANR5L16S2023E2N001.xml
# ➡️  CRSANR5L16S2024O1N012.xml
# ➡️  CRSANR5L16S2024O1N006.xml
# ➡️  CRSANR5L16S2023O1N089.xml
# ➡️  CRSANR5L16S2023O1N088.xml
# ➡️  CRSANR5L16S2024O1N007.xml
# ➡️  CRSANR5L16S2024O1N013.xml
# ➡️  CRSANR5L16S2023O1N063.xml
# ➡️  CRSANR5L16S2023O1N077.xml
# ➡️  CRSANR5L16S2022E1N017.xml
# ➡️  CRSANR5L16S2022E1N003.xml
# ➡️  CRSANR5L16S2024O1N205.xml
# ➡️  CRSANR5L16S2024O1N211.xml
# ➡️  CRSANR5L16S2023O1N249.xml
# ➡️  CRSANR5L16S2023O1N261.xml
# ➡️  CRSANR5L16S2023O1N275.xml
# ➡️  CRSANR5L16S2024O1N173.xml
# ➡️  CRSANR5L16S2024O1N167.xml
# ➡️  CRSANR5L16S2024O1N198.xml
# ➡️  CRSANR5L16S2023O1N117.xml
# ➡️  CRSANR5L16S2023O1N103.xml
# ➡️  CRSANR5L16S2023O1N115.xml
# ➡️  CRSANR5L16S2023O1N101.xml
# ➡️  CRSANR5L16S2023O1N129.xml
# ➡️  CRSANR5L16S2024O1N171.xml
# ➡️  CRSANR5L16S2024O1N165.xml
# ➡️  CRSANR5L16S2024O1N159.xml
# ➡️  CRSANR5L16S2023O1N263.xml
# ➡️  CRSANR5L16S2023O1N277.xml
# ➡️  CRSANR5L16S2022E1N029.xml
# ➡️  CRSANR5L16S2024O1N207.xml
# ➡️  CRSANR5L16S2024O1N213.xml
# ➡️  CRSANR5L16S2022E1N015.xml
# ➡️  CRSANR5L16S2023O1N288.xml
# ➡️  CRSANR5L16S2022E1N001.xml
# ➡️  CRSANR5L16S2023O1N061.xml
# ➡️  CRSANR5L16S2023E2N002.xml
# ➡️  CRSANR5L16S2023O1N075.xml
# ➡️  CRSANR5L16S2023O1N049.xml
# ➡️  CRSANR5L16S2024O1N005.xml
# ➡️  CRSANR5L16S2024O1N011.xml
# ➡️  CRSANR5L16S2024O1N039.xml
# ➡️  CRSANR5L16S2024O1N038.xml
# ➡️  CRSANR5L16S2024O1N010.xml
# ➡️  CRSANR5L16S2024O1N004.xml
# ➡️  CRSANR5L16S2023O1N048.xml
# ➡️  CRSANR5L16S2023O1N074.xml
# ➡️  CRSANR5L16S2023E2N003.xml
# ➡️  CRSANR5L16S2023O1N060.xml
# ➡️  CRSANR5L16S2023O1N289.xml
# ➡️  CRSANR5L16S2022E1N014.xml
# ➡️  CRSANR5L16S2024O1N212.xml
# ➡️  CRSANR5L16S2024O1N206.xml
# ➡️  CRSANR5L16S2022E1N028.xml
# ➡️  CRSANR5L16S2023O1N276.xml
# ➡️  CRSANR5L16S2023O1N262.xml
# ➡️  CRSANR5L16S2024O1N158.xml
# ➡️  CRSANR5L16S2024O1N164.xml
# ➡️  CRSANR5L16S2024O1N170.xml
# ➡️  CRSANR5L16S2023O1N128.xml
# ➡️  CRSANR5L16S2023O1N100.xml
# ➡️  CRSANR5L16S2023O1N114.xml
# ➡️  CRSANR5L16S2023O1N119.xml
# ➡️  CRSANR5L16S2024O1N196.xml
# ➡️  CRSANR5L16S2023O1N131.xml
# ➡️  CRSANR5L16S2023O1N125.xml
# ➡️  CRSANR5L16S2024O1N182.xml
# ➡️  CRSANR5L16S2024O1N169.xml
# ➡️  CRSANR5L16S2024O1N155.xml
# ➡️  CRSANR5L16S2024O1N141.xml
# ➡️  CRSANR5L16S2023O1N247.xml
# ➡️  CRSANR5L16S2023O1N253.xml
# ➡️  CRSANR5L16S2022E1N031.xml
# ➡️  CRSANR5L16S2022E1N025.xml
# ➡️  CRSANR5L16S2024O1N223.xml
# ➡️  CRSANR5L16S2023O1N284.xml
# ➡️  CRSANR5L16S2023O1N290.xml
# ➡️  CRSANR5L16S2022E1N019.xml
# ➡️  CRSANR5L16S2023O1N079.xml
# ➡️  CRSANR5L16S2023O1N045.xml
# ➡️  CRSANR5L16S2023O1N051.xml
# ➡️  CRSANR5L16S2024O1N009.xml
# ➡️  CRSANR5L16S2023O1N086.xml
# ➡️  CRSANR5L16S2024O1N021.xml
# ➡️  CRSANR5L16S2024O1N035.xml
# ➡️  CRSANR5L16S2023O1N092.xml
# ➡️  CRSANR5L16S2023O1N093.xml
# ➡️  CRSANR5L16S2024O1N034.xml
# ➡️  CRSANR5L16S2024O1N020.xml
# ➡️  CRSANR5L16S2023O1N087.xml
# ➡️  CRSANR5L16S2024O1N008.xml
# ➡️  CRSANR5L16S2023O1N050.xml
# ➡️  CRSANR5L16S2023O1N044.xml
# ➡️  CRSANR5L16S2023O1N078.xml
# ➡️  CRSANR5L16S2022E1N018.xml
# ➡️  CRSANR5L16S2023O1N291.xml
# ➡️  CRSANR5L16S2023O1N285.xml
# ➡️  CRSANR5L16S2024O1N222.xml
# ➡️  CRSANR5L16S2022E1N024.xml
# ➡️  CRSANR5L16S2022E1N030.xml
# ➡️  CRSANR5L16S2023O1N252.xml
# ➡️  CRSANR5L16S2023O1N246.xml
# ➡️  CRSANR5L16S2024O1N140.xml
# ➡️  CRSANR5L16S2024O1N154.xml
# ➡️  CRSANR5L16S2024O1N168.xml
# ➡️  CRSANR5L16S2024O1N183.xml
# ➡️  CRSANR5L16S2023O1N124.xml
# ➡️  CRSANR5L16S2023O1N130.xml
# ➡️  CRSANR5L16S2024O1N197.xml
# ➡️  CRSANR5L16S2023O1N118.xml
# ➡️  CRSANR5L16S2023O1N126.xml
# ➡️  CRSANR5L16S2024O1N181.xml
# ➡️  CRSANR5L16S2024O1N195.xml
# ➡️  CRSANR5L16S2023O1N132.xml
# ➡️  CRSANR5L16S2024O1N142.xml
# ➡️  CRSANR5L16S2024O1N156.xml
# ➡️  CRSANR5L16S2023O1N278.xml
# ➡️  CRSANR5L16S2023O1N250.xml
# ➡️  CRSANR5L16S2023O1N244.xml
# ➡️  CRSANR5L16S2024O1N208.xml
# ➡️  CRSANR5L16S2022E1N026.xml
# ➡️  CRSANR5L16S2022E1N032.xml
# ➡️  CRSANR5L16S2023O1N293.xml
# ➡️  CRSANR5L16S2024O1N234.xml
# ➡️  CRSANR5L16S2024O1N220.xml
# ➡️  CRSANR5L16S2023O1N287.xml
# ➡️  CRSANR5L16S2023O1N052.xml
# ➡️  CRSANR5L16S2023O1N046.xml
# ➡️  CRSANR5L16S2024O1N036.xml
# ➡️  CRSANR5L16S2023O1N091.xml
# ➡️  CRSANR5L16S2023O1N085.xml
# ➡️  CRSANR5L16S2024O1N022.xml
# ➡️  CRSANR5L16S2024O1N023.xml
# ➡️  CRSANR5L16S2023O1N084.xml
# ➡️  CRSANR5L16S2023O1N090.xml
# ➡️  CRSANR5L16S2024O1N037.xml
# ➡️  CRSANR5L16S2023O1N047.xml
# ➡️  CRSANR5L16S2023O1N053.xml
# ➡️  CRSANR5L16S2023O1N286.xml
# ➡️  CRSANR5L16S2024O1N221.xml
# ➡️  CRSANR5L16S2024O1N235.xml
# ➡️  CRSANR5L16S2023O1N292.xml
# ➡️  CRSANR5L16S2022E1N027.xml
# ➡️  CRSANR5L16S2024O1N209.xml
# ➡️  CRSANR5L16S2023O1N245.xml
# ➡️  CRSANR5L16S2023O1N251.xml
# ➡️  CRSANR5L16S2023O1N279.xml
# ➡️  CRSANR5L16S2024O1N157.xml
# ➡️  CRSANR5L16S2024O1N143.xml
# ➡️  CRSANR5L16S2023O1N133.xml
# ➡️  CRSANR5L16S2024O1N194.xml
# ➡️  CRSANR5L16S2024O1N180.xml
# ➡️  CRSANR5L16S2023O1N127.xml
# ➡️  CRSANR5L16S2023O1N123.xml
# ➡️  CRSANR5L16S2024O1N184.xml
# ➡️  CRSANR5L16S2024O1N190.xml
# ➡️  CRSANR5L16S2023O1N137.xml
# ➡️  CRSANR5L16S2024O1N147.xml
# ➡️  CRSANR5L16S2024O1N153.xml
# ➡️  CRSANR5L16S2023O1N255.xml
# ➡️  CRSANR5L16S2023O1N241.xml
# ➡️  CRSANR5L16S2023O1N269.xml
# ➡️  CRSANR5L16S2024O1N231.xml
# ➡️  CRSANR5L16S2024O1N225.xml
# ➡️  CRSANR5L16S2023O1N282.xml
# ➡️  CRSANR5L16S2022E1N023.xml
# ➡️  CRSANR5L16S2024O1N219.xml
# ➡️  CRSANR5L16S2023O1N057.xml
# ➡️  CRSANR5L16S2023O1N043.xml
# ➡️  CRSANR5L16S2023E2N008.xml
# ➡️  CRSANR5L16S2024O1N033.xml
# ➡️  CRSANR5L16S2023O1N094.xml
# ➡️  CRSANR5L16S2023O1N080.xml
# ➡️  CRSANR5L16S2024O1N027.xml
# ➡️  CRSANR5L16S2024O1N026.xml
# ➡️  CRSANR5L16S2023O1N081.xml
# ➡️  CRSANR5L16S2023O1N095.xml
# ➡️  CRSANR5L16S2024O1N032.xml
# ➡️  CRSANR5L16S2023E2N009.xml
# ➡️  CRSANR5L16S2023O1N042.xml
# ➡️  CRSANR5L16S2023O1N056.xml
# ➡️  CRSANR5L16S2024O1N218.xml
# ➡️  CRSANR5L16S2022E1N022.xml
# ➡️  CRSANR5L16S2023O1N283.xml
# ➡️  CRSANR5L16S2024O1N224.xml
# ➡️  CRSANR5L16S2024O1N230.xml
# ➡️  CRSANR5L16S2023O1N268.xml
# ➡️  CRSANR5L16S2023O1N240.xml
# ➡️  CRSANR5L16S2022O1N169.xml
# ➡️  CRSANR5L16S2023O1N254.xml
# ➡️  CRSANR5L16S2024O1N152.xml
# ➡️  CRSANR5L16S2024O1N146.xml
# ➡️  CRSANR5L16S2023O1N136.xml
# ➡️  CRSANR5L16S2024O1N191.xml
# ➡️  CRSANR5L16S2024O1N185.xml
# ➡️  CRSANR5L16S2023O1N122.xml
# ➡️  CRSANR5L16S2024O1N193.xml
# ➡️  CRSANR5L16S2023O1N134.xml
# ➡️  CRSANR5L16S2023O1N120.xml
# ➡️  CRSANR5L16S2024O1N187.xml
# ➡️  CRSANR5L16S2023O1N108.xml
# ➡️  CRSANR5L16S2024O1N150.xml
# ➡️  CRSANR5L16S2024O1N144.xml
# ➡️  CRSANR5L16S2024O1N178.xml
# ➡️  CRSANR5L16S2023O1N242.xml
# ➡️  CRSANR5L16S2023O1N256.xml
# ➡️  CRSANR5L16S2024O1N226.xml
# ➡️  CRSANR5L16S2023O1N281.xml
# ➡️  CRSANR5L16S2022E1N008.xml
# ➡️  CRSANR5L16S2024O1N232.xml
# ➡️  CRSANR5L16S2022E1N020.xml
# ➡️  CRSANR5L16S2023O1N040.xml
# ➡️  CRSCGR5L16S2024O1N001.xml
# ➡️  CRSANR5L16S2023O1N054.xml
# ➡️  CRSANR5L16S2023O1N068.xml
# ➡️  CRSANR5L16S2023O1N083.xml
# ➡️  CRSANR5L16S2024O1N024.xml
# ➡️  CRSANR5L16S2024O1N030.xml
# ➡️  CRSANR5L16S2023O1N097.xml
# ➡️  CRSANR5L16S2024O1N018.xml
# ➡️  CRSANR5L16S2024O1N019.xml
# ➡️  CRSANR5L16S2023O1N096.xml
# ➡️  CRSANR5L16S2024O1N031.xml
# ➡️  CRSANR5L16S2024O1N025.xml
# ➡️  CRSANR5L16S2023O1N082.xml
# ➡️  CRSANR5L16S2023O1N069.xml
# ➡️  CRSANR5L16S2023O1N055.xml
# ➡️  CRSANR5L16S2023O1N041.xml
# ➡️  CRSANR5L16S2022E1N021.xml
# ➡️  CRSANR5L16S2024O1N233.xml
# ➡️  CRSANR5L16S2022E1N009.xml
# ➡️  CRSANR5L16S2023O1N280.xml
# ➡️  CRSANR5L16S2024O1N227.xml
# ➡️  CRSANR5L16S2023O1N257.xml
# ➡️  CRSANR5L16S2023O1N243.xml
# ➡️  CRSANR5L16S2024O1N179.xml
# ➡️  CRSANR5L16S2024O1N145.xml
# ➡️  CRSANR5L16S2024O1N151.xml
# ➡️  CRSANR5L16S2023O1N109.xml
# ➡️  CRSANR5L16S2024O1N186.xml
# ➡️  CRSANR5L16S2023O1N121.xml
# ➡️  CRSANR5L16S2023O1N135.xml
# ➡️  CRSANR5L16S2024O1N192.xml
# ➡️  CRSANR5L16S2023O1N152.xml
# ➡️  CRSANR5L16S2023O1N146.xml
# ➡️  CRSANR5L16S2023E1N019.xml
# ➡️  CRSANR5L16S2024O1N136.xml
# ➡️  CRSANR5L16S2023O1N191.xml
# ➡️  CRSANR5L16S2023O1N185.xml
# ➡️  CRSANR5L16S2023E1N025.xml
# ➡️  CRSANR5L16S2024O1N122.xml
# ➡️  CRSANR5L16S2023O1N218.xml
# ➡️  CRSANR5L16S2023O1N224.xml
# ➡️  CRSANR5L16S2023O1N230.xml
# ➡️  CRSANR5L16S2023O1N026.xml
# ➡️  CRSANR5L16S2024O1N081.xml
# ➡️  CRSANR5L16S2024O1N095.xml
# ➡️  CRSANR5L16S2023O1N032.xml
# ➡️  CRSANR5L16S2024O1N042.xml
# ➡️  CRSANR5L16S2024O1N056.xml
# ➡️  CRSANR5L16S2024O1N057.xml
# ➡️  CRSANR5L16S2024O1N043.xml
# ➡️  CRSANR5L16S2023O1N033.xml
# ➡️  CRSANR5L16S2024O1N094.xml
# ➡️  CRSANR5L16S2024O1N080.xml
# ➡️  CRSANR5L16S2023O1N027.xml
# ➡️  CRSANR5L16S2023O1N231.xml
# ➡️  CRSANR5L16S2023O1N225.xml
# ➡️  CRSANR5L16S2023O1N219.xml
# ➡️  CRSANR5L16S2024O1N123.xml
# ➡️  CRSANR5L16S2023E1N024.xml
# ➡️  CRSANR5L16S2023O1N184.xml
# ➡️  CRSANR5L16S2023O1N190.xml
# ➡️  CRSANR5L16S2024O1N137.xml
# ➡️  CRSANR5L16S2023E1N018.xml
# ➡️  CRSANR5L16S2023O1N147.xml
# ➡️  CRSANR5L16S2023O1N153.xml
# ➡️  CRSANR5L16S2023O1N179.xml
# ➡️  CRSANR5L16S2023O1N145.xml
# ➡️  CRSANR5L16S2023O1N151.xml
# ➡️  CRSANR5L16S2024O1N109.xml
# ➡️  CRSANR5L16S2023O1N186.xml
# ➡️  CRSANR5L16S2023E1N026.xml
# ➡️  CRSANR5L16S2024O1N121.xml
# ➡️  CRSANR5L16S2024O1N135.xml
# ➡️  CRSANR5L16S2023O1N192.xml
# ➡️  CRSANR5L16S2023O1N233.xml
# ➡️  CRSANR5L16S2023O1N227.xml
# ➡️  CRSANR5L16S2023O1N019.xml
# ➡️  CRSANR5L16S2024O1N096.xml
# ➡️  CRSANR5L16S2023O1N031.xml
# ➡️  CRSANR5L16S2023O1N025.xml
# ➡️  CRSANR5L16S2024O1N082.xml
# ➡️  CRSANR5L16S2024O1N069.xml
# ➡️  CRSANR5L16S2024O1N055.xml
# ➡️  CRSANR5L16S2024O1N041.xml
# ➡️  CRSANR5L16S2024O1N040.xml
# ➡️  CRSANR5L16S2024O1N054.xml
# ➡️  CRSANR5L16S2024O1N068.xml
# ➡️  CRSANR5L16S2024O1N083.xml
# ➡️  CRSANR5L16S2023O1N024.xml
# ➡️  CRSANR5L16S2023O1N030.xml
# ➡️  CRSANR5L16S2024O1N097.xml
# ➡️  CRSANR5L16S2023O1N018.xml
# ➡️  CRSANR5L16S2023O1N226.xml
# ➡️  CRSANR5L16S2023O1N232.xml
# ➡️  CRSANR5L16S2023O1N193.xml
# ➡️  CRSANR5L16S2024O1N134.xml
# ➡️  CRSANR5L16S2024O1N120.xml
# ➡️  CRSANR5L16S2023E1N027.xml
# ➡️  CRSANR5L16S2023O1N187.xml
# ➡️  CRSANR5L16S2024O1N108.xml
# ➡️  CRSANR5L16S2023O1N150.xml
# ➡️  CRSANR5L16S2023O1N144.xml
# ➡️  CRSANR5L16S2023O1N178.xml
# ➡️  CRSANR5L16S2023O1N140.xml
# ➡️  CRSANR5L16S2023O1N154.xml
# ➡️  CRSANR5L16S2023O1N168.xml
# ➡️  CRSANR5L16S2023O1N183.xml
# ➡️  CRSANR5L16S2023E1N023.xml
# ➡️  CRSANR5L16S2024O1N124.xml
# ➡️  CRSANR5L16S2024O1N130.xml
# ➡️  CRSANR5L16S2023O1N197.xml
# ➡️  CRSANR5L16S2024O1N118.xml
# ➡️  CRSANR5L16S2023O1N236.xml
# ➡️  CRSANR5L16S2023O1N222.xml
# ➡️  CRSANR5L16S2024O1N093.xml
# ➡️  CRSANR5L16S2023O1N034.xml
# ➡️  CRSANR5L16S2023O1N020.xml
# ➡️  CRSANR5L16S2024O1N087.xml
# ➡️  CRSANR5L16S2023O1N008.xml
# ➡️  CRSANR5L16S2024O1N050.xml
# ➡️  CRSANR5L16S2024O1N044.xml
# ➡️  CRSANR5L16S2024O1N078.xml
# ➡️  CRSANR5L16S2024O1N079.xml
# ➡️  CRSANR5L16S2024O1N045.xml
# ➡️  CRSANR5L16S2024O1N051.xml
# ➡️  CRSANR5L16S2023O1N009.xml
# ➡️  CRSANR5L16S2024O1N086.xml
# ➡️  CRSANR5L16S2023O1N021.xml
# ➡️  CRSANR5L16S2023O1N035.xml
# ➡️  CRSANR5L16S2024O1N092.xml
# ➡️  CRSANR5L16S2023O1N223.xml
# ➡️  CRSANR5L16S2023O1N237.xml
# ➡️  CRSANR5L16S2024O1N119.xml
# ➡️  CRSANR5L16S2023O1N196.xml
# ➡️  CRSANR5L16S2024O1N131.xml
# ➡️  CRSANR5L16S2024O1N125.xml
# ➡️  CRSANR5L16S2023E1N022.xml
# ➡️  CRSANR5L16S2023O1N182.xml
# ➡️  CRSANR5L16S2023O1N169.xml
# ➡️  CRSANR5L16S2023O1N155.xml
# ➡️  CRSANR5L16S2023O1N141.xml
# ➡️  CRSANR5L16S2023O1N157.xml
# ➡️  CRSANR5L16S2023O1N143.xml
# ➡️  CRSANR5L16S2024O1N133.xml
# ➡️  CRSANR5L16S2023O1N194.xml
# ➡️  CRSANR5L16S2023O1N180.xml
# ➡️  CRSANR5L16S2023E1N020.xml
# ➡️  CRSANR5L16S2024O1N127.xml
# ➡️  CRSANR5L16S2023E1N008.xml
# ➡️  CRSANR5L16S2023O1N221.xml
# ➡️  CRSANR5L16S2023O1N235.xml
# ➡️  CRSANR5L16S2023O1N209.xml
# ➡️  CRSANR5L16S2023O1N023.xml
# ➡️  CRSANR5L16S2024O1N084.xml
# ➡️  CRSANR5L16S2024O1N090.xml
# ➡️  CRSANR5L16S2023O1N037.xml
# ➡️  CRSANR5L16S2024O1N047.xml
# ➡️  CRSANR5L16S2024O1N053.xml
# ➡️  CRSANR5L16S2024O1N052.xml
# ➡️  CRSANR5L16S2024O1N046.xml
# ➡️  CRSANR5L16S2023O1N036.xml
# ➡️  CRSANR5L16S2024O1N091.xml
# ➡️  CRSANR5L16S2024O1N085.xml
# ➡️  CRSANR5L16S2023O1N022.xml
# ➡️  CRSANR5L16S2023O1N208.xml
# ➡️  CRSANR5L16S2023O1N234.xml
# ➡️  CRSANR5L16S2023O1N220.xml
# ➡️  CRSANR5L16S2023E1N009.xml
# ➡️  CRSANR5L16S2024O1N126.xml
# ➡️  CRSANR5L16S2023E1N021.xml
# ➡️  CRSANR5L16S2023O1N181.xml
# ➡️  CRSANR5L16S2023O1N195.xml
# ➡️  CRSANR5L16S2024O1N132.xml
# ➡️  CRSANR5L16S2023O1N142.xml
# ➡️  CRSANR5L16S2023O1N156.xml
#
# ✅ Export CSV : export_v3.csv (337038 lignes)
