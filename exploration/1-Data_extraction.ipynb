# %% [markdown]
# # 2. Extraction des données (from XML to CSV by LXML)

# %% [markdown]
# Ce notebook extrait les paragraphes des CRS de l’Assemblée nationale à partir des fichiers XML, en utilisant la bibliothèque lxml (qui a ici donné des résultats plus simples que la précédente version). Sans doute moins robuste, moins de gestion des erreurs et exceptions, mais plus simple, lisible, et sans doute OK sur les données assemblée qui sont stables / propres.
#
# Sur le choix de cette base de données plus qu'une autre voir le notebook 1. Data collection
#
# ### Pré-Étape :
# Supprimer manuellement le premier fichier xml du dossier de la 16e législature qui correspond en réalité à la 15e législature !
# ID : "CRSANR5L16S2021O1N144"
#
# ## Modalités de fonctionnement :
#
# ### Option 1 :
#
# 1. Fusion des xml par législature
# 2. Fusionner les 2 CSV (avant ou après le match avec données sur les députés)
#
# ### Option 2 :
#
# 1. Fusion de tous les xml dans un seul fichier CSV
#
# 1 député = 1 ID qui ne change pas à travers le temps. ==> ce qui signifie que dans l’idéal il faudrait avoir les données complètes (avec affiliation partisane, etc) par législature et faire la fusion député/compte-rendus avant la fusion entre les 2 législatures.

# %% [markdown]
# ## Étape 1 : Fusionner les xml par législature dans un CSV
#
# **Faire attention à ne pas perdre de données en routes, et garder en tête l'architecture de construction des xml (cf 1. Data collection)**

# %%
import os #bibliothèque pour traiter les données sur l'ordi
import glob
from lxml import etree #bibliothèque pour traiter les données XML 
import pandas as pd #bibliothèque pour traiter les données tabulaires


def extraire_paragraphes_lxml(fichier_xml: str) -> pd.DataFrame: # Étape 1 consiste à extraire les paragraphes d'un fichier XML de compte rendu en utilisant lxml
    try:
        tree = etree.parse(fichier_xml) #analyser la structure du xml
        root = tree.getroot() # root est la racine de l’arbre XML, c’est-à-dire l’élément XML principal.
        ns = {'ns': 'http://schemas.assemblee-nationale.fr/referentiel'} # ns est un dictionnaire des espaces de noms XML. Le préfixe 'ns' est utilisé pour faire des recherches XPath dans le bon namespace (et ici celui de l'AN donné)

        meta = {
            'UID': root.findtext('ns:uid', namespaces=ns),
            'SeanceRef': root.findtext('ns:seanceRef', namespaces=ns), # donnée manquante pour les xml de la 15e législature
            'SessionRef': root.findtext('ns:sessionRef', namespaces=ns), # pareil
        } # ici il s'agit d'extraire les métadonnées essentielles (la première étant la seule généralisée)
        meta_tags = ['dateSeance', 'dateSeanceJour', 'numSeanceJour', 'numSeance', 'typeAssemblee', 
                     'legislature', 'session', 'nomFichierJo'] #ici on liste les balises complémentaires
        for tag in meta_tags:
            meta[tag] = root.findtext(f'.//ns:{tag}', namespaces=ns) #cela signifie que pour chaque balise, on extrait le texte grâce à la fonction .findtext

        meta['President'] = root.findtext('.//ns:presidentSeance', namespaces=ns)

        rows = []

        for para in root.xpath('.//ns:paragraphe', namespaces=ns): #On récupère tous les éléments <paragraphe> dans le document XML via XPath
            # Naviguer vers le <point> parent (représente généralement l'unité logique du débat)
            point = para.getparent()
            while point is not None and point.tag != f"{{{ns['ns']}}}point":
                point = point.getparent()
            # Extraction des attributs du paragraphe (<point>)
            point_id = point.get('id_syceron') if point is not None else None # simple arbre à conditions pour mettre données manquantes le cas échéant
            point_type = point.get('code_grammaire') if point is not None else None
            point_title = point.findtext('ns:texte', namespaces=ns) if point is not None else None
            valeur_odj = point.get('valeur_ptsodj') if point is not None else None
            # Extraction du texte de l'intervention
            texte_elem = para.find('ns:texte', namespaces=ns)
            texte = ''.join(texte_elem.itertext()).strip() if texte_elem is not None else None
            stime = texte_elem.get('stime') if texte_elem is not None else None  #absent pour la 15e législature
            # Extraction des informations sur l'orateur du paragraphe 
            orateur = para.find('.//ns:orateur', namespaces=ns)
            nom = orateur.findtext('ns:nom', namespaces=ns) if orateur is not None else None
            qualite = orateur.findtext('ns:qualite', namespaces=ns) if orateur is not None else None
            id_orateur = orateur.findtext('ns:id', namespaces=ns) if orateur is not None else None

            rows.append({
                'UID': meta['UID'], # le nom de chaque fichier/CRS
                'SeanceRef': meta['SeanceRef'],
                'SessionRef': meta['SessionRef'],
                'dateSeance': meta['dateSeance'],
                'dateSeanceJour': meta['dateSeanceJour'], # en supprimer un des 2 ?
                # 'numSeanceJour': meta['numSeanceJour'], pour cette étude pas nécessaire, élément intéressant dans des cas spécifiques à aller voir au cas par cas mais ici rajoute colonne inutilement
                # 'numSeance': meta['numSeance'], pareil
                'typeAssemblee': meta['typeAssemblee'],
                'legislature': meta['legislature'],
                'session': meta['session'],
                'nomFichierJO': meta['nomFichierJo'],
                'President': meta['President'],
                'titre_general': point_title,
                # 'Sous_titre': '',  # not in this version, get back to original if needed
                # 'Contexte_hierarchique': '',  # not in this version, get back to original if needed
                # 'Section_courante': '',  # not in this version, get back to original if needed
                # 'Sujet_point': '', # not in this version, get back to original if needed
                'valeur_ODJ': valeur_odj, # potentiellement intéressant pour vérifier si une forte occurence provient d'un même point ou de deux points différents à l'ODJ lors de la même séance
                'point_ID': point_id,
                'point_type': point_type,
                'ID_paragraphe': para.get('id_syceron'), # élement clé pour l'analyse de discours ensuite 
                'ordre_seance': para.get('ordre_absolu_seance'),
                'code_grammaire': para.get('code_grammaire'),
                'code_style': para.get('code_style'),
                'code_parole': para.get('code_parole'),
                'role_debat': para.get('roledebat'), # en réalité trop lacunaire donc pourrait être supprimé
                'nom_orateur': nom,
                'qualite_orateur': qualite, # utilisé essentiellement pour les ministres ou les rapporteur.ices
                'ID_orateur': id_orateur, # élément clé pour commencer à sociologiser l'analyse de discours ensuite 
                'stime': stime, # absent des XML de la 15e législature (correspond au temps de parole)
                'texte': texte # coeur de l'analyse de discours 
            })

        return pd.DataFrame(rows) # renvoie tout ça sous la forme d'un tableau avec les données en lignes. 

    except Exception as e:
        print(f"Erreur dans {fichier_xml} : {e}")
        return pd.DataFrame()


def dossier_CR_lxml(dossier_path: str, pattern: str = "*.xml") -> pd.DataFrame: #Traite tous les fichiers XML d'un dossier avec la fonction extraire_paragraphes_lxml().
    fichiers = glob.glob(os.path.join(dossier_path, pattern))
    if not fichiers:
        print(f"Aucun fichier XML trouvé dans {dossier_path}")
        return pd.DataFrame()

    all_dfs = []
    total = len(fichiers)
    print(f"Traitement de {total} fichiers XML...\n")

    for i, fichier in enumerate(fichiers, 1):
        nom = os.path.basename(fichier)
        print(f"[{i}/{total}] {nom}...", end=" ")

        df = extraire_paragraphes_lxml(fichier)
        if not df.empty:
            print(f" {len(df)} lignes")
            all_dfs.append(df)
        else:
            print("Vide ou erreur")

    if all_dfs:
        df_final = pd.concat(all_dfs, ignore_index=True)
        print(f"\n Export terminé : {len(df_final)} lignes consolidées")
        return df_final
    else:
        return pd.DataFrame()

# %%
df = dossier_CR_lxml("/Users/matthiaslevalet/Desktop/Projet de recherche/CSS_République/Data/Raw/16e/")
df.to_csv("/Users/matthiaslevalet/Desktop/Projet de recherche/CSS_République/Data/Interim/Data_AN_16e.csv", index=False, encoding='utf-8')
print(f"\n Export CSV : ({df.shape[0]} lignes)")

# Si volonté de faire directement un CSV utiliser le dossier où j'ai enregistré tous les xml indépendamment de leur législature. 
# Sinon, utiliser les dossiers de sortie du téléchargement sur le site de l'AN.
# Out:
# Traitement de 604 fichiers XML...
#
# [1/604] CRSANR5L16S2023O1N173.xml...  633 lignes
# [2/604] CRSANR5L16S2023O1N167.xml...  467 lignes
# [3/604] CRSANR5L16S2023O1N198.xml...  402 lignes
# [4/604] CRSANR5L16S2023E1N010.xml...  818 lignes
# [5/604] CRSANR5L16S2024O1N117.xml...  678 lignes
# [6/604] CRSANR5L16S2024O1N103.xml...  857 lignes
# [7/604] CRSANR5L16S2023E1N004.xml...  646 lignes
# [8/604] CRSANR5L16S2023O1N239.xml...  452 lignes
# [9/604] CRSANR5L16S2023O1N205.xml...  118 lignes
# [10/604] CRSANR5L16S2023O1N211.xml...  296 lignes
# [11/604] CRSANR5L16S2024O1N088.xml...  403 lignes
# [12/604] CRSANR5L16S2023O1N007.xml...  535 lignes
# [13/604] CRSANR5L16S2023O1N013.xml...  808 lignes
# [14/604] CRSANR5L16S2024O1N063.xml...  106 lignes
# [15/604] CRSANR5L16S2024O1N077.xml...  760 lignes
# [16/604] CRSANR5L16S2024O1N076.xml...  834 lignes
# [17/604] CRSANR5L16S2024O1N062.xml...  322 lignes
# [18/604] CRSANR5L16S2023O1N012.xml...  688 lignes
# [19/604] CRSANR5L16S2023O1N006.xml...  430 lignes
# [20/604] CRSANR5L16S2024O1N089.xml...  541 lignes
# [21/604] CRSANR5L16S2023O1N210.xml...  625 lignes
# [22/604] CRSANR5L16S2023O1N204.xml...  737 lignes
# [23/604] CRSANR5L16S2023O1N238.xml...  373 lignes
# [24/604] CRSANR5L16S2023E1N005.xml...  609 lignes
# [25/604] CRSANR5L16S2024O1N102.xml...  207 lignes
# [26/604] CRSANR5L16S2024O1N116.xml...  343 lignes
# [27/604] CRSANR5L16S2023E1N011.xml...  432 lignes
# [28/604] CRSANR5L16S2023O1N199.xml...  723 lignes
# [29/604] CRSANR5L16S2023O1N166.xml...  285 lignes
# [30/604] CRSANR5L16S2023O1N172.xml...  426 lignes
# [31/604] CRSANR5L16S2023O1N158.xml...  181 lignes
# [32/604] CRSANR5L16S2023O1N164.xml...  545 lignes
# [33/604] CRSANR5L16S2023O1N170.xml...  526 lignes
# [34/604] CRSANR5L16S2024O1N128.xml...  399 lignes
# [35/604] CRSANR5L16S2024O1N100.xml...  434 lignes
# [36/604] CRSANR5L16S2023E1N007.xml...  904 lignes
# [37/604] CRSANR5L16S2023E1N013.xml...  626 lignes
# [38/604] CRSANR5L16S2024O1N114.xml...  797 lignes
# [39/604] CRSANR5L16S2023O1N212.xml...  684 lignes
# [40/604] CRSANR5L16S2023O1N206.xml...  686 lignes
# [41/604] CRSANR5L16S2023O1N038.xml...  455 lignes
# [42/604] CRSANR5L16S2023O1N010.xml...  528 lignes
# [43/604] CRSANR5L16S2023O1N004.xml...  462 lignes
# [44/604] CRSANR5L16S2024O1N048.xml...  424 lignes
# [45/604] CRSANR5L16S2024O1N074.xml...  246 lignes
# [46/604] CRSANR5L16S2024O1N060.xml...  330 lignes
# [47/604] CRSANR5L16S2024O1N061.xml...  721 lignes
# [48/604] CRSANR5L16S2024O1N075.xml...  791 lignes
# [49/604] CRSANR5L16S2024O1N049.xml...  208 lignes
# [50/604] CRSANR5L16S2023O1N005.xml...  971 lignes
# [51/604] CRSANR5L16S2023O1N011.xml...  243 lignes
# [52/604] CRSANR5L16S2023O1N039.xml...  641 lignes
# [53/604] CRSANR5L16S2023O1N207.xml...  808 lignes
# [54/604] CRSANR5L16S2023O1N213.xml...  375 lignes
# [55/604] CRSANR5L16S2024O1N115.xml...  300 lignes
# [56/604] CRSANR5L16S2023E1N012.xml...  1178 lignes
# [57/604] CRSANR5L16S2023E1N006.xml...  515 lignes
# [58/604] CRSANR5L16S2024O1N101.xml...  875 lignes
# [59/604] CRSANR5L16S2024O1N129.xml...  550 lignes
# [60/604] CRSANR5L16S2023O1N171.xml...  609 lignes
# [61/604] CRSANR5L16S2023O1N165.xml...  301 lignes
# [62/604] CRSANR5L16S2023O1N159.xml...  578 lignes
# [63/604] CRSANR5L16S2023O1N161.xml...  417 lignes
# [64/604] CRSANR5L16S2023O1N175.xml...  812 lignes
# [65/604] CRSANR5L16S2023O1N149.xml...  488 lignes
# [66/604] CRSANR5L16S2024O1N105.xml...  43 lignes
# [67/604] CRSANR5L16S2023E1N002.xml...  559 lignes
# [68/604] CRSANR5L16S2023E1N016.xml...  843 lignes
# [69/604] CRSANR5L16S2024O1N111.xml...  953 lignes
# [70/604] CRSANR5L16S2024O1N139.xml...  527 lignes
# [71/604] CRSANR5L16S2023O1N217.xml...  192 lignes
# [72/604] CRSANR5L16S2023O1N203.xml...  114 lignes
# [73/604] CRSANR5L16S2023O1N015.xml...  544 lignes
# [74/604] CRSANR5L16S2023O1N001.xml...  257 lignes
# [75/604] CRSANR5L16S2023O1N029.xml...  429 lignes
# [76/604] CRSANR5L16S2024O1N071.xml...  19 lignes
# [77/604] CRSANR5L16S2024O1N065.xml...  607 lignes
# [78/604] CRSANR5L16S2024O1N059.xml...  664 lignes
# [79/604] CRSANR5L16S2024O1N058.xml...  774 lignes
# [80/604] CRSANR5L16S2024O1N064.xml...  202 lignes
# [81/604] CRSANR5L16S2024O1N070.xml...  376 lignes
# [82/604] CRSANR5L16S2023O1N028.xml...  737 lignes
# [83/604] CRSANR5L16S2023O1N014.xml...  782 lignes
# [84/604] CRSANR5L16S2023O1N202.xml...  682 lignes
# [85/604] CRSANR5L16S2023O1N216.xml...  462 lignes
# [86/604] CRSANR5L16S2024O1N138.xml...  245 lignes
# [87/604] CRSANR5L16S2024O1N110.xml...  414 lignes
# [88/604] CRSANR5L16S2023E1N017.xml...  1286 lignes
# [89/604] CRSANR5L16S2023E1N003.xml...  1140 lignes
# [90/604] CRSANR5L16S2024O1N104.xml...  680 lignes
# [91/604] CRSANR5L16S2023O1N148.xml...  773 lignes
# [92/604] CRSANR5L16S2023O1N174.xml...  533 lignes
# [93/604] CRSANR5L16S2023O1N160.xml...  139 lignes
# [94/604] CRSANR5L16S2023O1N176.xml...  475 lignes
# [95/604] CRSANR5L16S2023O1N162.xml...  195 lignes
# [96/604] CRSANR5L16S2023E1N015.xml...  645 lignes
# [97/604] CRSANR5L16S2024O1N112.xml...  423 lignes
# [98/604] CRSANR5L16S2024O1N106.xml...  748 lignes
# [99/604] CRSANR5L16S2023E1N001.xml...  553 lignes
# [100/604] CRSANR5L16S2023O1N189.xml...  1163 lignes
# [101/604] CRSANR5L16S2023E1N029.xml...  828 lignes
# [102/604] CRSANR5L16S2023O1N200.xml...  296 lignes
# [103/604] CRSANR5L16S2023O1N214.xml...  680 lignes
# [104/604] CRSANR5L16S2023O1N228.xml...  532 lignes
# [105/604] CRSANR5L16S2023O1N002.xml...  290 lignes
# [106/604] CRSANR5L16S2023O1N016.xml...  640 lignes
# [107/604] CRSANR5L16S2024O1N099.xml...  484 lignes
# [108/604] CRSANR5L16S2024O1N066.xml...  416 lignes
# [109/604] CRSANR5L16S2024O1N072.xml...  247 lignes
# [110/604] CRSANR5L16S2024O1N073.xml...  696 lignes
# [111/604] CRSANR5L16S2024O1N067.xml...  1152 lignes
# [112/604] CRSANR5L16S2024O1N098.xml...  237 lignes
# [113/604] CRSANR5L16S2023O1N017.xml...  734 lignes
# [114/604] CRSANR5L16S2023O1N003.xml...  813 lignes
# [115/604] CRSANR5L16S2023O1N229.xml...  738 lignes
# [116/604] CRSANR5L16S2023O1N215.xml...  933 lignes
# [117/604] CRSANR5L16S2023O1N201.xml...  100 lignes
# [118/604] CRSANR5L16S2023E1N028.xml...  1211 lignes
# [119/604] CRSANR5L16S2023O1N188.xml...  1071 lignes
# [120/604] CRSANR5L16S2024O1N107.xml...  479 lignes
# [121/604] CRSANR5L16S2024O1N113.xml...  808 lignes
# [122/604] CRSANR5L16S2023E1N014.xml...  667 lignes
# [123/604] CRSANR5L16S2023O1N163.xml...  563 lignes
# [124/604] CRSANR5L16S2023O1N177.xml...  581 lignes
# [125/604] CRSANR5L16S2023O1N138.xml...  589 lignes
# [126/604] CRSANR5L16S2023O1N110.xml...  435 lignes
# [127/604] CRSANR5L16S2023O1N104.xml...  602 lignes
# [128/604] CRSANR5L16S2024O1N148.xml...  481 lignes
# [129/604] CRSANR5L16S2024O1N174.xml...  503 lignes
# [130/604] CRSANR5L16S2024O1N160.xml...  980 lignes
# [131/604] CRSANR5L16S2023O1N266.xml...  204 lignes
# [132/604] CRSANR5L16S2023O1N272.xml...  744 lignes
# [133/604] CRSANR5L16S2022E1N010.xml...  495 lignes
# [134/604] CRSANR5L16S2022E1N004.xml...  798 lignes
# [135/604] CRSANR5L16S2024O1N202.xml...  573 lignes
# [136/604] CRSANR5L16S2024O1N216.xml...  936 lignes
# [137/604] CRSANR5L16S2023O1N058.xml...  1215 lignes
# [138/604] CRSANR5L16S2023O1N064.xml...  220 lignes
# [139/604] CRSANR5L16S2023E2N007.xml...  792 lignes
# [140/604] CRSANR5L16S2023O1N070.xml...  426 lignes
# [141/604] CRSANR5L16S2024O1N028.xml...  342 lignes
# [142/604] CRSANR5L16S2024O1N014.xml...  698 lignes
# [143/604] CRSANR5L16S2024O1N015.xml...  360 lignes
# [144/604] CRSANR5L16S2024O1N001.xml...  7 lignes
# [145/604] CRSANR5L16S2024O1N029.xml...  452 lignes
# [146/604] CRSANR5L16S2023E2N012.xml...  418 lignes
# [147/604] CRSANR5L16S2023O1N071.xml...  450 lignes
# [148/604] CRSANR5L16S2023E2N006.xml...  348 lignes
# [149/604] CRSANR5L16S2023O1N065.xml...  502 lignes
# [150/604] CRSANR5L16S2023O1N059.xml...  440 lignes
# [151/604] CRSANR5L16S2024O1N217.xml...  534 lignes
# [152/604] CRSANR5L16S2024O1N203.xml...  955 lignes
# [153/604] CRSANR5L16S2022E1N005.xml...  577 lignes
# [154/604] CRSANR5L16S2022E1N011.xml...  831 lignes
# [155/604] CRSANR5L16S2023O1N273.xml...  541 lignes
# [156/604] CRSANR5L16S2023O1N267.xml...  944 lignes
# [157/604] CRSANR5L16S2024O1N161.xml...  286 lignes
# [158/604] CRSANR5L16S2024O1N175.xml...  417 lignes
# [159/604] CRSANR5L16S2024O1N149.xml...  777 lignes
# [160/604] CRSANR5L16S2023O1N105.xml...  367 lignes
# [161/604] CRSANR5L16S2023O1N111.xml...  436 lignes
# [162/604] CRSANR5L16S2023O1N139.xml...  845 lignes
# [163/604] CRSANR5L16S2024O1N188.xml...  404 lignes
# [164/604] CRSANR5L16S2023O1N107.xml...  230 lignes
# [165/604] CRSANR5L16S2023O1N113.xml...  642 lignes
# [166/604] CRSANR5L16S2024O1N163.xml...  188 lignes
# [167/604] CRSANR5L16S2024O1N177.xml...  554 lignes
# [168/604] CRSANR5L16S2023O1N259.xml...  666 lignes
# [169/604] CRSANR5L16S2022O1N170.xml...  28 lignes
# [170/604] CRSANR5L16S2023O1N271.xml...  407 lignes
# [171/604] CRSANR5L16S2023O1N265.xml...  197 lignes
# [172/604] CRSANR5L16S2022E1N007.xml...  646 lignes
# [173/604] CRSANR5L16S2024O1N229.xml...  466 lignes
# [174/604] CRSANR5L16S2022E1N013.xml...  569 lignes
# [175/604] CRSANR5L16S2024O1N215.xml...  459 lignes
# [176/604] CRSANR5L16S2024O1N201.xml...  961 lignes
# [177/604] CRSANR5L16S2023O1N073.xml...  822 lignes
# [178/604] CRSANR5L16S2023E2N010.xml...  715 lignes
# [179/604] CRSANR5L16S2023O1N067.xml...  794 lignes
# [180/604] CRSANR5L16S2023E2N004.xml...  578 lignes
# [181/604] CRSANR5L16S2023O1N098.xml...  860 lignes
# [182/604] CRSANR5L16S2024O1N017.xml...  996 lignes
# [183/604] CRSANR5L16S2024O1N003.xml...  891 lignes
# [184/604] CRSANR5L16S2024O1N002.xml...  444 lignes
# [185/604] CRSANR5L16S2024O1N016.xml...  628 lignes
# [186/604] CRSANR5L16S2023O1N099.xml...  563 lignes
# [187/604] CRSANR5L16S2023E2N005.xml...  925 lignes
# [188/604] CRSANR5L16S2023O1N066.xml...  135 lignes
# [189/604] CRSANR5L16S2023E2N011.xml...  993 lignes
# [190/604] CRSANR5L16S2023O1N072.xml...  341 lignes
# [191/604] CRSANR5L16S2024O1N200.xml...  733 lignes
# [192/604] CRSANR5L16S2024O1N214.xml...  607 lignes
# [193/604] CRSANR5L16S2022E1N012.xml...  455 lignes
# [194/604] CRSANR5L16S2024O1N228.xml...  575 lignes
# [195/604] CRSANR5L16S2022E1N006.xml...  373 lignes
# [196/604] CRSANR5L16S2023O1N264.xml...  553 lignes
# [197/604] CRSANR5L16S2023O1N270.xml...  304 lignes
# [198/604] CRSANR5L16S2023O1N258.xml...  755 lignes
# [199/604] CRSANR5L16S2024O1N176.xml...  816 lignes
# [200/604] CRSANR5L16S2024O1N162.xml...  392 lignes
# [201/604] CRSANR5L16S2023O1N112.xml...  145 lignes
# [202/604] CRSANR5L16S2023O1N106.xml...  259 lignes
# [203/604] CRSANR5L16S2024O1N189.xml...  597 lignes
# [204/604] CRSANR5L16S2023O1N102.xml...  773 lignes
# [205/604] CRSANR5L16S2023O1N116.xml...  409 lignes
# [206/604] CRSANR5L16S2024O1N199.xml...  1028 lignes
# [207/604] CRSANR5L16S2024O1N166.xml...  609 lignes
# [208/604] CRSANR5L16S2024O1N172.xml...  280 lignes
# [209/604] CRSANR5L16S2023O1N274.xml...  555 lignes
# [210/604] CRSANR5L16S2023O1N260.xml...  132 lignes
# [211/604] CRSANR5L16S2023O1N248.xml...  701 lignes
# [212/604] CRSANR5L16S2024O1N210.xml...  1104 lignes
# [213/604] CRSANR5L16S2024O1N204.xml...  527 lignes
# [214/604] CRSANR5L16S2022E1N002.xml...  411 lignes
# [215/604] CRSANR5L16S2022E1N016.xml...  680 lignes
# [216/604] CRSANR5L16S2023O1N076.xml...  250 lignes
# [217/604] CRSANR5L16S2023O1N062.xml...  1422 lignes
# [218/604] CRSANR5L16S2023E2N001.xml...  478 lignes
# [219/604] CRSANR5L16S2024O1N012.xml...  698 lignes
# [220/604] CRSANR5L16S2024O1N006.xml...  385 lignes
# [221/604] CRSANR5L16S2023O1N089.xml...  417 lignes
# [222/604] CRSANR5L16S2023O1N088.xml...  421 lignes
# [223/604] CRSANR5L16S2024O1N007.xml...  540 lignes
# [224/604] CRSANR5L16S2024O1N013.xml...  359 lignes
# [225/604] CRSANR5L16S2023O1N063.xml...  335 lignes
# [226/604] CRSANR5L16S2023O1N077.xml...  624 lignes
# [227/604] CRSANR5L16S2022E1N017.xml...  448 lignes
# [228/604] CRSANR5L16S2022E1N003.xml...  374 lignes
# [229/604] CRSANR5L16S2024O1N205.xml...  526 lignes
# [230/604] CRSANR5L16S2024O1N211.xml...  301 lignes
# [231/604] CRSANR5L16S2023O1N249.xml...  1028 lignes
# [232/604] CRSANR5L16S2023O1N261.xml...  649 lignes
# [233/604] CRSANR5L16S2023O1N275.xml...  565 lignes
# [234/604] CRSANR5L16S2024O1N173.xml...  217 lignes
# [235/604] CRSANR5L16S2024O1N167.xml...  181 lignes
# [236/604] CRSANR5L16S2024O1N198.xml...  713 lignes
# [237/604] CRSANR5L16S2023O1N117.xml...  145 lignes
# [238/604] CRSANR5L16S2023O1N103.xml...  881 lignes
# [239/604] CRSANR5L16S2023O1N115.xml...  385 lignes
# [240/604] CRSANR5L16S2023O1N101.xml...  394 lignes
# [241/604] CRSANR5L16S2023O1N129.xml...  350 lignes
# [242/604] CRSANR5L16S2024O1N171.xml...  197 lignes
# [243/604] CRSANR5L16S2024O1N165.xml...  367 lignes
# [244/604] CRSANR5L16S2024O1N159.xml...  477 lignes
# [245/604] CRSANR5L16S2023O1N263.xml...  424 lignes
# [246/604] CRSANR5L16S2023O1N277.xml...  508 lignes
# [247/604] CRSANR5L16S2022E1N029.xml...  170 lignes
# [248/604] CRSANR5L16S2024O1N207.xml...  519 lignes
# [249/604] CRSANR5L16S2024O1N213.xml...  192 lignes
# [250/604] CRSANR5L16S2022E1N015.xml...  1324 lignes
# [251/604] CRSANR5L16S2023O1N288.xml...  832 lignes
# [252/604] CRSANR5L16S2022E1N001.xml...  584 lignes
# [253/604] CRSANR5L16S2023O1N061.xml...  924 lignes
# [254/604] CRSANR5L16S2023E2N002.xml...  435 lignes
# [255/604] CRSANR5L16S2023O1N075.xml...  489 lignes
# [256/604] CRSANR5L16S2023O1N049.xml...  902 lignes
# [257/604] CRSANR5L16S2024O1N005.xml...  634 lignes
# [258/604] CRSANR5L16S2024O1N011.xml...  365 lignes
# [259/604] CRSANR5L16S2024O1N039.xml...  566 lignes
# [260/604] CRSANR5L16S2024O1N038.xml...  832 lignes
# [261/604] CRSANR5L16S2024O1N010.xml...  601 lignes
# [262/604] CRSANR5L16S2024O1N004.xml...  544 lignes
# [263/604] CRSANR5L16S2023O1N048.xml...  663 lignes
# [264/604] CRSANR5L16S2023O1N074.xml...  455 lignes
# [265/604] CRSANR5L16S2023E2N003.xml...  867 lignes
# [266/604] CRSANR5L16S2023O1N060.xml...  818 lignes
# [267/604] CRSANR5L16S2023O1N289.xml...  525 lignes
# [268/604] CRSANR5L16S2022E1N014.xml...  786 lignes
# [269/604] CRSANR5L16S2024O1N212.xml...  399 lignes
# [270/604] CRSANR5L16S2024O1N206.xml...  1038 lignes
# [271/604] CRSANR5L16S2022E1N028.xml...  684 lignes
# [272/604] CRSANR5L16S2023O1N276.xml...  577 lignes
# [273/604] CRSANR5L16S2023O1N262.xml...  515 lignes
# [274/604] CRSANR5L16S2024O1N158.xml...  813 lignes
# [275/604] CRSANR5L16S2024O1N164.xml...  574 lignes
# [276/604] CRSANR5L16S2024O1N170.xml...  628 lignes
# [277/604] CRSANR5L16S2023O1N128.xml...  581 lignes
# [278/604] CRSANR5L16S2023O1N100.xml...  707 lignes
# [279/604] CRSANR5L16S2023O1N114.xml...  854 lignes
# [280/604] CRSANR5L16S2023O1N119.xml...  551 lignes
# [281/604] CRSANR5L16S2024O1N196.xml...  734 lignes
# [282/604] CRSANR5L16S2023O1N131.xml...  739 lignes
# [283/604] CRSANR5L16S2023O1N125.xml...  723 lignes
# [284/604] CRSANR5L16S2024O1N182.xml...  270 lignes
# [285/604] CRSANR5L16S2024O1N169.xml...  976 lignes
# [286/604] CRSANR5L16S2024O1N155.xml...  335 lignes
# [287/604] CRSANR5L16S2024O1N141.xml...  346 lignes
# [288/604] CRSANR5L16S2023O1N247.xml...  481 lignes
# [289/604] CRSANR5L16S2023O1N253.xml...  897 lignes
# [290/604] CRSANR5L16S2022E1N031.xml...  257 lignes
# [291/604] CRSANR5L16S2022E1N025.xml...  469 lignes
# [292/604] CRSANR5L16S2024O1N223.xml...  548 lignes
# [293/604] CRSANR5L16S2023O1N284.xml...  424 lignes
# [294/604] CRSANR5L16S2023O1N290.xml...  559 lignes
# [295/604] CRSANR5L16S2022E1N019.xml...  1015 lignes
# [296/604] CRSANR5L16S2023O1N079.xml...  607 lignes
# [297/604] CRSANR5L16S2023O1N045.xml...  361 lignes
# [298/604] CRSANR5L16S2023O1N051.xml...  447 lignes
# [299/604] CRSANR5L16S2024O1N009.xml...  376 lignes
# [300/604] CRSANR5L16S2023O1N086.xml...  401 lignes
# [301/604] CRSANR5L16S2024O1N021.xml...  625 lignes
# [302/604] CRSANR5L16S2024O1N035.xml...  785 lignes
# [303/604] CRSANR5L16S2023O1N092.xml...  700 lignes
# [304/604] CRSANR5L16S2023O1N093.xml...  954 lignes
# [305/604] CRSANR5L16S2024O1N034.xml...  417 lignes
# [306/604] CRSANR5L16S2024O1N020.xml...  925 lignes
# [307/604] CRSANR5L16S2023O1N087.xml...  837 lignes
# [308/604] CRSANR5L16S2024O1N008.xml...  751 lignes
# [309/604] CRSANR5L16S2023O1N050.xml...  1255 lignes
# [310/604] CRSANR5L16S2023O1N044.xml...  231 lignes
# [311/604] CRSANR5L16S2023O1N078.xml...  738 lignes
# [312/604] CRSANR5L16S2022E1N018.xml...  810 lignes
# [313/604] CRSANR5L16S2023O1N291.xml...  563 lignes
# [314/604] CRSANR5L16S2023O1N285.xml...  835 lignes
# [315/604] CRSANR5L16S2024O1N222.xml...  890 lignes
# [316/604] CRSANR5L16S2022E1N024.xml...  1128 lignes
# [317/604] CRSANR5L16S2022E1N030.xml...  444 lignes
# [318/604] CRSANR5L16S2023O1N252.xml...  463 lignes
# [319/604] CRSANR5L16S2023O1N246.xml...  838 lignes
# [320/604] CRSANR5L16S2024O1N140.xml...  708 lignes
# [321/604] CRSANR5L16S2024O1N154.xml...  734 lignes
# [322/604] CRSANR5L16S2024O1N168.xml...  664 lignes
# [323/604] CRSANR5L16S2024O1N183.xml...  305 lignes
# [324/604] CRSANR5L16S2023O1N124.xml...  97 lignes
# [325/604] CRSANR5L16S2023O1N130.xml...  109 lignes
# [326/604] CRSANR5L16S2024O1N197.xml...  599 lignes
# [327/604] CRSANR5L16S2023O1N118.xml...  183 lignes
# [328/604] CRSANR5L16S2023O1N126.xml...  423 lignes
# [329/604] CRSANR5L16S2024O1N181.xml...  375 lignes
# [330/604] CRSANR5L16S2024O1N195.xml...  566 lignes
# [331/604] CRSANR5L16S2023O1N132.xml...  472 lignes
# [332/604] CRSANR5L16S2024O1N142.xml...  367 lignes
# [333/604] CRSANR5L16S2024O1N156.xml...  918 lignes
# [334/604] CRSANR5L16S2023O1N278.xml...  976 lignes
# [335/604] CRSANR5L16S2023O1N250.xml...  446 lignes
# [336/604] CRSANR5L16S2023O1N244.xml...  494 lignes
# [337/604] CRSANR5L16S2024O1N208.xml...  699 lignes
# [338/604] CRSANR5L16S2022E1N026.xml...  229 lignes
# [339/604] CRSANR5L16S2022E1N032.xml...  403 lignes
# [340/604] CRSANR5L16S2023O1N293.xml...  195 lignes
# [341/604] CRSANR5L16S2024O1N234.xml...  785 lignes
# [342/604] CRSANR5L16S2024O1N220.xml...  242 lignes
# [343/604] CRSANR5L16S2023O1N287.xml...  421 lignes
# [344/604] CRSANR5L16S2023O1N052.xml...  406 lignes
# [345/604] CRSANR5L16S2023O1N046.xml...  376 lignes
# [346/604] CRSANR5L16S2024O1N036.xml...  403 lignes
# [347/604] CRSANR5L16S2023O1N091.xml...  515 lignes
# [348/604] CRSANR5L16S2023O1N085.xml...  788 lignes
# [349/604] CRSANR5L16S2024O1N022.xml...  246 lignes
# [350/604] CRSANR5L16S2024O1N023.xml...  275 lignes
# [351/604] CRSANR5L16S2023O1N084.xml...  215 lignes
# [352/604] CRSANR5L16S2023O1N090.xml...  970 lignes
# [353/604] CRSANR5L16S2024O1N037.xml...  690 lignes
# [354/604] CRSANR5L16S2023O1N047.xml...  486 lignes
# [355/604] CRSANR5L16S2023O1N053.xml...  681 lignes
# [356/604] CRSANR5L16S2023O1N286.xml...  493 lignes
# [357/604] CRSANR5L16S2024O1N221.xml...  662 lignes
# [358/604] CRSANR5L16S2024O1N235.xml...  510 lignes
# [359/604] CRSANR5L16S2023O1N292.xml...  358 lignes
# [360/604] CRSANR5L16S2022E1N027.xml...  73 lignes
# [361/604] CRSANR5L16S2024O1N209.xml...  1196 lignes
# [362/604] CRSANR5L16S2023O1N245.xml...  934 lignes
# [363/604] CRSANR5L16S2023O1N251.xml...  938 lignes
# [364/604] CRSANR5L16S2023O1N279.xml...  517 lignes
# [365/604] CRSANR5L16S2024O1N157.xml...  216 lignes
# [366/604] CRSANR5L16S2024O1N143.xml...  193 lignes
# [367/604] CRSANR5L16S2023O1N133.xml...  178 lignes
# [368/604] CRSANR5L16S2024O1N194.xml...  424 lignes
# [369/604] CRSANR5L16S2024O1N180.xml...  633 lignes
# [370/604] CRSANR5L16S2023O1N127.xml...  175 lignes
# [371/604] CRSANR5L16S2023O1N123.xml...  797 lignes
# [372/604] CRSANR5L16S2024O1N184.xml...  511 lignes
# [373/604] CRSANR5L16S2024O1N190.xml...  208 lignes
# [374/604] CRSANR5L16S2023O1N137.xml...  495 lignes
# [375/604] CRSANR5L16S2024O1N147.xml...  548 lignes
# [376/604] CRSANR5L16S2024O1N153.xml...  512 lignes
# [377/604] CRSANR5L16S2023O1N255.xml...  662 lignes
# [378/604] CRSANR5L16S2023O1N241.xml...  914 lignes
# [379/604] CRSANR5L16S2023O1N269.xml...  897 lignes
# [380/604] CRSANR5L16S2024O1N231.xml...  823 lignes
# [381/604] CRSANR5L16S2024O1N225.xml...  386 lignes
# [382/604] CRSANR5L16S2023O1N282.xml...  531 lignes
# [383/604] CRSANR5L16S2022E1N023.xml...  814 lignes
# [384/604] CRSANR5L16S2024O1N219.xml...  543 lignes
# [385/604] CRSANR5L16S2023O1N057.xml...  501 lignes
# [386/604] CRSANR5L16S2023O1N043.xml...  478 lignes
# [387/604] CRSANR5L16S2023E2N008.xml...  916 lignes
# [388/604] CRSANR5L16S2024O1N033.xml...  564 lignes
# [389/604] CRSANR5L16S2023O1N094.xml...  580 lignes
# [390/604] CRSANR5L16S2023O1N080.xml...  783 lignes
# [391/604] CRSANR5L16S2024O1N027.xml...  783 lignes
# [392/604] CRSANR5L16S2024O1N026.xml...  454 lignes
# [393/604] CRSANR5L16S2023O1N081.xml...  372 lignes
# [394/604] CRSANR5L16S2023O1N095.xml...  387 lignes
# [395/604] CRSANR5L16S2024O1N032.xml...  733 lignes
# [396/604] CRSANR5L16S2023E2N009.xml...  496 lignes
# [397/604] CRSANR5L16S2023O1N042.xml...  815 lignes
# [398/604] CRSANR5L16S2023O1N056.xml...  393 lignes
# [399/604] CRSANR5L16S2024O1N218.xml...  472 lignes
# [400/604] CRSANR5L16S2022E1N022.xml...  1055 lignes
# [401/604] CRSANR5L16S2023O1N283.xml...  897 lignes
# [402/604] CRSANR5L16S2024O1N224.xml...  952 lignes
# [403/604] CRSANR5L16S2024O1N230.xml...  628 lignes
# [404/604] CRSANR5L16S2023O1N268.xml...  430 lignes
# [405/604] CRSANR5L16S2023O1N240.xml...  178 lignes
# [406/604] CRSANR5L16S2022O1N169.xml...  31 lignes
# [407/604] CRSANR5L16S2023O1N254.xml...  744 lignes
# [408/604] CRSANR5L16S2024O1N152.xml...  384 lignes
# [409/604] CRSANR5L16S2024O1N146.xml...  1078 lignes
# [410/604] CRSANR5L16S2023O1N136.xml...  883 lignes
# [411/604] CRSANR5L16S2024O1N191.xml...  674 lignes
# [412/604] CRSANR5L16S2024O1N185.xml...  222 lignes
# [413/604] CRSANR5L16S2023O1N122.xml...  399 lignes
# [414/604] CRSANR5L16S2024O1N193.xml...  843 lignes
# [415/604] CRSANR5L16S2023O1N134.xml...  822 lignes
# [416/604] CRSANR5L16S2023O1N120.xml...  432 lignes
# [417/604] CRSANR5L16S2024O1N187.xml...  124 lignes
# [418/604] CRSANR5L16S2023O1N108.xml...  198 lignes
# [419/604] CRSANR5L16S2024O1N150.xml...  557 lignes
# [420/604] CRSANR5L16S2024O1N144.xml...  788 lignes
# [421/604] CRSANR5L16S2024O1N178.xml...  449 lignes
# [422/604] CRSANR5L16S2023O1N242.xml...  424 lignes
# [423/604] CRSANR5L16S2023O1N256.xml...  161 lignes
# [424/604] CRSANR5L16S2024O1N226.xml...  676 lignes
# [425/604] CRSANR5L16S2023O1N281.xml...  433 lignes
# [426/604] CRSANR5L16S2022E1N008.xml...  466 lignes
# [427/604] CRSANR5L16S2024O1N232.xml...  466 lignes
# [428/604] CRSANR5L16S2022E1N020.xml...  232 lignes
# [429/604] CRSANR5L16S2023O1N040.xml...  1036 lignes
# [430/604] CRSCGR5L16S2024O1N001.xml...  77 lignes
# [431/604] CRSANR5L16S2023O1N054.xml...  385 lignes
# [432/604] CRSANR5L16S2023O1N068.xml...  885 lignes
# [433/604] CRSANR5L16S2023O1N083.xml...  459 lignes
# [434/604] CRSANR5L16S2024O1N024.xml...  155 lignes
# [435/604] CRSANR5L16S2024O1N030.xml...  646 lignes
# [436/604] CRSANR5L16S2023O1N097.xml...  462 lignes
# [437/604] CRSANR5L16S2024O1N018.xml...  481 lignes
# [438/604] CRSANR5L16S2024O1N019.xml...  519 lignes
# [439/604] CRSANR5L16S2023O1N096.xml...  642 lignes
# [440/604] CRSANR5L16S2024O1N031.xml...  322 lignes
# [441/604] CRSANR5L16S2024O1N025.xml...  522 lignes
# [442/604] CRSANR5L16S2023O1N082.xml...  443 lignes
# [443/604] CRSANR5L16S2023O1N069.xml...  381 lignes
# [444/604] CRSANR5L16S2023O1N055.xml...  680 lignes
# [445/604] CRSANR5L16S2023O1N041.xml...  269 lignes
# [446/604] CRSANR5L16S2022E1N021.xml...  467 lignes
# [447/604] CRSANR5L16S2024O1N233.xml...  359 lignes
# [448/604] CRSANR5L16S2022E1N009.xml...  835 lignes
# [449/604] CRSANR5L16S2023O1N280.xml...  859 lignes
# [450/604] CRSANR5L16S2024O1N227.xml...  472 lignes
# [451/604] CRSANR5L16S2023O1N257.xml...  447 lignes
# [452/604] CRSANR5L16S2023O1N243.xml...  951 lignes
# [453/604] CRSANR5L16S2024O1N179.xml...  271 lignes
# [454/604] CRSANR5L16S2024O1N145.xml...  376 lignes
# [455/604] CRSANR5L16S2024O1N151.xml...  448 lignes
# [456/604] CRSANR5L16S2023O1N109.xml...  509 lignes
# [457/604] CRSANR5L16S2024O1N186.xml...  534 lignes
# [458/604] CRSANR5L16S2023O1N121.xml...  700 lignes
# [459/604] CRSANR5L16S2023O1N135.xml...  434 lignes
# [460/604] CRSANR5L16S2024O1N192.xml...  382 lignes
# [461/604] CRSANR5L16S2023O1N152.xml...  407 lignes
# [462/604] CRSANR5L16S2023O1N146.xml...  963 lignes
# [463/604] CRSANR5L16S2023E1N019.xml...  579 lignes
# [464/604] CRSANR5L16S2024O1N136.xml...  280 lignes
# [465/604] CRSANR5L16S2023O1N191.xml...  436 lignes
# [466/604] CRSANR5L16S2023O1N185.xml...  552 lignes
# [467/604] CRSANR5L16S2023E1N025.xml...  961 lignes
# [468/604] CRSANR5L16S2024O1N122.xml...  458 lignes
# [469/604] CRSANR5L16S2023O1N218.xml...  650 lignes
# [470/604] CRSANR5L16S2023O1N224.xml...  453 lignes
# [471/604] CRSANR5L16S2023O1N230.xml...  720 lignes
# [472/604] CRSANR5L16S2023O1N026.xml...  405 lignes
# [473/604] CRSANR5L16S2024O1N081.xml...  326 lignes
# [474/604] CRSANR5L16S2024O1N095.xml...  136 lignes
# [475/604] CRSANR5L16S2023O1N032.xml...  387 lignes
# [476/604] CRSANR5L16S2024O1N042.xml...  541 lignes
# [477/604] CRSANR5L16S2024O1N056.xml...  456 lignes
# [478/604] CRSANR5L16S2024O1N057.xml...  446 lignes
# [479/604] CRSANR5L16S2024O1N043.xml...  388 lignes
# [480/604] CRSANR5L16S2023O1N033.xml...  846 lignes
# [481/604] CRSANR5L16S2024O1N094.xml...  750 lignes
# [482/604] CRSANR5L16S2024O1N080.xml...  352 lignes
# [483/604] CRSANR5L16S2023O1N027.xml...  423 lignes
# [484/604] CRSANR5L16S2023O1N231.xml...  427 lignes
# [485/604] CRSANR5L16S2023O1N225.xml...  201 lignes
# [486/604] CRSANR5L16S2023O1N219.xml...  365 lignes
# [487/604] CRSANR5L16S2024O1N123.xml...  976 lignes
# [488/604] CRSANR5L16S2023E1N024.xml...  887 lignes
# [489/604] CRSANR5L16S2023O1N184.xml...  869 lignes
# [490/604] CRSANR5L16S2023O1N190.xml...  670 lignes
# [491/604] CRSANR5L16S2024O1N137.xml...  1278 lignes
# [492/604] CRSANR5L16S2023E1N018.xml...  771 lignes
# [493/604] CRSANR5L16S2023O1N147.xml...  511 lignes
# [494/604] CRSANR5L16S2023O1N153.xml...  835 lignes
# [495/604] CRSANR5L16S2023O1N179.xml...  777 lignes
# [496/604] CRSANR5L16S2023O1N145.xml...  443 lignes
# [497/604] CRSANR5L16S2023O1N151.xml...  905 lignes
# [498/604] CRSANR5L16S2024O1N109.xml...  782 lignes
# [499/604] CRSANR5L16S2023O1N186.xml...  671 lignes
# [500/604] CRSANR5L16S2023E1N026.xml...  540 lignes
# [501/604] CRSANR5L16S2024O1N121.xml...  789 lignes
# [502/604] CRSANR5L16S2024O1N135.xml...  871 lignes
# [503/604] CRSANR5L16S2023O1N192.xml...  354 lignes
# [504/604] CRSANR5L16S2023O1N233.xml...  569 lignes
# [505/604] CRSANR5L16S2023O1N227.xml...  724 lignes
# [506/604] CRSANR5L16S2023O1N019.xml...  485 lignes
# [507/604] CRSANR5L16S2024O1N096.xml...  325 lignes
# [508/604] CRSANR5L16S2023O1N031.xml...  627 lignes
# [509/604] CRSANR5L16S2023O1N025.xml...  488 lignes
# [510/604] CRSANR5L16S2024O1N082.xml...  216 lignes
# [511/604] CRSANR5L16S2024O1N069.xml...  929 lignes
# [512/604] CRSANR5L16S2024O1N055.xml...  444 lignes
# [513/604] CRSANR5L16S2024O1N041.xml...  492 lignes
# [514/604] CRSANR5L16S2024O1N040.xml...  215 lignes
# [515/604] CRSANR5L16S2024O1N054.xml...  485 lignes
# [516/604] CRSANR5L16S2024O1N068.xml...  659 lignes
# [517/604] CRSANR5L16S2024O1N083.xml...  708 lignes
# [518/604] CRSANR5L16S2023O1N024.xml...  881 lignes
# [519/604] CRSANR5L16S2023O1N030.xml...  425 lignes
# [520/604] CRSANR5L16S2024O1N097.xml...  245 lignes
# [521/604] CRSANR5L16S2023O1N018.xml...  450 lignes
# [522/604] CRSANR5L16S2023O1N226.xml...  106 lignes
# [523/604] CRSANR5L16S2023O1N232.xml...  575 lignes
# [524/604] CRSANR5L16S2023O1N193.xml...  199 lignes
# [525/604] CRSANR5L16S2024O1N134.xml...  225 lignes
# [526/604] CRSANR5L16S2024O1N120.xml...  207 lignes
# [527/604] CRSANR5L16S2023E1N027.xml...  949 lignes
# [528/604] CRSANR5L16S2023O1N187.xml...  570 lignes
# [529/604] CRSANR5L16S2024O1N108.xml...  188 lignes
# [530/604] CRSANR5L16S2023O1N150.xml...  1013 lignes
# [531/604] CRSANR5L16S2023O1N144.xml...  650 lignes
# [532/604] CRSANR5L16S2023O1N178.xml...  521 lignes
# [533/604] CRSANR5L16S2023O1N140.xml...  353 lignes
# [534/604] CRSANR5L16S2023O1N154.xml...  1165 lignes
# [535/604] CRSANR5L16S2023O1N168.xml...  182 lignes
# [536/604] CRSANR5L16S2023O1N183.xml...  421 lignes
# [537/604] CRSANR5L16S2023E1N023.xml...  592 lignes
# [538/604] CRSANR5L16S2024O1N124.xml...  141 lignes
# [539/604] CRSANR5L16S2024O1N130.xml...  104 lignes
# [540/604] CRSANR5L16S2023O1N197.xml...  618 lignes
# [541/604] CRSANR5L16S2024O1N118.xml...  528 lignes
# [542/604] CRSANR5L16S2023O1N236.xml...  1021 lignes
# [543/604] CRSANR5L16S2023O1N222.xml...  607 lignes
# [544/604] CRSANR5L16S2024O1N093.xml...  219 lignes
# [545/604] CRSANR5L16S2023O1N034.xml...  370 lignes
# [546/604] CRSANR5L16S2023O1N020.xml...  702 lignes
# [547/604] CRSANR5L16S2024O1N087.xml...  343 lignes
# [548/604] CRSANR5L16S2023O1N008.xml...  586 lignes
# [549/604] CRSANR5L16S2024O1N050.xml...  885 lignes
# [550/604] CRSANR5L16S2024O1N044.xml...  653 lignes
# [551/604] CRSANR5L16S2024O1N078.xml...  720 lignes
# [552/604] CRSANR5L16S2024O1N079.xml...  1080 lignes
# [553/604] CRSANR5L16S2024O1N045.xml...  462 lignes
# [554/604] CRSANR5L16S2024O1N051.xml...  584 lignes
# [555/604] CRSANR5L16S2023O1N009.xml...  230 lignes
# [556/604] CRSANR5L16S2024O1N086.xml...  152 lignes
# [557/604] CRSANR5L16S2023O1N021.xml...  330 lignes
# [558/604] CRSANR5L16S2023O1N035.xml...  664 lignes
# [559/604] CRSANR5L16S2024O1N092.xml...  758 lignes
# [560/604] CRSANR5L16S2023O1N223.xml...  1001 lignes
# [561/604] CRSANR5L16S2023O1N237.xml...  503 lignes
# [562/604] CRSANR5L16S2024O1N119.xml...  569 lignes
# [563/604] CRSANR5L16S2023O1N196.xml...  1010 lignes
# [564/604] CRSANR5L16S2024O1N131.xml...  409 lignes
# [565/604] CRSANR5L16S2024O1N125.xml...  116 lignes
# [566/604] CRSANR5L16S2023E1N022.xml...  717 lignes
# [567/604] CRSANR5L16S2023O1N182.xml...  611 lignes
# [568/604] CRSANR5L16S2023O1N169.xml...  851 lignes
# [569/604] CRSANR5L16S2023O1N155.xml...  1026 lignes
# [570/604] CRSANR5L16S2023O1N141.xml...  909 lignes
# [571/604] CRSANR5L16S2023O1N157.xml...  97 lignes
# [572/604] CRSANR5L16S2023O1N143.xml...  498 lignes
# [573/604] CRSANR5L16S2024O1N133.xml...  351 lignes
# [574/604] CRSANR5L16S2023O1N194.xml...  813 lignes
# [575/604] CRSANR5L16S2023O1N180.xml...  651 lignes
# [576/604] CRSANR5L16S2023E1N020.xml...  712 lignes
# [577/604] CRSANR5L16S2024O1N127.xml...  680 lignes
# [578/604] CRSANR5L16S2023E1N008.xml...  858 lignes
# [579/604] CRSANR5L16S2023O1N221.xml...  382 lignes
# [580/604] CRSANR5L16S2023O1N235.xml...  503 lignes
# [581/604] CRSANR5L16S2023O1N209.xml...  190 lignes
# [582/604] CRSANR5L16S2023O1N023.xml...  403 lignes
# [583/604] CRSANR5L16S2024O1N084.xml...  189 lignes
# [584/604] CRSANR5L16S2024O1N090.xml...  274 lignes
# [585/604] CRSANR5L16S2023O1N037.xml...  564 lignes
# [586/604] CRSANR5L16S2024O1N047.xml...  343 lignes
# [587/604] CRSANR5L16S2024O1N053.xml...  388 lignes
# [588/604] CRSANR5L16S2024O1N052.xml...  622 lignes
# [589/604] CRSANR5L16S2024O1N046.xml...  974 lignes
# [590/604] CRSANR5L16S2023O1N036.xml...  987 lignes
# [591/604] CRSANR5L16S2024O1N091.xml...  362 lignes
# [592/604] CRSANR5L16S2024O1N085.xml...  109 lignes
# [593/604] CRSANR5L16S2023O1N022.xml...  681 lignes
# [594/604] CRSANR5L16S2023O1N208.xml...  626 lignes
# [595/604] CRSANR5L16S2023O1N234.xml...  901 lignes
# [596/604] CRSANR5L16S2023O1N220.xml...  517 lignes
# [597/604] CRSANR5L16S2023E1N009.xml...  475 lignes
# [598/604] CRSANR5L16S2024O1N126.xml...  222 lignes
# [599/604] CRSANR5L16S2023E1N021.xml...  528 lignes
# [600/604] CRSANR5L16S2023O1N181.xml...  586 lignes
# [601/604] CRSANR5L16S2023O1N195.xml...  259 lignes
# [602/604] CRSANR5L16S2024O1N132.xml...  567 lignes
# [603/604] CRSANR5L16S2023O1N142.xml...  243 lignes
# [604/604] CRSANR5L16S2023O1N156.xml...  208 lignes
#
#  Export terminé : 336817 lignes consolidées
#
#  Export CSV : (336817 lignes)

# %% [markdown]
# ## Étape 2 : Fusionner données députés pour chaque législature
#
# 1 député = 1 ID qui ne change pas à travers le temps. ==> ce qui signifie que dans l’idéal il faudrait avoir les données complètes (avec affiliation partisane, etc) par législature et faire la fusion député/compte-rendus avant la fusion entre les 2 législatures.
#
# En attendant, possible de lancer les analyses et de recouper en 2 le fichier pour ajouter les députés avant de fusionner à nouveau ensuite

# %% [markdown]
# ### Quelles options possibles et disponibles ?
#
#
# #### L'option de base lacunaire : les informations d'état civique donné par l'AN
#
# Jeu de données en open acces disponible sur le site open data de l'Assemblée nationale avec État civil des personnes qui sont ou qui ont été députés, sénateurs et ministres (précisant pour ces derniers l'intitulé de leur ministère)
# --> **Gros soucis puisque ne contient par leur affiliation politique**
# - https://data.assemblee-nationale.fr/archives-anterieures/archives-15e/deputes-senateurs-et-ministres
# - https://data.assemblee-nationale.fr/archives-16e/deputes-senateurs-ministres
# --> dispo en json ou xml
#
# En théorie, il serait possible de retravailler nous-même ce fichier en le combinant avec d'autres pour avoir leur affiliation politique. En pratique, a déjà été réalisé par d'autres.
#
#
# #### L'option la plus facile/accessible et moins couteuse dans un premier temps : la base de données de DATAN
#
# Ce travail de fusion des données ouvertes de l'AN a été réalisé par Awenig Marié (post-doc au social media lab au CEVIPOl de l'ULB à Bruxelle, contact awenig.marie@ulb.be) via le site/outil DATAN (initiative aux frontières de l'académique avec un conseil scientifique présidé par Olivier Costa, et présence notamment de Isabelle Guinaudeau et Olivier Rozenberg). Les contacter via info[at]datan.fr
#
# Ce site/outil DATAN propose en open data (sur leur site et sur data.gouv) des informations et statistiques sur les groupes parlementaires et les députés. Il met notamment à disposition un jeu de données en .CSV qui présente tous les députés de l'Assemblée nationale française depuis la 12ème législature (2002) avec notamment leur historique parlementaire et leur actuel groupe politique.
#
# Les variables sont les suivantes :
#
# - id : id présente sur le site de l'Assemblée
# - legislatureLast : dernière législature où le député a eu un mandat
# - civ : genre du député
# - nom
# - prenom
# - villeNaissance : ville de naissance
# - naissance : date de naissance
# - age
# - groupe : actuel groupe parlementaire
# - groupeAbrev : abréviation du groupe
# - departementNom : nom du département dans lequel le député a été élu
# - departementCode : code du département dans lequel le député a été élu
# - circo : numéro de sa circonscription
# - datePriseFonction : date à laquelle il a pris fonction lors de la législature actuelle
# - job
# - mail
# - twitter
# - facebook
# - website
# - nombreMandats: le nombre de mandats parlementaires exercé par le député
# - experienceDepute : expérience parlementaire (en jours, mois ou années)
# - scoreParticipation : le score participation correspond au pourcentage de scrutins auquel le député a pris part en séance publique
# - scoreParticipationSpectialite : le score de participation "spécialité" correspond au pourcentage de scrutins auquel le député a pris part en séance publique et qui sont reliés à un texte législatif examiné dans la commission parlementaire du député, et donc pour lequel le député a un intérêt ou une expertise
# - scoreLoyaute : le score de loyauté correspond au pourcentage de scrutins pour lequel le député a voté sur la même ligne que son groupe parlementaire
# - scoreMajorite : le score de proximité avec la majorité présidentielle correspond au pourcentage de scrutins pour lequel le député a voté sur la même ligne que le groupe de la majorité présidentielle
# - active : "1" si le député est encore actif
# - dateMaj : dernière date de mise à jour du jeu de données
#
# ==> Awenig Marié a été contacté et devrait prochainement transmettre un fichier CSV par législature étudiée (15e et 16e) avec les variables suivantes
#
# À compléter une fois données récupérées
#
# https://datan.fr/deputes/legislature-15
# https://datan.fr/deputes/legislature-16
#
#
# #### Les critiques faites aux données de l'AN
#
# Critiques récurrentes dans les travaux de Boelaert, Michon et Ollion, sur l’usage habituel des données de l’AN pour étudier les députés. Il s’agit de **données auto-déclaratives sujettes à la mal-déclaration, aux stratégies de présentations de soi** (mettre en avant une profession ou expérience que l’on juge plus valorisante), et à une inadéquation des catégories et données à remplir (: exemple de la profession d’origine qui ne prend pas en compte le temps passé en politique depuis).
#
#
# #### Les alternatives à considérer pour plus tard
#
# 1. Demander le jeu de données constitué par l'équipe autour de Ollion, Michon et Boelaert
#     - Systématisation d'une collecte documentaire visant à noter chaque profession occupée par les députés à partir de leurs 25 ans via les articles de presse locale, dictionnaires biographiques (lesbiographies.com et Who’s Who in France), pages Wikipédia, professions de foi, présentations de soi sur les sites et réseaux sociaux des candidats, curriculum vitae disponibles en ligne, bases de données du ministère de l’Intérieur, et données de la HATVP
# 2. Constituer un jeu de données propre avec notamment les données de la HATVP ([lien](https://www.hatvp.fr/consulter-les-declarations/)) et d'autres données à réfléchir comme le RNE (https://www.data.gouv.fr/datasets/repertoire-national-des-elus-1/)
#
# Dans tous les cas, prendre en compte les critiques sur ces bases de données et les catégories qu'ils ont mobilisés. Mais se souvenir aussi de ce qui nous intéresse ici (pas forcément les professions auto-déclarées mais les affiliations partisanes, et les contextes et manières d'utilliser la "République")

# %% [markdown]
# ### Join deputy dataset with CRS dataset

# %%
# Stabiliser le ID_orateur pour etre au format AN (et pouvoir matcher données)

import pandas as pd

df = pd.read_csv(
    "à compléter", low_memory=False, dtype={"ID_orateur": str} #à compléter = emplacement fichier par législature ou brut
)
df.shape

df["ID_orateur"] = "PA" + df["ID_orateur"]

# %%
# Importer maintenant le fichier des données sur les députés à joindre
df_deputes = pd.read_csv(".../deputes-historique(datan-datagouv).csv")

# %%
# shape avant fusion
df.shape

# %%
# Join des données sur la base de l'id des intervenants
df = df.join(df_deputes.set_index("id"), on="ID_orateur", how="left", rsuffix="_dep")

# %%
# shape après fusion
df.shape

# %%
# certaines col du join introduisent une erreur à l'import/export
# forcer le QUOTE_ALL permet de résoudre

import csv  # pour résoudre le soucis d'écart. Checker

df.to_csv(
    "../data/interim/data_cleaning.csv",
    index=False,
    quoting=csv.QUOTE_ALL,  # a permis de résoudre le soucis d'écart. Checker
)

# %%
# verif excriture/lecture ok
df_test = pd.read_csv(
    "../data/interim/data_cleaning.csv", low_memory=False, dtype={"ID_orateur": str}
)
df_test.shape

# %% [markdown]
# ## Étape 3 : fusionner les deux fichiers CSV
#
# ### Attention aux différences :
#
# La présence en métadonnées de références "Sessionref" et "Séanceref" n'apparait qu'à la XVIe législature mais absent dans la 15e. Ne pose pas de soucis dans la mesure ou c'est présent sous une forme écrite "Session"/"Séance" pour les 2.
# *Pose la question de si pertinent de garder "Sessionref" et "Séanceref" ou si on les nettoie ?*
#
# Absence aussi de Stime...mais pareil pas important.

# %%
import pandas as pd

# Étape 1 : lire les deux fichiers CSV
fichier1 = '/Users/matthiaslevalet/Desktop/Projet de recherche/CSS_République/Data/Interim/Data_AN_15e.csv'
fichier2 = '/Users/matthiaslevalet/Desktop/Projet de recherche/CSS_République/Data/Interim/Data_AN_16e.csv'

df1 = pd.read_csv(fichier1)
df2 = pd.read_csv(fichier2)

# Étape 2 : fusionner les deux fichiers
df_fusion = pd.concat([df1, df2], ignore_index=True)

# Étape 3 : supprimer les doublons
    # On peut préciser des colonnes clés si on veut plus de précision
df_fusion = df_fusion.drop_duplicates()

# Étape 4 : (optionnelle) trier les données par date ou autre champ pertinent
if 'dateSeance' in df_fusion.columns:
    df_fusion['dateSeance'] = pd.to_datetime(df_fusion['dateSeance'], errors='coerce')
    df_fusion = df_fusion.sort_values(by='dateSeance')

# Étape 5 : sauvegarder le résultat
df_fusion.to_csv('/Users/matthiaslevalet/Desktop/Projet de recherche/CSS_République/Data/Interim/Data_AN_CSS.csv', index=False, encoding='utf-8')

print("Fusion terminée : fichier sauvegardé sous 'Data_AN_CSS.csv'")
# Out:
# Fusion terminée : fichier sauvegardé sous 'Data_AN_CSS.csv'

# %% [markdown]
# ### Checker les différences entre les 2 fichiers optenus (fusion de tous les xml d'un coup ou des 2 CSV après-coup)
#
# Différents test (difflib echec) et les 2 fichiers sembles similaires en tout point ! Dans tous les cas, il existe une version séparée avec exactement la même extraction pour chaque législature au cas où pour appliquer des analyses spécifiques à chaque législature.

# %%
import pandas as pd

df = pd.read_csv(
    "/Users/matthiaslevalet/Desktop/Projet de recherche/CSS_République/Data/Interim/Data_AN_CSS.csv", low_memory=False, dtype={"ID_orateur": str}
)
df.shape
# Out:
# (1128128, 27)

# %%
df.groupby("session", dropna=False)["UID"].describe()
# Out:
#                                          count unique  \
# session
# Congrès du Parlement du 3 juillet 2017      86      2
# Congrès du Parlement du 4 mars 2024         77      1
# Congrès du Parlement du 9 juillet 2018     127      1
# Deuxième session extraordinaire 2017      5240      8
# Deuxième session extraordinaire 2018     12560     23
# Deuxième session extraordinaire 2019      8582     18
# Deuxième session extraordinaire 2020      9468     18
# Deuxième session extraordinaire 2021       650      1
# Deuxième session extraordinaire 2023      7961     12
# Première session extraordinaire 2017     18580     33
# Première session extraordinaire 2018     24815     44
# Première session extraordinaire 2019      8675     21
# Première session extraordinaire 2020     16865     30
# Première session extraordinaire 2021     10685     20
# Première session extraordinaire 2022     18902     32
# Première session extraordinaire 2023     22029     29
# Session ordinaire 2016-2017                149      2
# Session ordinaire 2017-2018             152383    289
# Session ordinaire 2018-2019             154377    296
# Session ordinaire 2021-2022              74175    170
# Session ordinaire 2022-2023             164019    293
# Session ordinaire 2023-2024             123770    235
# Troisième session extraordinaire 2021     3827      9
# session ordinaire 2019-2020             129477    254
# session ordinaire 2020-2021             160649    325
#
#                                                             top  freq
# session
# Congrès du Parlement du 3 juillet 2017    CRSANR5L15S2017O1N001    43
# Congrès du Parlement du 4 mars 2024       CRSCGR5L16S2024O1N001    77
# Congrès du Parlement du 9 juillet 2018  CRSJOCGR5L15S2018E1N001   127
# Deuxième session extraordinaire 2017      CRSANR5L15S2017E2N008   940
# Deuxième session extraordinaire 2018      CRSANR5L15S2018E2N008  1058
# Deuxième session extraordinaire 2019      CRSANR5L15S2019E2N017   756
# Deuxième session extraordinaire 2020      CRSANR5L15S2020E2N011   919
# Deuxième session extraordinaire 2021      CRSANR5L15S2021E2N001   650
# Deuxième session extraordinaire 2023      CRSANR5L16S2023E2N011   993
# Première session extraordinaire 2017      CRSANR5L15S2017E1N028  1188
# Première session extraordinaire 2018      CRSANR5L15S2018E1N034  1054
# Première session extraordinaire 2019      CRSANR5L15S2019E1N015   912
# Première session extraordinaire 2020      CRSANR5L15S2020E1N011  1043
# Première session extraordinaire 2021      CRSANR5L15S2021E1N018  1640
# Première session extraordinaire 2022      CRSANR5L16S2022E1N015  1324
# Première session extraordinaire 2023      CRSANR5L16S2023E1N017  1286
# Session ordinaire 2016-2017               CRSANR5L15S2017O1N125   123
# Session ordinaire 2017-2018               CRSANR5L15S2018O1N206  1833
# Session ordinaire 2018-2019               CRSANR5L15S2019O1N111  2079
# Session ordinaire 2021-2022               CRSANR5L15S2022O1N125  1294
# Session ordinaire 2022-2023               CRSANR5L16S2023O1N062  1422
# Session ordinaire 2023-2024               CRSANR5L16S2024O1N137  1278
# Troisième session extraordinaire 2021     CRSANR5L15S2021E3N003   843
# session ordinaire 2019-2020               CRSANR5L15S2020O1N108  1356
# session ordinaire 2020-2021               CRSANR5L15S2021O1N089  1892
