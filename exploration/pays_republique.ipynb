# %% [markdown]
# # Liste des pays à exclure

# %%
# voir ici : https://www.legifrance.gouv.fr/jorf/id/JORFTEXT000019509867

## ATTENTION ICI LISTE PLUS COMPLÈTE AVEC AUSSI LA FORME ADJECTIVALE !!!
liste_full = """
NOM DE L'ÉTAT
forme courte	
NOM DE L'ÉTAT
forme longue	
NOM DES HABITANTS	
CAPITALE,
SIÈGES DIPLOMATIQUES
OU CONSULAIRES

Afghanistan (l') (m.).	
la République islamique d'Afghanistan	
la République islamique d’Afghanistan
la République islamique Afghane	
Kaboul.

Afrique du Sud (l') (f.).	
la République d'Afrique du Sud	
la République d’Afrique du Sud
la République Sudafricaine	
Prétoria.
Le Cap.
Johannesburg.

Albanie (l') (f.).	
la République d'Albanie	
la République d’Albanie
la République Albanaise	
Tirana.

Algérie (l') (f.).	
la République algérienne démocratique et populaire	
la République Algérienne	
Alger.
Annaba.
Oran.

Allemagne (l') (f.).	
la République fédérale d'Allemagne	
la République fédérale d’Allemagne	
la République fédérale Allemande	
Berlin.
Düsseldorf.
Francfort-sur-le-Main.
Hambourg.
Munich.
Sarrebruck.
Stuttgart.

Andorre (l') (f.).	
la Principauté d'Andorre.	
Andorran, -e.	
Andorre-la-Vieille.

Angola (l') (m.).	
la République d'Angola
la République Angolaise	
Luanda.

Antigua-et-Barbuda (f.).	
Antigua-et-Barbuda.	
Antiguayen, -ne.	
Saint John's.

Arabie saoudite (l') (f.).	
le Royaume d'Arabie saoudite	
Saoudien, -ne.	
Riyad.
Djedda.

Argentine (l') (f.).	
la République argentine	
Argentin, -e.	
Buenos Aires.

Arménie (l') (f.).	
la République d'Arménie
la République d’Arménie	
la République Arménienne.	
Erevan.

Australie (l') (f.).	
le Commonwealth d'Australie.	
Australien, -ne.	
Canberra.
Sydney.

Autriche (l') (f.).	
la République d'Autriche	
la République d’Autriche	
la République Autrichienne.	
Vienne.

Azerbaïdjan (l') (m.).	
la République d'Azerbaïdjan	
la République Azerbaïdjanaise	
Bakou.

Bahamas (les) (f.).	
le Commonwealth des Bahamas.	
Bahaméen, -ne.	
Nassau.

Bahreïn (m.).	
le Royaume de Bahreïn.	
Bahreïnien, -ne.	
Manama.

Bangladesh (le).	
la République populaire du Bangladesh	
la République populaire Bangladaise
Bangladais, -e.	
Dacca.

Barbade (la).	
la Barbade.	
Barbadien, -ne.	
Bridgetown.

Belgique (la).	
le Royaume de Belgique.	
Belge.	
Bruxelles.
Anvers.
Liège.

Bélize (le).	
le Bélize.	
Bélizien, -ne.	
Belmopan.

Bénin (le).	
la République du Bénin	
la République Béninoise
Béninois, -e.	
Porto-Novo.
Cotonou.

Bhoutan (le).	
le Royaume du Bhoutan.	
Bhoutanais, -e.	
Thimphou.

Biélorussie (la).	
la République de Biélorussie	
la République Biélorusse	
Minsk.

Birmanie (la).	
l'Union de Birmanie.	
Birman, -e.	
Rangoun.

Bolivie (la).	
la République de Bolivie	
la République Bolivienne	
Sucre.
Jamaïcain, -e.	
Kingston.

Japon (le).	
le Japon.	
Japonais, -e.	
Tokyo.
Osaka.
Kobé.

Jordanie (la).	
le Royaume hachémite de Jordanie.	
Jordanien, -ne.	
Amman.

Kazakhstan (le).	
la République du Kazakhstan	
la République Kazakhstanaise	
la République Kazakh
Astana.
Almaty.

Kenya (le).	
la République du Kenya	
la République Kényane	
Nairobi.

Kirghizstan (le).	
la République kirghize	
Bichkek.

Kiribati (les) (f.).	
la République des Kiribati	
la République Kiribatienne	
Bairiki (Tarawa).

Kosovo (le).	
la République du Kosovo	
la République Kosovare	
Pristina.

Koweït (le).	
l'État du Koweït.	
Koweïtien, -ne.	
Koweït.

Laos (le).	
la République démocratique populaire lao	
la République démocratique populaire Laotienne
la République Laotienne	
Vientiane.

Lesotho (le).	
le Royaume du Lesotho.	
Lesothien, -ne.	
Maseru.

Lettonie (la).	
la République de Lettonie	
la République Lettonne	
Riga.

Liban (le).	
la République libanaise	
Libanais, -e.	
Beyrouth.

Libéria (le).	
la République du Libéria	
la République Libérienne	
Monrovia.

Libye (la).	
la Grande Jamahiriya arabe libyenne populaire et socialiste.	
Libyen, -ne.	
Tripoli.

Liechtenstein (le).	
la Principauté du Liechtenstein	
Liechtensteinois, -e.	
Vaduz.

Lituanie (la).	
la République de Lituanie	
la République Lituanienne	
Vilnius.

Luxembourg (le).	
le Grand-Duché de Luxembourg.	
Luxembourgeois, -e.	
Luxembourg.

Macédoine (l'Ancienne République yougoslave de) ou ARYM (l') (f.).	
l'Ancienne République yougoslave de Macédoine ou l'ARYM.	
Macédonien, -ne.	
Skopje.

Madagascar (f.).	
la République de Madagascar	
la République Malgache	
Antananarivo ou Tananarive.
Antsiranana ou Diégo-Suarez.
Mahajanga ou Majunga.
Toamasina ou Tamatave.

Malaisie (la).	
la Malaisie.	
Malaisien, -ne.	
Kuala Lumpur.

Malawi (le).	
la République du Malawi	
la République Malawite
Lilongwé.

Maldives (les) (f.).	
la République des Maldives
la République Maldivienne	
Malé.

Mali (le).	
la République du Mali	
la République Malienne	
Bamako.

Malte (f.).	
la République de Malte	
la République Maltaise	
La Valette.

Maroc (le).	
le Royaume du Maroc.	
Marocain, -e.	
Rabat.
Agadir.
Casablanca.
Fès.
Marrakech.
Tanger.

Marshall (les) (f.).	
la République des Îles Marshall	
la République Marshallaise
Delap-Uliga-Darrit (Majuro).

Maurice (f.).	
la République de Maurice	
la République Mauricienne	
Port-Louis.

Mauritanie (la).	
la République islamique de Mauritanie	
la République Mauritanienne	
Nouakchott.

Mexique (le).	
les États-Unis du Mexique.	
Mexicain, -e.	
Mexico.

Micronésie (la).	
les États fédérés de Micronésie.	
Micronésien, -ne.	
Palikir.

Moldavie (la).	
la République de Moldavie	
la République Moldave	
Chisinau.

Monaco (m.).	
la Principauté de Monaco.	
Monégasque.	
Monaco.

Mongolie (la).	
la Mongolie.	
Mongol, -e.	
Oulan-Bator.

Monténégro (le).	
le Monténégro.	
Monténégrin, -e.	
Podgorica.

Mozambique (le).	
la République du Mozambique	
la République Mozambicaine	
Maputo.

Namibie (la).	
la République de Namibie	
la République Namibienne	
Windhoek.

Nauru (f.).	
la République de Nauru	
la République Nauruane	
Yaren.

Népal (le).	
le Royaume du Népal.	
Népalais, -e.	
Katmandou.

Nicaragua (le).	
la République du Nicaragua	
la République Nicaraguayenne	
Managua.

Niger (le).	
la République du Niger	
la République Nigérienne	
Niamey.

Nigéria (le).	
la République fédérale du Nigéria	
la République fédérale Nigériane
la République Nigériane	
Abuja.
Lagos.

Norvège (la).	
le Royaume de Norvège.	
Norvégien, -ne.	
Oslo.

Nouvelle-Zélande (la).	
la Nouvelle-Zélande.	
Néozélandais, -e.	
Wellington.

Oman (m.).	
le Sultanat d'Oman.	
Omanais, -e.	
Mascate.

Ouganda (l') (m.).	
la République d'Ouganda	
la République d’Ouganda	
la République Ougandaise	
Kampala.

Ouzbékistan (l') (m.).	
la République d'Ouzbékistan
la République d’Ouzbékistan	
la République Ouzbekèke	
Tachkent.

Pakistan (le).	
la République islamique du Pakistan	
la République islamique Pakistanaise
la République Pakistanaise	
Islamabad.
Karachi.

Palaos (les) (f.).	
la République des Palaos	
la République Palaoise
Melekeok.

Panama (le).	
la République du Panama	
la République Panaméenne	
Panama.

Papouasie-Nouvelle-Guinée (la).	
la Papouasie-Nouvelle-Guinée.	
Papouasien, -ne.	
Port Moresby.

Paraguay (le).	
la République du Paraguay	
la République Paraguayenne	
Asuncion ou Assomption.

Pays-Bas (les).	
le Royaume des Pays-Bas.	
Néerlandais, -e.	
Amsterdam.
La Haye.

Pérou (le).	
la République du Pérou
la République Péruvienne	
Lima.

Philippines (les) (f.).	
la République des Philippines	
la République Philippine	
Manille.

Pologne (la).	
la République de Pologne	
la République Polonaise	
Varsovie.
Cracovie.

Portugal (le).	
la République portugaise	
la République Portugaise	
Lisbonne.
Porto.

Qatar (le).	
l'État du Qatar.	
Qatarien, -ne.	
Doha.

Roumanie (la).	
la Roumanie.	
Roumain, -e.	
Bucarest.

Royaume-Uni (le).	
le Royaume-Uni de Grande-Bretagne et d'Irlande du Nord.	
Britannique.	
Londres.
Édimbourg.
Glasgow.
Gibraltar.

Russie (la).	
la Fédération de Russie.	
Russe.	
Moscou.
Ekaterinbourg ou Iekaterinbourg.
Saint-Pétersbourg.

Rwanda (le).	
la République du Rwanda	
la République Rwandaise	
Kigali.

Saint-Christophe-et-Niévès (f.).	
la Fédération de Saint-Christophe-et-Niévès.	
Christophien, -ne.	
Basseterre.

Sainte-Lucie (f.).	
Sainte-Lucie.	
Lucien, -ne.	
Castries.

Saint-Marin (m.).	
la République de Saint-Marin	
la République Saint-Marinaise	
Saint-Marin.

Saint-Siège (le) ou Vatican (le).	
l'État de la Cité du Vatican.	
 	
 

Saint-Vincent-et-les-Grenadines (f.).	
Saint-Vincent-et-les-Grenadines.	
Vincentais, -e.	
Kingstown.

Salomon (les) (f.).	
les Îles Salomon.	
Salomonais, -e.	
Honiara.

Salvador (le).	
la République du Salvador	
la République Salvadorienne	
San Salvador.

Samoa (les) (f.).	
l'État indépendant des Samoa.	
Samoen, -ne.	
Apia.

Sao Tomé-et-Principe (m.).	
la République démocratique de Sao Tomé-et-Principe	
la République démocratique Santoméenne
la République Santoméenne	
Sao Tomé.

Sénégal (le).	
la République du Sénégal	
la République Sénégalaise	
Dakar.
Saint-Louis.

Serbie (la).	
la République de Serbie	
la République Serbe	
Belgrade.

Seychelles (les) (f.).	
la République des Seychelles	
la République Seychelloise
Victoria.

Sierra Leone (la).	
la République de Sierra Leone	
la République Sierraléonaise	
Freetown.

Singapour (f.).	
la République de Singapour	
la République Singapourienne	
Singapour.

Slovaquie (la).	
la République slovaque
la République Slovaque	
Bratislava.

Slovénie (la).	
la République de Slovénie	
la République Slovène	
Ljubljana.

Somalie (la).	
la Somalie.	
Somalien, -ne.	
Mogadiscio.

Soudan (le).	
la République du Soudan	
la République Soudanaise	
Khartoum.
Juba ou Djouba.

Sri Lanka (le).	
la République démocratique socialiste du Sri Lanka	
la République démocratique socialiste Srilankaise
la République Srilankaise	
Sri Jayewardenepura Kotte.
Colombo.

Suède (la).	
le Royaume de Suède.	
Suédois, -e.	
Stockholm.

Suisse (la).	
la Confédération suisse.	
Suisse, -esse.	
Berne.
Genève.
Lausanne.
Zurich.

Suriname (le).	
la République du Suriname	
la République Surinamienne	
Paramaribo.

Swaziland (le).	
le Royaume du Swaziland.	
Swazi, -e.	
Mbabané.
Lobamba.

Syrie (la).	
la République arabe syrienne	
la République Syrienne.
Damas.
Alep.

Tadjikistan (le).	
la République du Tadjikistan	
la République Tadjike
Douchanbé.

Tanzanie (la).	
la République unie de Tanzanie	
la République Tanzanienne.
Dodoma.
Dar es Salam.

Tchad (le).	
la République du Tchad
la République Tchadienne
Ndjamena.

Tchèque (la République).	
la République tchèque	
Tchèque.	
Prague.

Thaïlande (la).	
le Royaume de Thaïlande.	
Thaïlandais, -e.	
Bangkok.

Timor oriental (le).	
la République démocratique du Timor oriental	
la République Timoraise
la République démocratique Timoraise
Dili.

Togo (le).	
la République togolaise
la République Togolaise	
Lomé.

Tonga (les) (f.).	
le Royaume des Tonga.	
Tongien, -ne.	
Nuku'alofa.

Trinité-et-Tobago (la).	
la République de Trinité-et-Tobago
la République Trinidadienne
Port of Spain ou Port d'Espagne.

Tunisie (la).	
la République tunisienne	
la République Tunisienne	
Tunis.
Sfax.

Turkménistan (le).	
le Turkménistan.	
Turkmène.	
Achgabat.

Turquie (la).	
la République de Turquie	
la République Turque	
Ankara.
Istamboul ou Istanbul.

Tuvalu (les) (f.).	
les Tuvalu.	
Tuvalais, -e.	
Vaiaku (Funafuti).

Ukraine (l') (f.).	
l'Ukraine.	
Ukrainien, -ne.	
Kiev.

Uruguay (l') (m.).	
la République orientale de l'Uruguay	
la République Uruguayenne	
Montévidéo.

Vanuatu (le).	
la République du Vanuatu
la République Vanouataise
Port-Vila.

Vénézuéla (le).	
la République bolivarienne du Vénézuéla	
la République Vénézuélienne.
Caracas.

Vietnam (le) ou Viêt Nam (le).	
la République socialiste du Vietnam ou la République socialiste du Viêt Nam	
la République Vietnamienne
Hanoï.
Hô Chi Minh-Ville.

Yémen (le).	
la République du Yémen
la République Yéménite	
Sanaa.

Zambie (la).	
la République de Zambie
la République Zambienne
Lusaka.

Zimbabwé (le).	
la République du Zimbabwé
la République Zimbabwéenne
"""

# %%
import re
import csv

# Extraire les lignes contenant "républi" (insensible à la casse)
pays_republi = [
    ligne for ligne in liste_full.splitlines() if re.search(r"républi", ligne, re.I)
]
# Supprimer également les terminaisons ".\t"
pays_republi = [re.sub(r"\.\t$", "", ligne) for ligne in pays_republi]
# Enlever aussi "la " en début de ligne (avec espace)
pays_republi = [re.sub(r"^la ", "", ligne, flags=re.I) for ligne in pays_republi]
pays_republi
# Uniformiser les ' 
pays_republi = [p.replace("’", "'") for p in pays_republi]
with open("/Users/matthiaslevalet/Desktop/Projet de recherche/CSS_République/Data/Interim/liste_pays_republique_sup.txt", "w", encoding="utf-8") as f:
    for pays in pays_republi:
        f.write(pays + "\n")

# %%
type(pays_republi)
# Out:
# list

# %%
len(pays_republi)
# Out:
# 131

# %%
with open("../data/interim/liste_pays_republique.txt", "w", encoding="utf-8") as f:
    for pays in pays_republi:
        f.write(pays + "\n")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 with open("../data/interim/liste_pays_republique.txt", "w", encoding="utf-8") as f:
#       2     for pays in pays_republi:
#       3         f.write(pays + "\n")
#
# File /opt/anaconda3/lib/python3.13/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/interim/liste_pays_republique.txt'

# %% [markdown]
# Annexe

# %%
# 2e option pays sur la base du nom des pays données par la diplomatie (en enlève 5 506, soit 34 de moins que la regex bourrin)

# https://www.diplomatie.gouv.fr/IMG/pdf/Index_alphabetique_des_pays.pdf

pattern_PAYS = re.compile (
    r"|(\bRépublique Centrafricaine\b)"
    r"|(\bRépublique démocratique du Congo\b)"
    r"|(\bRépublique du Congo\b)"
    r"|(\bRépublique Dominicaine\b)"
    r"|(\bRépublique yougoslave de Macédoine\b)"
    r"|(\brépublique de Moldavie\b)"
    r"|(\bRépublique Tchèque\b)"
    r"|(\bRépublique islamique d'Iran\b)"
    r"|(\bRépublique fédérale d'Allemagne\b)"
    r"|(\bRépublique fédérale allemande\b)"
    r"|(\bRépublique populaire de Chine\b)"
    r"|(\bRépublique populaire chinoise\b)"
    r"|(\bRépublique populaire démocratique de Corée\b)"
    r"|(\bRépublique de Corée\b)"
    r"|(\bRépublique d’Arménie\b)"
    r"|(\brépublique arménienne\b)"
    r"|(\bRépublique de Chypre\b)"
    r"|(\bRépublique chypriote\b)"
    r"|(\bRépublique d’Albanie\b)"
    r"|(\brépublique insulaire\b)" # pas sur, car utilisé pour chypre mais peut-être aussi plus largement ?
    r"|(\brépublique[s] soviétique[s]\b)"
    r"|(\brépublique de Moldavie\b)"
   
    
)
