# %% [markdown]
# # 1. Extraction des données (lxml)

# %% [markdown]
# Ce notebook extrait les paragraphes des comptes rendus de l’Assemblée nationale à partir des fichiers XML, en utilisant la bibliothèque lxml (qui a ici donné des résultats plus simples que la précédente version).

# %% [markdown]
# Sans doute moins robuste, moins de gestion des erreurs et exceptions, mais plus simple, lisible, et sans doute OK sur les données assemblée qui sont stables / propres.

# %%
# TODO: s'assurer que le passage vers lxml est ok

# %%
import os
import glob
from lxml import etree
import pandas as pd


def extraire_paragraphes_lxml(fichier_xml: str) -> pd.DataFrame:
    """
    Extrait les paragraphes d'un fichier XML de compte rendu en utilisant lxml.
    """
    try:
        tree = etree.parse(fichier_xml)
        root = tree.getroot()
        ns = {'ns': 'http://schemas.assemblee-nationale.fr/referentiel'}

        meta = {
            'UID': root.findtext('ns:uid', namespaces=ns),
            'SeanceRef': root.findtext('ns:seanceRef', namespaces=ns),
            'SessionRef': root.findtext('ns:sessionRef', namespaces=ns)
        }
        meta_tags = ['dateSeance', 'dateSeanceJour', 'numSeanceJour', 'numSeance', 'typeAssemblee',
                     'legislature', 'session', 'nomFichierJo']
        for tag in meta_tags:
            meta[tag] = root.findtext(f'.//ns:{tag}', namespaces=ns)

        meta['President'] = root.findtext('.//ns:presidentSeance', namespaces=ns)

        rows = []

        for para in root.xpath('.//ns:paragraphe', namespaces=ns):
            # Naviguer vers le <point> parent
            point = para.getparent()
            while point is not None and point.tag != f"{{{ns['ns']}}}point":
                point = point.getparent()

            point_id = point.get('id_syceron') if point is not None else None
            point_type = point.get('code_grammaire') if point is not None else None
            point_title = point.findtext('ns:texte', namespaces=ns) if point is not None else None
            valeur_odj = point.get('valeur_ptsodj') if point is not None else None

            texte_elem = para.find('ns:texte', namespaces=ns)
            texte = ''.join(texte_elem.itertext()).strip() if texte_elem is not None else None
            stime = texte_elem.get('stime') if texte_elem is not None else None

            orateur = para.find('.//ns:orateur', namespaces=ns)
            nom = orateur.findtext('ns:nom', namespaces=ns) if orateur is not None else None
            qualite = orateur.findtext('ns:qualite', namespaces=ns) if orateur is not None else None
            id_orateur = orateur.findtext('ns:id', namespaces=ns) if orateur is not None else None

            rows.append({
                'UID': meta['UID'],
                'SeanceRef': meta['SeanceRef'],
                'SessionRef': meta['SessionRef'],
                'DateSeance': meta['dateSeance'],
                'DateSeanceJour': meta['dateSeanceJour'],
                'NumSeanceJour': meta['numSeanceJour'],
                'NumSeance': meta['numSeance'],
                'TypeAssemblee': meta['typeAssemblee'],
                'Legislature': meta['legislature'],
                'Session': meta['session'],
                'NomFichierJO': meta['nomFichierJo'],
                'President': meta['President'],
                'Titre_general': point_title,
                # 'Sous_titre': '',  # not in this version, get back to original if needed
                # 'Contexte_hierarchique': '',  # not in this version, get back to original if needed
                # 'Section_courante': '',  # not in this version, get back to original if needed
                # 'Sujet_point': '', # not in this version, get back to original if needed
                'Valeur_ODJ': valeur_odj,
                'Point_ID': point_id,
                'Point_type': point_type,
                'ID_paragraphe': para.get('id_syceron'),
                'Ordre_seance': para.get('ordre_absolu_seance'),
                'Code_grammaire': para.get('code_grammaire'),
                'Code_style': para.get('code_style'),
                'Code_parole': para.get('code_parole'),
                'Role_debat': para.get('roledebat'),
                'Nom_orateur': nom,
                'Qualite_orateur': qualite,
                'ID_orateur': id_orateur,
                'stime': stime,
                'Texte': texte
            })

        return pd.DataFrame(rows)

    except Exception as e:
        print(f"❌ Erreur dans {fichier_xml} : {e}")
        return pd.DataFrame()


def traiter_dossier_compte_rendu_lxml(dossier_path: str, pattern: str = "*.xml") -> pd.DataFrame:
    """
    Traite tous les fichiers XML d'un dossier avec la fonction extraire_paragraphes_lxml().
    """
    fichiers = glob.glob(os.path.join(dossier_path, pattern))
    if not fichiers:
        print(f"❌ Aucun fichier XML trouvé dans {dossier_path}")
        return pd.DataFrame()

    all_dfs = []
    total = len(fichiers)
    print(f"🔄 Traitement de {total} fichiers XML...\n")

    for i, fichier in enumerate(fichiers, 1):
        nom = os.path.basename(fichier)
        print(f"[{i}/{total}] 📄 {nom}...", end=" ")

        df = extraire_paragraphes_lxml(fichier)
        if not df.empty:
            print(f"✅ {len(df)} lignes")
            all_dfs.append(df)
        else:
            print("⚠️ Vide ou erreur")

    if all_dfs:
        df_final = pd.concat(all_dfs, ignore_index=True)
        print(f"\n✅ Export terminé : {len(df_final)} lignes consolidées")
        return df_final
    else:
        return pd.DataFrame()


# # Exemple d'utilisation :
# if __name__ == "__main__":
#     dossier = "../data/raw/16-xml/compteRendu/"
#     df = traiter_dossier_compte_rendu_lxml(dossier)
#     df.to_csv("assemblee_extrait_lxml.csv", index=False, encoding='utf-8')
#     print(f"\n✅ Export CSV : ({df.shape[0]} lignes)"))

# %%
df = traiter_dossier_compte_rendu_lxml("../data/raw/16-xml/compteRendu/")
df.to_csv("../data/interim/extract_16.csv", index=False, encoding='utf-8')
print(f"\n✅ Export CSV : ({df.shape[0]} lignes)")
# Out:
# 🔄 Traitement de 605 fichiers XML...
#
# [1/605] 📄 CRSANR5L16S2023O1N173.xml... ✅ 633 lignes
# [2/605] 📄 CRSANR5L16S2023O1N167.xml... ✅ 467 lignes
# [3/605] 📄 CRSANR5L16S2023O1N198.xml... ✅ 402 lignes
# [4/605] 📄 CRSANR5L16S2023E1N010.xml... ✅ 818 lignes
# [5/605] 📄 CRSANR5L16S2024O1N117.xml... ✅ 678 lignes
# [6/605] 📄 CRSANR5L16S2024O1N103.xml... ✅ 857 lignes
# [7/605] 📄 CRSANR5L16S2023E1N004.xml... ✅ 646 lignes
# [8/605] 📄 CRSANR5L16S2023O1N239.xml... ✅ 452 lignes
# [9/605] 📄 CRSANR5L16S2023O1N205.xml... ✅ 118 lignes
# [10/605] 📄 CRSANR5L16S2023O1N211.xml... ✅ 296 lignes
# [11/605] 📄 CRSANR5L16S2024O1N088.xml... ✅ 403 lignes
# [12/605] 📄 CRSANR5L16S2023O1N007.xml... ✅ 535 lignes
# [13/605] 📄 CRSANR5L16S2023O1N013.xml... ✅ 808 lignes
# [14/605] 📄 CRSANR5L16S2024O1N063.xml... ✅ 106 lignes
# [15/605] 📄 CRSANR5L16S2024O1N077.xml... ✅ 760 lignes
# [16/605] 📄 CRSANR5L16S2024O1N076.xml... ✅ 834 lignes
# [17/605] 📄 CRSANR5L16S2024O1N062.xml... ✅ 322 lignes
# [18/605] 📄 CRSANR5L16S2023O1N012.xml... ✅ 688 lignes
# [19/605] 📄 CRSANR5L16S2023O1N006.xml... ✅ 430 lignes
# [20/605] 📄 CRSANR5L16S2024O1N089.xml... ✅ 541 lignes
# [21/605] 📄 CRSANR5L16S2023O1N210.xml... ✅ 625 lignes
# [22/605] 📄 CRSANR5L16S2023O1N204.xml... ✅ 737 lignes
# [23/605] 📄 CRSANR5L16S2023O1N238.xml... ✅ 373 lignes
# [24/605] 📄 CRSANR5L16S2023E1N005.xml... ✅ 609 lignes
# [25/605] 📄 CRSANR5L16S2024O1N102.xml... ✅ 207 lignes
# [26/605] 📄 CRSANR5L16S2024O1N116.xml... ✅ 343 lignes
# [27/605] 📄 CRSANR5L16S2023E1N011.xml... ✅ 432 lignes
# [28/605] 📄 CRSANR5L16S2023O1N199.xml... ✅ 723 lignes
# [29/605] 📄 CRSANR5L16S2023O1N166.xml... ✅ 285 lignes
# [30/605] 📄 CRSANR5L16S2023O1N172.xml... ✅ 426 lignes
# [31/605] 📄 CRSANR5L16S2023O1N158.xml... ✅ 181 lignes
# [32/605] 📄 CRSANR5L16S2023O1N164.xml... ✅ 545 lignes
# [33/605] 📄 CRSANR5L16S2023O1N170.xml... ✅ 526 lignes
# [34/605] 📄 CRSANR5L16S2024O1N128.xml... ✅ 399 lignes
# [35/605] 📄 CRSANR5L16S2024O1N100.xml... ✅ 434 lignes
# [36/605] 📄 CRSANR5L16S2023E1N007.xml... ✅ 904 lignes
# [37/605] 📄 CRSANR5L16S2023E1N013.xml... ✅ 626 lignes
# [38/605] 📄 CRSANR5L16S2024O1N114.xml... ✅ 797 lignes
# [39/605] 📄 CRSANR5L16S2023O1N212.xml... ✅ 684 lignes
# [40/605] 📄 CRSANR5L16S2023O1N206.xml... ✅ 686 lignes
# [41/605] 📄 CRSANR5L16S2023O1N038.xml... ✅ 455 lignes
# [42/605] 📄 CRSANR5L16S2023O1N010.xml... ✅ 528 lignes
# [43/605] 📄 CRSANR5L16S2023O1N004.xml... ✅ 462 lignes
# [44/605] 📄 CRSANR5L16S2024O1N048.xml... ✅ 424 lignes
# [45/605] 📄 CRSANR5L16S2024O1N074.xml... ✅ 246 lignes
# [46/605] 📄 CRSANR5L16S2024O1N060.xml... ✅ 330 lignes
# [47/605] 📄 CRSANR5L16S2024O1N061.xml... ✅ 721 lignes
# [48/605] 📄 CRSANR5L16S2024O1N075.xml... ✅ 791 lignes
# [49/605] 📄 CRSANR5L16S2024O1N049.xml... ✅ 208 lignes
# [50/605] 📄 CRSANR5L16S2023O1N005.xml... ✅ 971 lignes
# [51/605] 📄 CRSANR5L16S2023O1N011.xml... ✅ 243 lignes
# [52/605] 📄 CRSANR5L16S2023O1N039.xml... ✅ 641 lignes
# [53/605] 📄 CRSANR5L16S2023O1N207.xml... ✅ 808 lignes
# [54/605] 📄 CRSANR5L16S2023O1N213.xml... ✅ 375 lignes
# [55/605] 📄 CRSANR5L16S2024O1N115.xml... ✅ 300 lignes
# [56/605] 📄 CRSANR5L16S2023E1N012.xml... ✅ 1178 lignes
# [57/605] 📄 CRSANR5L16S2023E1N006.xml... ✅ 515 lignes
# [58/605] 📄 CRSANR5L16S2024O1N101.xml... ✅ 875 lignes
# [59/605] 📄 CRSANR5L16S2024O1N129.xml... ✅ 550 lignes
# [60/605] 📄 CRSANR5L16S2023O1N171.xml... ✅ 609 lignes
# [61/605] 📄 CRSANR5L16S2023O1N165.xml... ✅ 301 lignes
# [62/605] 📄 CRSANR5L16S2023O1N159.xml... ✅ 578 lignes
# [63/605] 📄 CRSANR5L16S2023O1N161.xml... ✅ 417 lignes
# [64/605] 📄 CRSANR5L16S2023O1N175.xml... ✅ 812 lignes
# [65/605] 📄 CRSANR5L16S2023O1N149.xml... ✅ 488 lignes
# [66/605] 📄 CRSANR5L16S2024O1N105.xml... ✅ 43 lignes
# [67/605] 📄 CRSANR5L16S2023E1N002.xml... ✅ 559 lignes
# [68/605] 📄 CRSANR5L16S2023E1N016.xml... ✅ 843 lignes
# [69/605] 📄 CRSANR5L16S2024O1N111.xml... ✅ 953 lignes
# [70/605] 📄 CRSANR5L16S2024O1N139.xml... ✅ 527 lignes
# [71/605] 📄 CRSANR5L16S2023O1N217.xml... ✅ 192 lignes
# [72/605] 📄 CRSANR5L16S2023O1N203.xml... ✅ 114 lignes
# [73/605] 📄 CRSANR5L16S2023O1N015.xml... ✅ 544 lignes
# [74/605] 📄 CRSANR5L16S2023O1N001.xml... ✅ 257 lignes
# [75/605] 📄 CRSANR5L16S2023O1N029.xml... ✅ 429 lignes
# [76/605] 📄 CRSANR5L16S2024O1N071.xml... ✅ 19 lignes
# [77/605] 📄 CRSANR5L16S2024O1N065.xml... ✅ 607 lignes
# [78/605] 📄 CRSANR5L16S2024O1N059.xml... ✅ 664 lignes
# [79/605] 📄 CRSANR5L16S2024O1N058.xml... ✅ 774 lignes
# [80/605] 📄 CRSANR5L16S2024O1N064.xml... ✅ 202 lignes
# [81/605] 📄 CRSANR5L16S2024O1N070.xml... ✅ 376 lignes
# [82/605] 📄 CRSANR5L16S2023O1N028.xml... ✅ 737 lignes
# [83/605] 📄 CRSANR5L16S2023O1N014.xml... ✅ 782 lignes
# [84/605] 📄 CRSANR5L16S2023O1N202.xml... ✅ 682 lignes
# [85/605] 📄 CRSANR5L16S2023O1N216.xml... ✅ 462 lignes
# [86/605] 📄 CRSANR5L16S2024O1N138.xml... ✅ 245 lignes
# [87/605] 📄 CRSANR5L16S2024O1N110.xml... ✅ 414 lignes
# [88/605] 📄 CRSANR5L16S2023E1N017.xml... ✅ 1286 lignes
# [89/605] 📄 CRSANR5L16S2023E1N003.xml... ✅ 1140 lignes
# [90/605] 📄 CRSANR5L16S2024O1N104.xml... ✅ 680 lignes
# [91/605] 📄 CRSANR5L16S2023O1N148.xml... ✅ 773 lignes
# [92/605] 📄 CRSANR5L16S2023O1N174.xml... ✅ 533 lignes
# [93/605] 📄 CRSANR5L16S2023O1N160.xml... ✅ 139 lignes
# [94/605] 📄 CRSANR5L16S2023O1N176.xml... ✅ 475 lignes
# [95/605] 📄 CRSANR5L16S2023O1N162.xml... ✅ 195 lignes
# [96/605] 📄 CRSANR5L16S2023E1N015.xml... ✅ 645 lignes
# [97/605] 📄 CRSANR5L16S2024O1N112.xml... ✅ 423 lignes
# [98/605] 📄 CRSANR5L16S2024O1N106.xml... ✅ 748 lignes
# [99/605] 📄 CRSANR5L16S2023E1N001.xml... ✅ 553 lignes
# [100/605] 📄 CRSANR5L16S2023O1N189.xml... ✅ 1163 lignes
# [101/605] 📄 CRSANR5L16S2023E1N029.xml... ✅ 828 lignes
# [102/605] 📄 CRSANR5L16S2023O1N200.xml... ✅ 296 lignes
# [103/605] 📄 CRSANR5L16S2023O1N214.xml... ✅ 680 lignes
# [104/605] 📄 CRSANR5L16S2023O1N228.xml... ✅ 532 lignes
# [105/605] 📄 CRSANR5L16S2023O1N002.xml... ✅ 290 lignes
# [106/605] 📄 CRSANR5L16S2023O1N016.xml... ✅ 640 lignes
# [107/605] 📄 CRSANR5L16S2024O1N099.xml... ✅ 484 lignes
# [108/605] 📄 CRSANR5L16S2024O1N066.xml... ✅ 416 lignes
# [109/605] 📄 CRSANR5L16S2024O1N072.xml... ✅ 247 lignes
# [110/605] 📄 CRSANR5L16S2024O1N073.xml... ✅ 696 lignes
# [111/605] 📄 CRSANR5L16S2024O1N067.xml... ✅ 1152 lignes
# [112/605] 📄 CRSANR5L16S2024O1N098.xml... ✅ 237 lignes
# [113/605] 📄 CRSANR5L16S2023O1N017.xml... ✅ 734 lignes
# [114/605] 📄 CRSANR5L16S2023O1N003.xml... ✅ 813 lignes
# [115/605] 📄 CRSANR5L16S2023O1N229.xml... ✅ 738 lignes
# [116/605] 📄 CRSANR5L16S2023O1N215.xml... ✅ 933 lignes
# [117/605] 📄 CRSANR5L16S2023O1N201.xml... ✅ 100 lignes
# [118/605] 📄 CRSANR5L16S2023E1N028.xml... ✅ 1211 lignes
# [119/605] 📄 CRSANR5L16S2023O1N188.xml... ✅ 1071 lignes
# [120/605] 📄 CRSANR5L16S2024O1N107.xml... ✅ 479 lignes
# [121/605] 📄 CRSANR5L16S2024O1N113.xml... ✅ 808 lignes
# [122/605] 📄 CRSANR5L16S2023E1N014.xml... ✅ 667 lignes
# [123/605] 📄 CRSANR5L16S2023O1N163.xml... ✅ 563 lignes
# [124/605] 📄 CRSANR5L16S2023O1N177.xml... ✅ 581 lignes
# [125/605] 📄 CRSANR5L16S2023O1N138.xml... ✅ 589 lignes
# [126/605] 📄 CRSANR5L16S2023O1N110.xml... ✅ 435 lignes
# [127/605] 📄 CRSANR5L16S2023O1N104.xml... ✅ 602 lignes
# [128/605] 📄 CRSANR5L16S2024O1N148.xml... ✅ 481 lignes
# [129/605] 📄 CRSANR5L16S2024O1N174.xml... ✅ 503 lignes
# [130/605] 📄 CRSANR5L16S2024O1N160.xml... ✅ 980 lignes
# [131/605] 📄 CRSANR5L16S2023O1N266.xml... ✅ 204 lignes
# [132/605] 📄 CRSANR5L16S2023O1N272.xml... ✅ 744 lignes
# [133/605] 📄 CRSANR5L16S2022E1N010.xml... ✅ 495 lignes
# [134/605] 📄 CRSANR5L16S2022E1N004.xml... ✅ 798 lignes
# [135/605] 📄 CRSANR5L16S2024O1N202.xml... ✅ 573 lignes
# [136/605] 📄 CRSANR5L16S2024O1N216.xml... ✅ 936 lignes
# [137/605] 📄 CRSANR5L16S2023O1N058.xml... ✅ 1215 lignes
# [138/605] 📄 CRSANR5L16S2023O1N064.xml... ✅ 220 lignes
# [139/605] 📄 CRSANR5L16S2023E2N007.xml... ✅ 792 lignes
# [140/605] 📄 CRSANR5L16S2023O1N070.xml... ✅ 426 lignes
# [141/605] 📄 CRSANR5L16S2024O1N028.xml... ✅ 342 lignes
# [142/605] 📄 CRSANR5L16S2024O1N014.xml... ✅ 698 lignes
# [143/605] 📄 CRSANR5L16S2024O1N015.xml... ✅ 360 lignes
# [144/605] 📄 CRSANR5L16S2024O1N001.xml... ✅ 7 lignes
# [145/605] 📄 CRSANR5L16S2024O1N029.xml... ✅ 452 lignes
# [146/605] 📄 CRSANR5L16S2023E2N012.xml... ✅ 418 lignes
# [147/605] 📄 CRSANR5L16S2023O1N071.xml... ✅ 450 lignes
# [148/605] 📄 CRSANR5L16S2023E2N006.xml... ✅ 348 lignes
# [149/605] 📄 CRSANR5L16S2023O1N065.xml... ✅ 502 lignes
# [150/605] 📄 CRSANR5L16S2023O1N059.xml... ✅ 440 lignes
# [151/605] 📄 CRSANR5L16S2024O1N217.xml... ✅ 534 lignes
# [152/605] 📄 CRSANR5L16S2024O1N203.xml... ✅ 955 lignes
# [153/605] 📄 CRSANR5L16S2022E1N005.xml... ✅ 577 lignes
# [154/605] 📄 CRSANR5L16S2022E1N011.xml... ✅ 831 lignes
# [155/605] 📄 CRSANR5L16S2023O1N273.xml... ✅ 541 lignes
# [156/605] 📄 CRSANR5L16S2023O1N267.xml... ✅ 944 lignes
# [157/605] 📄 CRSANR5L16S2024O1N161.xml... ✅ 286 lignes
# [158/605] 📄 CRSANR5L16S2024O1N175.xml... ✅ 417 lignes
# [159/605] 📄 CRSANR5L16S2024O1N149.xml... ✅ 777 lignes
# [160/605] 📄 CRSANR5L16S2023O1N105.xml... ✅ 367 lignes
# [161/605] 📄 CRSANR5L16S2023O1N111.xml... ✅ 436 lignes
# [162/605] 📄 CRSANR5L16S2023O1N139.xml... ✅ 845 lignes
# [163/605] 📄 CRSANR5L16S2024O1N188.xml... ✅ 404 lignes
# [164/605] 📄 CRSANR5L16S2023O1N107.xml... ✅ 230 lignes
# [165/605] 📄 CRSANR5L16S2023O1N113.xml... ✅ 642 lignes
# [166/605] 📄 CRSANR5L16S2024O1N163.xml... ✅ 188 lignes
# [167/605] 📄 CRSANR5L16S2024O1N177.xml... ✅ 554 lignes
# [168/605] 📄 CRSANR5L16S2023O1N259.xml... ✅ 666 lignes
# [169/605] 📄 CRSANR5L16S2022O1N170.xml... ✅ 28 lignes
# [170/605] 📄 CRSANR5L16S2023O1N271.xml... ✅ 407 lignes
# [171/605] 📄 CRSANR5L16S2023O1N265.xml... ✅ 197 lignes
# [172/605] 📄 CRSANR5L16S2022E1N007.xml... ✅ 646 lignes
# [173/605] 📄 CRSANR5L16S2024O1N229.xml... ✅ 466 lignes
# [174/605] 📄 CRSANR5L16S2022E1N013.xml... ✅ 569 lignes
# [175/605] 📄 CRSANR5L16S2024O1N215.xml... ✅ 459 lignes
# [176/605] 📄 CRSANR5L16S2024O1N201.xml... ✅ 961 lignes
# [177/605] 📄 CRSANR5L16S2021O1N144.xml... ✅ 224 lignes
# [178/605] 📄 CRSANR5L16S2023O1N073.xml... ✅ 822 lignes
# [179/605] 📄 CRSANR5L16S2023E2N010.xml... ✅ 715 lignes
# [180/605] 📄 CRSANR5L16S2023O1N067.xml... ✅ 794 lignes
# [181/605] 📄 CRSANR5L16S2023E2N004.xml... ✅ 578 lignes
# [182/605] 📄 CRSANR5L16S2023O1N098.xml... ✅ 860 lignes
# [183/605] 📄 CRSANR5L16S2024O1N017.xml... ✅ 996 lignes
# [184/605] 📄 CRSANR5L16S2024O1N003.xml... ✅ 891 lignes
# [185/605] 📄 CRSANR5L16S2024O1N002.xml... ✅ 444 lignes
# [186/605] 📄 CRSANR5L16S2024O1N016.xml... ✅ 628 lignes
# [187/605] 📄 CRSANR5L16S2023O1N099.xml... ✅ 563 lignes
# [188/605] 📄 CRSANR5L16S2023E2N005.xml... ✅ 925 lignes
# [189/605] 📄 CRSANR5L16S2023O1N066.xml... ✅ 135 lignes
# [190/605] 📄 CRSANR5L16S2023E2N011.xml... ✅ 993 lignes
# [191/605] 📄 CRSANR5L16S2023O1N072.xml... ✅ 341 lignes
# [192/605] 📄 CRSANR5L16S2024O1N200.xml... ✅ 733 lignes
# [193/605] 📄 CRSANR5L16S2024O1N214.xml... ✅ 607 lignes
# [194/605] 📄 CRSANR5L16S2022E1N012.xml... ✅ 455 lignes
# [195/605] 📄 CRSANR5L16S2024O1N228.xml... ✅ 575 lignes
# [196/605] 📄 CRSANR5L16S2022E1N006.xml... ✅ 373 lignes
# [197/605] 📄 CRSANR5L16S2023O1N264.xml... ✅ 553 lignes
# [198/605] 📄 CRSANR5L16S2023O1N270.xml... ✅ 304 lignes
# [199/605] 📄 CRSANR5L16S2023O1N258.xml... ✅ 755 lignes
# [200/605] 📄 CRSANR5L16S2024O1N176.xml... ✅ 816 lignes
# [201/605] 📄 CRSANR5L16S2024O1N162.xml... ✅ 392 lignes
# [202/605] 📄 CRSANR5L16S2023O1N112.xml... ✅ 145 lignes
# [203/605] 📄 CRSANR5L16S2023O1N106.xml... ✅ 259 lignes
# [204/605] 📄 CRSANR5L16S2024O1N189.xml... ✅ 597 lignes
# [205/605] 📄 CRSANR5L16S2023O1N102.xml... ✅ 773 lignes
# [206/605] 📄 CRSANR5L16S2023O1N116.xml... ✅ 409 lignes
# [207/605] 📄 CRSANR5L16S2024O1N199.xml... ✅ 1028 lignes
# [208/605] 📄 CRSANR5L16S2024O1N166.xml... ✅ 609 lignes
# [209/605] 📄 CRSANR5L16S2024O1N172.xml... ✅ 280 lignes
# [210/605] 📄 CRSANR5L16S2023O1N274.xml... ✅ 555 lignes
# [211/605] 📄 CRSANR5L16S2023O1N260.xml... ✅ 132 lignes
# [212/605] 📄 CRSANR5L16S2023O1N248.xml... ✅ 701 lignes
# [213/605] 📄 CRSANR5L16S2024O1N210.xml... ✅ 1104 lignes
# [214/605] 📄 CRSANR5L16S2024O1N204.xml... ✅ 527 lignes
# [215/605] 📄 CRSANR5L16S2022E1N002.xml... ✅ 411 lignes
# [216/605] 📄 CRSANR5L16S2022E1N016.xml... ✅ 680 lignes
# [217/605] 📄 CRSANR5L16S2023O1N076.xml... ✅ 250 lignes
# [218/605] 📄 CRSANR5L16S2023O1N062.xml... ✅ 1422 lignes
# [219/605] 📄 CRSANR5L16S2023E2N001.xml... ✅ 478 lignes
# [220/605] 📄 CRSANR5L16S2024O1N012.xml... ✅ 698 lignes
# [221/605] 📄 CRSANR5L16S2024O1N006.xml... ✅ 385 lignes
# [222/605] 📄 CRSANR5L16S2023O1N089.xml... ✅ 417 lignes
# [223/605] 📄 CRSANR5L16S2023O1N088.xml... ✅ 421 lignes
# [224/605] 📄 CRSANR5L16S2024O1N007.xml... ✅ 540 lignes
# [225/605] 📄 CRSANR5L16S2024O1N013.xml... ✅ 359 lignes
# [226/605] 📄 CRSANR5L16S2023O1N063.xml... ✅ 335 lignes
# [227/605] 📄 CRSANR5L16S2023O1N077.xml... ✅ 624 lignes
# [228/605] 📄 CRSANR5L16S2022E1N017.xml... ✅ 448 lignes
# [229/605] 📄 CRSANR5L16S2022E1N003.xml... ✅ 374 lignes
# [230/605] 📄 CRSANR5L16S2024O1N205.xml... ✅ 526 lignes
# [231/605] 📄 CRSANR5L16S2024O1N211.xml... ✅ 301 lignes
# [232/605] 📄 CRSANR5L16S2023O1N249.xml... ✅ 1028 lignes
# [233/605] 📄 CRSANR5L16S2023O1N261.xml... ✅ 649 lignes
# [234/605] 📄 CRSANR5L16S2023O1N275.xml... ✅ 565 lignes
# [235/605] 📄 CRSANR5L16S2024O1N173.xml... ✅ 217 lignes
# [236/605] 📄 CRSANR5L16S2024O1N167.xml... ✅ 181 lignes
# [237/605] 📄 CRSANR5L16S2024O1N198.xml... ✅ 713 lignes
# [238/605] 📄 CRSANR5L16S2023O1N117.xml... ✅ 145 lignes
# [239/605] 📄 CRSANR5L16S2023O1N103.xml... ✅ 881 lignes
# [240/605] 📄 CRSANR5L16S2023O1N115.xml... ✅ 385 lignes
# [241/605] 📄 CRSANR5L16S2023O1N101.xml... ✅ 394 lignes
# [242/605] 📄 CRSANR5L16S2023O1N129.xml... ✅ 350 lignes
# [243/605] 📄 CRSANR5L16S2024O1N171.xml... ✅ 197 lignes
# [244/605] 📄 CRSANR5L16S2024O1N165.xml... ✅ 367 lignes
# [245/605] 📄 CRSANR5L16S2024O1N159.xml... ✅ 477 lignes
# [246/605] 📄 CRSANR5L16S2023O1N263.xml... ✅ 424 lignes
# [247/605] 📄 CRSANR5L16S2023O1N277.xml... ✅ 508 lignes
# [248/605] 📄 CRSANR5L16S2022E1N029.xml... ✅ 170 lignes
# [249/605] 📄 CRSANR5L16S2024O1N207.xml... ✅ 519 lignes
# [250/605] 📄 CRSANR5L16S2024O1N213.xml... ✅ 192 lignes
# [251/605] 📄 CRSANR5L16S2022E1N015.xml... ✅ 1324 lignes
# [252/605] 📄 CRSANR5L16S2023O1N288.xml... ✅ 832 lignes
# [253/605] 📄 CRSANR5L16S2022E1N001.xml... ✅ 584 lignes
# [254/605] 📄 CRSANR5L16S2023O1N061.xml... ✅ 924 lignes
# [255/605] 📄 CRSANR5L16S2023E2N002.xml... ✅ 435 lignes
# [256/605] 📄 CRSANR5L16S2023O1N075.xml... ✅ 489 lignes
# [257/605] 📄 CRSANR5L16S2023O1N049.xml... ✅ 902 lignes
# [258/605] 📄 CRSANR5L16S2024O1N005.xml... ✅ 634 lignes
# [259/605] 📄 CRSANR5L16S2024O1N011.xml... ✅ 365 lignes
# [260/605] 📄 CRSANR5L16S2024O1N039.xml... ✅ 566 lignes
# [261/605] 📄 CRSANR5L16S2024O1N038.xml... ✅ 832 lignes
# [262/605] 📄 CRSANR5L16S2024O1N010.xml... ✅ 601 lignes
# [263/605] 📄 CRSANR5L16S2024O1N004.xml... ✅ 544 lignes
# [264/605] 📄 CRSANR5L16S2023O1N048.xml... ✅ 663 lignes
# [265/605] 📄 CRSANR5L16S2023O1N074.xml... ✅ 455 lignes
# [266/605] 📄 CRSANR5L16S2023E2N003.xml... ✅ 867 lignes
# [267/605] 📄 CRSANR5L16S2023O1N060.xml... ✅ 818 lignes
# [268/605] 📄 CRSANR5L16S2023O1N289.xml... ✅ 525 lignes
# [269/605] 📄 CRSANR5L16S2022E1N014.xml... ✅ 786 lignes
# [270/605] 📄 CRSANR5L16S2024O1N212.xml... ✅ 399 lignes
# [271/605] 📄 CRSANR5L16S2024O1N206.xml... ✅ 1038 lignes
# [272/605] 📄 CRSANR5L16S2022E1N028.xml... ✅ 684 lignes
# [273/605] 📄 CRSANR5L16S2023O1N276.xml... ✅ 577 lignes
# [274/605] 📄 CRSANR5L16S2023O1N262.xml... ✅ 515 lignes
# [275/605] 📄 CRSANR5L16S2024O1N158.xml... ✅ 813 lignes
# [276/605] 📄 CRSANR5L16S2024O1N164.xml... ✅ 574 lignes
# [277/605] 📄 CRSANR5L16S2024O1N170.xml... ✅ 628 lignes
# [278/605] 📄 CRSANR5L16S2023O1N128.xml... ✅ 581 lignes
# [279/605] 📄 CRSANR5L16S2023O1N100.xml... ✅ 707 lignes
# [280/605] 📄 CRSANR5L16S2023O1N114.xml... ✅ 854 lignes
# [281/605] 📄 CRSANR5L16S2023O1N119.xml... ✅ 551 lignes
# [282/605] 📄 CRSANR5L16S2024O1N196.xml... ✅ 734 lignes
# [283/605] 📄 CRSANR5L16S2023O1N131.xml... ✅ 739 lignes
# [284/605] 📄 CRSANR5L16S2023O1N125.xml... ✅ 723 lignes
# [285/605] 📄 CRSANR5L16S2024O1N182.xml... ✅ 270 lignes
# [286/605] 📄 CRSANR5L16S2024O1N169.xml... ✅ 976 lignes
# [287/605] 📄 CRSANR5L16S2024O1N155.xml... ✅ 335 lignes
# [288/605] 📄 CRSANR5L16S2024O1N141.xml... ✅ 346 lignes
# [289/605] 📄 CRSANR5L16S2023O1N247.xml... ✅ 481 lignes
# [290/605] 📄 CRSANR5L16S2023O1N253.xml... ✅ 897 lignes
# [291/605] 📄 CRSANR5L16S2022E1N031.xml... ✅ 257 lignes
# [292/605] 📄 CRSANR5L16S2022E1N025.xml... ✅ 469 lignes
# [293/605] 📄 CRSANR5L16S2024O1N223.xml... ✅ 548 lignes
# [294/605] 📄 CRSANR5L16S2023O1N284.xml... ✅ 424 lignes
# [295/605] 📄 CRSANR5L16S2023O1N290.xml... ✅ 559 lignes
# [296/605] 📄 CRSANR5L16S2022E1N019.xml... ✅ 1015 lignes
# [297/605] 📄 CRSANR5L16S2023O1N079.xml... ✅ 607 lignes
# [298/605] 📄 CRSANR5L16S2023O1N045.xml... ✅ 361 lignes
# [299/605] 📄 CRSANR5L16S2023O1N051.xml... ✅ 447 lignes
# [300/605] 📄 CRSANR5L16S2024O1N009.xml... ✅ 376 lignes
# [301/605] 📄 CRSANR5L16S2023O1N086.xml... ✅ 401 lignes
# [302/605] 📄 CRSANR5L16S2024O1N021.xml... ✅ 625 lignes
# [303/605] 📄 CRSANR5L16S2024O1N035.xml... ✅ 785 lignes
# [304/605] 📄 CRSANR5L16S2023O1N092.xml... ✅ 700 lignes
# [305/605] 📄 CRSANR5L16S2023O1N093.xml... ✅ 954 lignes
# [306/605] 📄 CRSANR5L16S2024O1N034.xml... ✅ 417 lignes
# [307/605] 📄 CRSANR5L16S2024O1N020.xml... ✅ 925 lignes
# [308/605] 📄 CRSANR5L16S2023O1N087.xml... ✅ 837 lignes
# [309/605] 📄 CRSANR5L16S2024O1N008.xml... ✅ 751 lignes
# [310/605] 📄 CRSANR5L16S2023O1N050.xml... ✅ 1255 lignes
# [311/605] 📄 CRSANR5L16S2023O1N044.xml... ✅ 231 lignes
# [312/605] 📄 CRSANR5L16S2023O1N078.xml... ✅ 738 lignes
# [313/605] 📄 CRSANR5L16S2022E1N018.xml... ✅ 810 lignes
# [314/605] 📄 CRSANR5L16S2023O1N291.xml... ✅ 563 lignes
# [315/605] 📄 CRSANR5L16S2023O1N285.xml... ✅ 835 lignes
# [316/605] 📄 CRSANR5L16S2024O1N222.xml... ✅ 890 lignes
# [317/605] 📄 CRSANR5L16S2022E1N024.xml... ✅ 1128 lignes
# [318/605] 📄 CRSANR5L16S2022E1N030.xml... ✅ 444 lignes
# [319/605] 📄 CRSANR5L16S2023O1N252.xml... ✅ 463 lignes
# [320/605] 📄 CRSANR5L16S2023O1N246.xml... ✅ 838 lignes
# [321/605] 📄 CRSANR5L16S2024O1N140.xml... ✅ 708 lignes
# [322/605] 📄 CRSANR5L16S2024O1N154.xml... ✅ 734 lignes
# [323/605] 📄 CRSANR5L16S2024O1N168.xml... ✅ 664 lignes
# [324/605] 📄 CRSANR5L16S2024O1N183.xml... ✅ 305 lignes
# [325/605] 📄 CRSANR5L16S2023O1N124.xml... ✅ 97 lignes
# [326/605] 📄 CRSANR5L16S2023O1N130.xml... ✅ 109 lignes
# [327/605] 📄 CRSANR5L16S2024O1N197.xml... ✅ 599 lignes
# [328/605] 📄 CRSANR5L16S2023O1N118.xml... ✅ 183 lignes
# [329/605] 📄 CRSANR5L16S2023O1N126.xml... ✅ 423 lignes
# [330/605] 📄 CRSANR5L16S2024O1N181.xml... ✅ 375 lignes
# [331/605] 📄 CRSANR5L16S2024O1N195.xml... ✅ 566 lignes
# [332/605] 📄 CRSANR5L16S2023O1N132.xml... ✅ 472 lignes
# [333/605] 📄 CRSANR5L16S2024O1N142.xml... ✅ 367 lignes
# [334/605] 📄 CRSANR5L16S2024O1N156.xml... ✅ 918 lignes
# [335/605] 📄 CRSANR5L16S2023O1N278.xml... ✅ 976 lignes
# [336/605] 📄 CRSANR5L16S2023O1N250.xml... ✅ 446 lignes
# [337/605] 📄 CRSANR5L16S2023O1N244.xml... ✅ 494 lignes
# [338/605] 📄 CRSANR5L16S2024O1N208.xml... ✅ 699 lignes
# [339/605] 📄 CRSANR5L16S2022E1N026.xml... ✅ 229 lignes
# [340/605] 📄 CRSANR5L16S2022E1N032.xml... ✅ 403 lignes
# [341/605] 📄 CRSANR5L16S2023O1N293.xml... ✅ 195 lignes
# [342/605] 📄 CRSANR5L16S2024O1N234.xml... ✅ 785 lignes
# [343/605] 📄 CRSANR5L16S2024O1N220.xml... ✅ 242 lignes
# [344/605] 📄 CRSANR5L16S2023O1N287.xml... ✅ 421 lignes
# [345/605] 📄 CRSANR5L16S2023O1N052.xml... ✅ 406 lignes
# [346/605] 📄 CRSANR5L16S2023O1N046.xml... ✅ 376 lignes
# [347/605] 📄 CRSANR5L16S2024O1N036.xml... ✅ 403 lignes
# [348/605] 📄 CRSANR5L16S2023O1N091.xml... ✅ 515 lignes
# [349/605] 📄 CRSANR5L16S2023O1N085.xml... ✅ 788 lignes
# [350/605] 📄 CRSANR5L16S2024O1N022.xml... ✅ 246 lignes
# [351/605] 📄 CRSANR5L16S2024O1N023.xml... ✅ 275 lignes
# [352/605] 📄 CRSANR5L16S2023O1N084.xml... ✅ 215 lignes
# [353/605] 📄 CRSANR5L16S2023O1N090.xml... ✅ 970 lignes
# [354/605] 📄 CRSANR5L16S2024O1N037.xml... ✅ 690 lignes
# [355/605] 📄 CRSANR5L16S2023O1N047.xml... ✅ 486 lignes
# [356/605] 📄 CRSANR5L16S2023O1N053.xml... ✅ 681 lignes
# [357/605] 📄 CRSANR5L16S2023O1N286.xml... ✅ 493 lignes
# [358/605] 📄 CRSANR5L16S2024O1N221.xml... ✅ 662 lignes
# [359/605] 📄 CRSANR5L16S2024O1N235.xml... ✅ 510 lignes
# [360/605] 📄 CRSANR5L16S2023O1N292.xml... ✅ 358 lignes
# [361/605] 📄 CRSANR5L16S2022E1N027.xml... ✅ 73 lignes
# [362/605] 📄 CRSANR5L16S2024O1N209.xml... ✅ 1196 lignes
# [363/605] 📄 CRSANR5L16S2023O1N245.xml... ✅ 934 lignes
# [364/605] 📄 CRSANR5L16S2023O1N251.xml... ✅ 938 lignes
# [365/605] 📄 CRSANR5L16S2023O1N279.xml... ✅ 517 lignes
# [366/605] 📄 CRSANR5L16S2024O1N157.xml... ✅ 216 lignes
# [367/605] 📄 CRSANR5L16S2024O1N143.xml... ✅ 193 lignes
# [368/605] 📄 CRSANR5L16S2023O1N133.xml... ✅ 178 lignes
# [369/605] 📄 CRSANR5L16S2024O1N194.xml... ✅ 424 lignes
# [370/605] 📄 CRSANR5L16S2024O1N180.xml... ✅ 633 lignes
# [371/605] 📄 CRSANR5L16S2023O1N127.xml... ✅ 175 lignes
# [372/605] 📄 CRSANR5L16S2023O1N123.xml... ✅ 797 lignes
# [373/605] 📄 CRSANR5L16S2024O1N184.xml... ✅ 511 lignes
# [374/605] 📄 CRSANR5L16S2024O1N190.xml... ✅ 208 lignes
# [375/605] 📄 CRSANR5L16S2023O1N137.xml... ✅ 495 lignes
# [376/605] 📄 CRSANR5L16S2024O1N147.xml... ✅ 548 lignes
# [377/605] 📄 CRSANR5L16S2024O1N153.xml... ✅ 512 lignes
# [378/605] 📄 CRSANR5L16S2023O1N255.xml... ✅ 662 lignes
# [379/605] 📄 CRSANR5L16S2023O1N241.xml... ✅ 914 lignes
# [380/605] 📄 CRSANR5L16S2023O1N269.xml... ✅ 897 lignes
# [381/605] 📄 CRSANR5L16S2024O1N231.xml... ✅ 823 lignes
# [382/605] 📄 CRSANR5L16S2024O1N225.xml... ✅ 386 lignes
# [383/605] 📄 CRSANR5L16S2023O1N282.xml... ✅ 531 lignes
# [384/605] 📄 CRSANR5L16S2022E1N023.xml... ✅ 814 lignes
# [385/605] 📄 CRSANR5L16S2024O1N219.xml... ✅ 543 lignes
# [386/605] 📄 CRSANR5L16S2023O1N057.xml... ✅ 501 lignes
# [387/605] 📄 CRSANR5L16S2023O1N043.xml... ✅ 478 lignes
# [388/605] 📄 CRSANR5L16S2023E2N008.xml... ✅ 916 lignes
# [389/605] 📄 CRSANR5L16S2024O1N033.xml... ✅ 564 lignes
# [390/605] 📄 CRSANR5L16S2023O1N094.xml... ✅ 580 lignes
# [391/605] 📄 CRSANR5L16S2023O1N080.xml... ✅ 783 lignes
# [392/605] 📄 CRSANR5L16S2024O1N027.xml... ✅ 783 lignes
# [393/605] 📄 CRSANR5L16S2024O1N026.xml... ✅ 454 lignes
# [394/605] 📄 CRSANR5L16S2023O1N081.xml... ✅ 372 lignes
# [395/605] 📄 CRSANR5L16S2023O1N095.xml... ✅ 387 lignes
# [396/605] 📄 CRSANR5L16S2024O1N032.xml... ✅ 733 lignes
# [397/605] 📄 CRSANR5L16S2023E2N009.xml... ✅ 496 lignes
# [398/605] 📄 CRSANR5L16S2023O1N042.xml... ✅ 815 lignes
# [399/605] 📄 CRSANR5L16S2023O1N056.xml... ✅ 393 lignes
# [400/605] 📄 CRSANR5L16S2024O1N218.xml... ✅ 472 lignes
# [401/605] 📄 CRSANR5L16S2022E1N022.xml... ✅ 1055 lignes
# [402/605] 📄 CRSANR5L16S2023O1N283.xml... ✅ 897 lignes
# [403/605] 📄 CRSANR5L16S2024O1N224.xml... ✅ 952 lignes
# [404/605] 📄 CRSANR5L16S2024O1N230.xml... ✅ 628 lignes
# [405/605] 📄 CRSANR5L16S2023O1N268.xml... ✅ 430 lignes
# [406/605] 📄 CRSANR5L16S2023O1N240.xml... ✅ 178 lignes
# [407/605] 📄 CRSANR5L16S2022O1N169.xml... ✅ 31 lignes
# [408/605] 📄 CRSANR5L16S2023O1N254.xml... ✅ 744 lignes
# [409/605] 📄 CRSANR5L16S2024O1N152.xml... ✅ 384 lignes
# [410/605] 📄 CRSANR5L16S2024O1N146.xml... ✅ 1078 lignes
# [411/605] 📄 CRSANR5L16S2023O1N136.xml... ✅ 883 lignes
# [412/605] 📄 CRSANR5L16S2024O1N191.xml... ✅ 674 lignes
# [413/605] 📄 CRSANR5L16S2024O1N185.xml... ✅ 222 lignes
# [414/605] 📄 CRSANR5L16S2023O1N122.xml... ✅ 399 lignes
# [415/605] 📄 CRSANR5L16S2024O1N193.xml... ✅ 843 lignes
# [416/605] 📄 CRSANR5L16S2023O1N134.xml... ✅ 822 lignes
# [417/605] 📄 CRSANR5L16S2023O1N120.xml... ✅ 432 lignes
# [418/605] 📄 CRSANR5L16S2024O1N187.xml... ✅ 124 lignes
# [419/605] 📄 CRSANR5L16S2023O1N108.xml... ✅ 198 lignes
# [420/605] 📄 CRSANR5L16S2024O1N150.xml... ✅ 557 lignes
# [421/605] 📄 CRSANR5L16S2024O1N144.xml... ✅ 788 lignes
# [422/605] 📄 CRSANR5L16S2024O1N178.xml... ✅ 449 lignes
# [423/605] 📄 CRSANR5L16S2023O1N242.xml... ✅ 424 lignes
# [424/605] 📄 CRSANR5L16S2023O1N256.xml... ✅ 161 lignes
# [425/605] 📄 CRSANR5L16S2024O1N226.xml... ✅ 676 lignes
# [426/605] 📄 CRSANR5L16S2023O1N281.xml... ✅ 433 lignes
# [427/605] 📄 CRSANR5L16S2022E1N008.xml... ✅ 466 lignes
# [428/605] 📄 CRSANR5L16S2024O1N232.xml... ✅ 466 lignes
# [429/605] 📄 CRSANR5L16S2022E1N020.xml... ✅ 232 lignes
# [430/605] 📄 CRSANR5L16S2023O1N040.xml... ✅ 1036 lignes
# [431/605] 📄 CRSCGR5L16S2024O1N001.xml... ✅ 77 lignes
# [432/605] 📄 CRSANR5L16S2023O1N054.xml... ✅ 385 lignes
# [433/605] 📄 CRSANR5L16S2023O1N068.xml... ✅ 885 lignes
# [434/605] 📄 CRSANR5L16S2023O1N083.xml... ✅ 459 lignes
# [435/605] 📄 CRSANR5L16S2024O1N024.xml... ✅ 155 lignes
# [436/605] 📄 CRSANR5L16S2024O1N030.xml... ✅ 646 lignes
# [437/605] 📄 CRSANR5L16S2023O1N097.xml... ✅ 462 lignes
# [438/605] 📄 CRSANR5L16S2024O1N018.xml... ✅ 481 lignes
# [439/605] 📄 CRSANR5L16S2024O1N019.xml... ✅ 519 lignes
# [440/605] 📄 CRSANR5L16S2023O1N096.xml... ✅ 642 lignes
# [441/605] 📄 CRSANR5L16S2024O1N031.xml... ✅ 322 lignes
# [442/605] 📄 CRSANR5L16S2024O1N025.xml... ✅ 522 lignes
# [443/605] 📄 CRSANR5L16S2023O1N082.xml... ✅ 443 lignes
# [444/605] 📄 CRSANR5L16S2023O1N069.xml... ✅ 381 lignes
# [445/605] 📄 CRSANR5L16S2023O1N055.xml... ✅ 680 lignes
# [446/605] 📄 CRSANR5L16S2023O1N041.xml... ✅ 269 lignes
# [447/605] 📄 CRSANR5L16S2022E1N021.xml... ✅ 467 lignes
# [448/605] 📄 CRSANR5L16S2024O1N233.xml... ✅ 359 lignes
# [449/605] 📄 CRSANR5L16S2022E1N009.xml... ✅ 835 lignes
# [450/605] 📄 CRSANR5L16S2023O1N280.xml... ✅ 859 lignes
# [451/605] 📄 CRSANR5L16S2024O1N227.xml... ✅ 472 lignes
# [452/605] 📄 CRSANR5L16S2023O1N257.xml... ✅ 447 lignes
# [453/605] 📄 CRSANR5L16S2023O1N243.xml... ✅ 951 lignes
# [454/605] 📄 CRSANR5L16S2024O1N179.xml... ✅ 271 lignes
# [455/605] 📄 CRSANR5L16S2024O1N145.xml... ✅ 376 lignes
# [456/605] 📄 CRSANR5L16S2024O1N151.xml... ✅ 448 lignes
# [457/605] 📄 CRSANR5L16S2023O1N109.xml... ✅ 509 lignes
# [458/605] 📄 CRSANR5L16S2024O1N186.xml... ✅ 534 lignes
# [459/605] 📄 CRSANR5L16S2023O1N121.xml... ✅ 700 lignes
# [460/605] 📄 CRSANR5L16S2023O1N135.xml... ✅ 434 lignes
# [461/605] 📄 CRSANR5L16S2024O1N192.xml... ✅ 382 lignes
# [462/605] 📄 CRSANR5L16S2023O1N152.xml... ✅ 407 lignes
# [463/605] 📄 CRSANR5L16S2023O1N146.xml... ✅ 963 lignes
# [464/605] 📄 CRSANR5L16S2023E1N019.xml... ✅ 579 lignes
# [465/605] 📄 CRSANR5L16S2024O1N136.xml... ✅ 280 lignes
# [466/605] 📄 CRSANR5L16S2023O1N191.xml... ✅ 436 lignes
# [467/605] 📄 CRSANR5L16S2023O1N185.xml... ✅ 552 lignes
# [468/605] 📄 CRSANR5L16S2023E1N025.xml... ✅ 961 lignes
# [469/605] 📄 CRSANR5L16S2024O1N122.xml... ✅ 458 lignes
# [470/605] 📄 CRSANR5L16S2023O1N218.xml... ✅ 650 lignes
# [471/605] 📄 CRSANR5L16S2023O1N224.xml... ✅ 453 lignes
# [472/605] 📄 CRSANR5L16S2023O1N230.xml... ✅ 720 lignes
# [473/605] 📄 CRSANR5L16S2023O1N026.xml... ✅ 405 lignes
# [474/605] 📄 CRSANR5L16S2024O1N081.xml... ✅ 326 lignes
# [475/605] 📄 CRSANR5L16S2024O1N095.xml... ✅ 136 lignes
# [476/605] 📄 CRSANR5L16S2023O1N032.xml... ✅ 387 lignes
# [477/605] 📄 CRSANR5L16S2024O1N042.xml... ✅ 541 lignes
# [478/605] 📄 CRSANR5L16S2024O1N056.xml... ✅ 456 lignes
# [479/605] 📄 CRSANR5L16S2024O1N057.xml... ✅ 446 lignes
# [480/605] 📄 CRSANR5L16S2024O1N043.xml... ✅ 388 lignes
# [481/605] 📄 CRSANR5L16S2023O1N033.xml... ✅ 846 lignes
# [482/605] 📄 CRSANR5L16S2024O1N094.xml... ✅ 750 lignes
# [483/605] 📄 CRSANR5L16S2024O1N080.xml... ✅ 352 lignes
# [484/605] 📄 CRSANR5L16S2023O1N027.xml... ✅ 423 lignes
# [485/605] 📄 CRSANR5L16S2023O1N231.xml... ✅ 427 lignes
# [486/605] 📄 CRSANR5L16S2023O1N225.xml... ✅ 201 lignes
# [487/605] 📄 CRSANR5L16S2023O1N219.xml... ✅ 365 lignes
# [488/605] 📄 CRSANR5L16S2024O1N123.xml... ✅ 976 lignes
# [489/605] 📄 CRSANR5L16S2023E1N024.xml... ✅ 887 lignes
# [490/605] 📄 CRSANR5L16S2023O1N184.xml... ✅ 869 lignes
# [491/605] 📄 CRSANR5L16S2023O1N190.xml... ✅ 670 lignes
# [492/605] 📄 CRSANR5L16S2024O1N137.xml... ✅ 1278 lignes
# [493/605] 📄 CRSANR5L16S2023E1N018.xml... ✅ 771 lignes
# [494/605] 📄 CRSANR5L16S2023O1N147.xml... ✅ 511 lignes
# [495/605] 📄 CRSANR5L16S2023O1N153.xml... ✅ 835 lignes
# [496/605] 📄 CRSANR5L16S2023O1N179.xml... ✅ 777 lignes
# [497/605] 📄 CRSANR5L16S2023O1N145.xml... ✅ 443 lignes
# [498/605] 📄 CRSANR5L16S2023O1N151.xml... ✅ 905 lignes
# [499/605] 📄 CRSANR5L16S2024O1N109.xml... ✅ 782 lignes
# [500/605] 📄 CRSANR5L16S2023O1N186.xml... ✅ 671 lignes
# [501/605] 📄 CRSANR5L16S2023E1N026.xml... ✅ 540 lignes
# [502/605] 📄 CRSANR5L16S2024O1N121.xml... ✅ 789 lignes
# [503/605] 📄 CRSANR5L16S2024O1N135.xml... ✅ 871 lignes
# [504/605] 📄 CRSANR5L16S2023O1N192.xml... ✅ 354 lignes
# [505/605] 📄 CRSANR5L16S2023O1N233.xml... ✅ 569 lignes
# [506/605] 📄 CRSANR5L16S2023O1N227.xml... ✅ 724 lignes
# [507/605] 📄 CRSANR5L16S2023O1N019.xml... ✅ 485 lignes
# [508/605] 📄 CRSANR5L16S2024O1N096.xml... ✅ 325 lignes
# [509/605] 📄 CRSANR5L16S2023O1N031.xml... ✅ 627 lignes
# [510/605] 📄 CRSANR5L16S2023O1N025.xml... ✅ 488 lignes
# [511/605] 📄 CRSANR5L16S2024O1N082.xml... ✅ 216 lignes
# [512/605] 📄 CRSANR5L16S2024O1N069.xml... ✅ 929 lignes
# [513/605] 📄 CRSANR5L16S2024O1N055.xml... ✅ 444 lignes
# [514/605] 📄 CRSANR5L16S2024O1N041.xml... ✅ 492 lignes
# [515/605] 📄 CRSANR5L16S2024O1N040.xml... ✅ 215 lignes
# [516/605] 📄 CRSANR5L16S2024O1N054.xml... ✅ 485 lignes
# [517/605] 📄 CRSANR5L16S2024O1N068.xml... ✅ 659 lignes
# [518/605] 📄 CRSANR5L16S2024O1N083.xml... ✅ 708 lignes
# [519/605] 📄 CRSANR5L16S2023O1N024.xml... ✅ 881 lignes
# [520/605] 📄 CRSANR5L16S2023O1N030.xml... ✅ 425 lignes
# [521/605] 📄 CRSANR5L16S2024O1N097.xml... ✅ 245 lignes
# [522/605] 📄 CRSANR5L16S2023O1N018.xml... ✅ 450 lignes
# [523/605] 📄 CRSANR5L16S2023O1N226.xml... ✅ 106 lignes
# [524/605] 📄 CRSANR5L16S2023O1N232.xml... ✅ 575 lignes
# [525/605] 📄 CRSANR5L16S2023O1N193.xml... ✅ 199 lignes
# [526/605] 📄 CRSANR5L16S2024O1N134.xml... ✅ 225 lignes
# [527/605] 📄 CRSANR5L16S2024O1N120.xml... ✅ 207 lignes
# [528/605] 📄 CRSANR5L16S2023E1N027.xml... ✅ 949 lignes
# [529/605] 📄 CRSANR5L16S2023O1N187.xml... ✅ 570 lignes
# [530/605] 📄 CRSANR5L16S2024O1N108.xml... ✅ 188 lignes
# [531/605] 📄 CRSANR5L16S2023O1N150.xml... ✅ 1013 lignes
# [532/605] 📄 CRSANR5L16S2023O1N144.xml... ✅ 650 lignes
# [533/605] 📄 CRSANR5L16S2023O1N178.xml... ✅ 521 lignes
# [534/605] 📄 CRSANR5L16S2023O1N140.xml... ✅ 353 lignes
# [535/605] 📄 CRSANR5L16S2023O1N154.xml... ✅ 1165 lignes
# [536/605] 📄 CRSANR5L16S2023O1N168.xml... ✅ 182 lignes
# [537/605] 📄 CRSANR5L16S2023O1N183.xml... ✅ 421 lignes
# [538/605] 📄 CRSANR5L16S2023E1N023.xml... ✅ 592 lignes
# [539/605] 📄 CRSANR5L16S2024O1N124.xml... ✅ 141 lignes
# [540/605] 📄 CRSANR5L16S2024O1N130.xml... ✅ 104 lignes
# [541/605] 📄 CRSANR5L16S2023O1N197.xml... ✅ 618 lignes
# [542/605] 📄 CRSANR5L16S2024O1N118.xml... ✅ 528 lignes
# [543/605] 📄 CRSANR5L16S2023O1N236.xml... ✅ 1021 lignes
# [544/605] 📄 CRSANR5L16S2023O1N222.xml... ✅ 607 lignes
# [545/605] 📄 CRSANR5L16S2024O1N093.xml... ✅ 219 lignes
# [546/605] 📄 CRSANR5L16S2023O1N034.xml... ✅ 370 lignes
# [547/605] 📄 CRSANR5L16S2023O1N020.xml... ✅ 702 lignes
# [548/605] 📄 CRSANR5L16S2024O1N087.xml... ✅ 343 lignes
# [549/605] 📄 CRSANR5L16S2023O1N008.xml... ✅ 586 lignes
# [550/605] 📄 CRSANR5L16S2024O1N050.xml... ✅ 885 lignes
# [551/605] 📄 CRSANR5L16S2024O1N044.xml... ✅ 653 lignes
# [552/605] 📄 CRSANR5L16S2024O1N078.xml... ✅ 720 lignes
# [553/605] 📄 CRSANR5L16S2024O1N079.xml... ✅ 1080 lignes
# [554/605] 📄 CRSANR5L16S2024O1N045.xml... ✅ 462 lignes
# [555/605] 📄 CRSANR5L16S2024O1N051.xml... ✅ 584 lignes
# [556/605] 📄 CRSANR5L16S2023O1N009.xml... ✅ 230 lignes
# [557/605] 📄 CRSANR5L16S2024O1N086.xml... ✅ 152 lignes
# [558/605] 📄 CRSANR5L16S2023O1N021.xml... ✅ 330 lignes
# [559/605] 📄 CRSANR5L16S2023O1N035.xml... ✅ 664 lignes
# [560/605] 📄 CRSANR5L16S2024O1N092.xml... ✅ 758 lignes
# [561/605] 📄 CRSANR5L16S2023O1N223.xml... ✅ 1001 lignes
# [562/605] 📄 CRSANR5L16S2023O1N237.xml... ✅ 503 lignes
# [563/605] 📄 CRSANR5L16S2024O1N119.xml... ✅ 569 lignes
# [564/605] 📄 CRSANR5L16S2023O1N196.xml... ✅ 1010 lignes
# [565/605] 📄 CRSANR5L16S2024O1N131.xml... ✅ 409 lignes
# [566/605] 📄 CRSANR5L16S2024O1N125.xml... ✅ 116 lignes
# [567/605] 📄 CRSANR5L16S2023E1N022.xml... ✅ 717 lignes
# [568/605] 📄 CRSANR5L16S2023O1N182.xml... ✅ 611 lignes
# [569/605] 📄 CRSANR5L16S2023O1N169.xml... ✅ 851 lignes
# [570/605] 📄 CRSANR5L16S2023O1N155.xml... ✅ 1026 lignes
# [571/605] 📄 CRSANR5L16S2023O1N141.xml... ✅ 909 lignes
# [572/605] 📄 CRSANR5L16S2023O1N157.xml... ✅ 97 lignes
# [573/605] 📄 CRSANR5L16S2023O1N143.xml... ✅ 498 lignes
# [574/605] 📄 CRSANR5L16S2024O1N133.xml... ✅ 351 lignes
# [575/605] 📄 CRSANR5L16S2023O1N194.xml... ✅ 813 lignes
# [576/605] 📄 CRSANR5L16S2023O1N180.xml... ✅ 651 lignes
# [577/605] 📄 CRSANR5L16S2023E1N020.xml... ✅ 712 lignes
# [578/605] 📄 CRSANR5L16S2024O1N127.xml... ✅ 680 lignes
# [579/605] 📄 CRSANR5L16S2023E1N008.xml... ✅ 858 lignes
# [580/605] 📄 CRSANR5L16S2023O1N221.xml... ✅ 382 lignes
# [581/605] 📄 CRSANR5L16S2023O1N235.xml... ✅ 503 lignes
# [582/605] 📄 CRSANR5L16S2023O1N209.xml... ✅ 190 lignes
# [583/605] 📄 CRSANR5L16S2023O1N023.xml... ✅ 403 lignes
# [584/605] 📄 CRSANR5L16S2024O1N084.xml... ✅ 189 lignes
# [585/605] 📄 CRSANR5L16S2024O1N090.xml... ✅ 274 lignes
# [586/605] 📄 CRSANR5L16S2023O1N037.xml... ✅ 564 lignes
# [587/605] 📄 CRSANR5L16S2024O1N047.xml... ✅ 343 lignes
# [588/605] 📄 CRSANR5L16S2024O1N053.xml... ✅ 388 lignes
# [589/605] 📄 CRSANR5L16S2024O1N052.xml... ✅ 622 lignes
# [590/605] 📄 CRSANR5L16S2024O1N046.xml... ✅ 974 lignes
# [591/605] 📄 CRSANR5L16S2023O1N036.xml... ✅ 987 lignes
# [592/605] 📄 CRSANR5L16S2024O1N091.xml... ✅ 362 lignes
# [593/605] 📄 CRSANR5L16S2024O1N085.xml... ✅ 109 lignes
# [594/605] 📄 CRSANR5L16S2023O1N022.xml... ✅ 681 lignes
# [595/605] 📄 CRSANR5L16S2023O1N208.xml... ✅ 626 lignes
# [596/605] 📄 CRSANR5L16S2023O1N234.xml... ✅ 901 lignes
# [597/605] 📄 CRSANR5L16S2023O1N220.xml... ✅ 517 lignes
# [598/605] 📄 CRSANR5L16S2023E1N009.xml... ✅ 475 lignes
# [599/605] 📄 CRSANR5L16S2024O1N126.xml... ✅ 222 lignes
# [600/605] 📄 CRSANR5L16S2023E1N021.xml... ✅ 528 lignes
# [601/605] 📄 CRSANR5L16S2023O1N181.xml... ✅ 586 lignes
# [602/605] 📄 CRSANR5L16S2023O1N195.xml... ✅ 259 lignes
# [603/605] 📄 CRSANR5L16S2024O1N132.xml... ✅ 567 lignes
# [604/605] 📄 CRSANR5L16S2023O1N142.xml... ✅ 243 lignes
# [605/605] 📄 CRSANR5L16S2023O1N156.xml... ✅ 208 lignes
#
# ✅ Export terminé : 337041 lignes consolidées
#
# ✅ Export CSV : (337041 lignes)
