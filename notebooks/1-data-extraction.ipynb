# %% [markdown]
# # 1. Extraction des données depuis les fichiers XML

# %% [markdown]
# ## TODO:
# - vérifier si le pattern d'extraction est ok (cf petits fichier identifiés à la fin)
# - (les différences avec la v3 ont été testées et l'écart de nb c'était des infos inutiles)
# - stabiliser le tout en comparant entre fichiers pour être sur que leur structure reste cohérente

# %%
import pandas as pd
import xml.etree.ElementTree as ET
import os
import glob

# TODO: ajouter l'info du nom du fichier ? dans extraire paragraphe ? ou metadata ?


def extraire_donnees_assemblee(fichier_xml: str) -> pd.DataFrame:
    """
    Extrait les données d'un fichier XML de compte rendu de l'Assemblée nationale
    Version hybride : combine contexte global ET informations des points ODJ.
    """

    # Charger le XML
    tree = ET.parse(fichier_xml)
    root = tree.getroot()
    ns = {"ns": "http://schemas.assemblee-nationale.fr/referentiel"}

    def get_text(path):
        """Fonction helper pour extraire le texte de manière sûre"""
        elem = root.find(path, ns)
        return elem.text.strip() if elem is not None and elem.text else ""

    # Métadonnées générales
    metadata = {
        "UID": get_text(".//ns:uid"),
        "SeanceRef": get_text(".//ns:seanceRef"),
        "SessionRef": get_text(".//ns:sessionRef"),
        "DateSeance": get_text(".//ns:dateSeance"),
        "DateSeanceJour": get_text(".//ns:dateSeanceJour"),
        "NumSeanceJour": get_text(".//ns:numSeanceJour"),
        "NumSeance": get_text(".//ns:numSeance"),
        "TypeAssemblee": get_text(".//ns:typeAssemblee"),
        "Legislature": get_text(".//ns:legislature"),
        "Session": get_text(".//ns:session"),
        "NomFichierJO": get_text(".//ns:nomFichierJo"),
        "President": get_text(".//ns:presidentSeance"),
    }

    # ÉTAPE 1 : Créer le mapping paragraphe -> point (contexte local)
    paragraphe_to_point = _creer_mapping_points(root, ns)

    # ÉTAPE 2 : Parcourir le contenu et extraire tous les paragraphes
    contenu = root.find("ns:contenu", ns)
    if contenu is None:
        print(f"⚠️ Pas de contenu trouvé dans {fichier_xml}")
        return pd.DataFrame()

    rows = []
    contexte_global = _initialiser_contexte()

    for elem in contenu.iter():
        tag = elem.tag.split("}")[-1]
        # TODO: check code_grammaire et code_style pas utilisés ?
        # genre je le mets à un autre moment en fait
        # mais plus ici au final
        # code_grammaire = elem.attrib.get("code_grammaire", "")  # pas utilisé ?
        # code_style = elem.attrib.get("code_style", "")  # pas utilisé ?

        # Mettre à jour le contexte global
        _mettre_a_jour_contexte(elem, contexte_global, ns)

        # Traiter les paragraphes
        if tag == "paragraphe":
            row = _extraire_paragraphe(
                elem, metadata, contexte_global, paragraphe_to_point, ns
            )
            if row:
                rows.append(row)

    return pd.DataFrame(rows)


def _creer_mapping_points(root, ns):
    """
    Crée un mapping entre les paragraphes et leurs points parents
    pour récupérer le contexte local (sujet du point, valeur ODJ).
    """
    paragraphe_to_point = {}

    for point in root.findall(".//ns:point", ns):
        # Informations du point
        sujet_elem = point.find("ns:texte", ns)
        sujet_texte = (
            sujet_elem.text.strip()
            if sujet_elem is not None and sujet_elem.text
            else ""
        )
        valeur_ptsodj = point.attrib.get("valeur_ptsodj", "")

        # Récupérer d'autres métadonnées du point si disponibles
        point_id = point.attrib.get("id", "")
        point_type = point.attrib.get("type", "")

        point_info = {
            "sujet": sujet_texte,
            "valeur_odj": valeur_ptsodj,
            "point_id": point_id,
            "point_type": point_type,
        }

        # Associer tous les paragraphes de ce point (recherche récursive)
        for para in point.findall(".//ns:paragraphe", ns):
            para_id = para.attrib.get("id_syceron", "")
            if para_id:  # Seulement si on a un ID valide
                paragraphe_to_point[para_id] = point_info
            else:
                # Fallback : utiliser l'objet Python comme clé
                paragraphe_to_point[id(para)] = point_info

    return paragraphe_to_point


def _initialiser_contexte():
    """Initialise la structure de contexte global"""
    return {
        "titre_general": "",
        "sous_titre": "",
        "contexte_stack": [],
        "section_courante": "",
    }


def _mettre_a_jour_contexte(elem, contexte, ns):
    """
    Met à jour le contexte global basé sur l'élément courant.
    Gère différents niveaux hiérarchiques de titres.
    """
    code_grammaire = elem.attrib.get("code_grammaire", "")
    code_style = elem.attrib.get("code_style", "")

    texte_elem = elem.find("ns:texte", ns)
    texte = (
        texte_elem.text.strip() if texte_elem is not None and texte_elem.text else ""
    )

    if not texte:
        return

    # Titre principal
    if code_grammaire == "TITRE_TEXTE_DISCUSSION" and code_style == "Titre":
        contexte["titre_general"] = texte
        contexte["contexte_stack"] = [texte]

    # Sous-titre
    elif (
        code_grammaire == "SOUS_TITRE_TEXTE_DISCUSSION"
        and code_style == "Sous-tit_info"
    ):
        contexte["sous_titre"] = texte
        if len(contexte["contexte_stack"]) == 1:
            contexte["contexte_stack"].append(texte)
        else:
            contexte["contexte_stack"] = [contexte["titre_general"], texte]

    # Autres types de sections
    elif code_grammaire in ["TITRE_RUBRIQUE", "SOUS_TITRE_RUBRIQUE"]:
        if "SOUS" in code_grammaire:
            if len(contexte["contexte_stack"]) >= 2:
                contexte["contexte_stack"][1] = texte
            else:
                contexte["contexte_stack"].append(texte)
        else:
            contexte["contexte_stack"] = [texte]

    # Section courante pour d'autres cas
    elif code_style in ["Titre", "Sous-tit", "Sous-tit_info"]:
        contexte["section_courante"] = texte


def _extraire_paragraphe(elem, metadata, contexte_global, paragraphe_to_point, ns):
    """
    Extrait toutes les informations d'un paragraphe.
    Combine contexte global et contexte local (point).
    """
    texte_elem = elem.find("ns:texte", ns)
    if texte_elem is None:
        return None

    # Extraction du texte avec gestion des balises internes
    texte = "".join(texte_elem.itertext()).strip()
    if not texte:  # Skip les paragraphes vides
        return None

    stime = texte_elem.attrib.get("stime", "")

    # Informations orateur
    nom, qualite, id_orateur = _extraire_orateur(elem, ns)

    # Récupérer le contexte du point parent (si disponible)
    para_id = elem.attrib.get("id_syceron", "")
    point_info = paragraphe_to_point.get(para_id) or paragraphe_to_point.get(
        id(elem), {}
    )

    # Déterminer la source d'extraction
    source_extraction = "point" if point_info else "global"

    # Construire le contexte hiérarchique complet
    contexte_hierarchique = " > ".join(filter(None, contexte_global["contexte_stack"]))

    return {
        **metadata,
        # Contexte global
        "Titre_general": contexte_global["titre_general"],
        "Sous_titre": contexte_global["sous_titre"],
        "Contexte_hierarchique": contexte_hierarchique,
        "Section_courante": contexte_global["section_courante"],
        # Contexte local du point
        "Sujet_point": point_info.get("sujet", ""),
        "Valeur_ODJ": point_info.get("valeur_odj", ""),
        "Point_ID": point_info.get("point_id", ""),
        "Point_type": point_info.get("point_type", ""),
        # Informations du paragraphe
        "ID_paragraphe": para_id,
        "Ordre_seance": elem.attrib.get("ordre_absolu_seance", ""),
        "Code_grammaire": elem.attrib.get("code_grammaire", ""),
        "Code_style": elem.attrib.get("code_style", ""),
        "Code_parole": elem.attrib.get("code_parole", ""),
        "Role_debat": elem.attrib.get("roledebat", ""),
        # Informations de l'orateur
        "Nom_orateur": nom,
        "Qualite_orateur": qualite,
        "ID_orateur": id_orateur,
        # Contenu
        "stime": stime,
        "Texte": texte,
        # Métadonnées d'extraction
        "Source_extraction": source_extraction,
    }


def _extraire_orateur(elem, ns):
    """Extrait les informations de l'orateur de manière robuste"""
    orateur_elem = elem.find(".//ns:orateur", ns)
    nom, qualite, id_orateur = "", "", ""

    if orateur_elem is not None:
        nom_elem = orateur_elem.find("ns:nom", ns)
        nom = nom_elem.text.strip() if nom_elem is not None and nom_elem.text else ""

        qualite_elem = orateur_elem.find("ns:qualite", ns)
        qualite = (
            qualite_elem.text.strip()
            if qualite_elem is not None and qualite_elem.text
            else ""
        )

        id_elem = orateur_elem.find("ns:id", ns)
        id_orateur = (
            id_elem.text.strip() if id_elem is not None and id_elem.text else ""
        )

    return nom, qualite, id_orateur


def traiter_dossier_xml(dossier_path: str, pattern: str = "*.xml") -> pd.DataFrame:
    """
    Traite tous les fichiers XML d'un dossier et retourne un DataFrame consolidé.
    """
    fichiers_xml = glob.glob(os.path.join(dossier_path, pattern))

    if not fichiers_xml:
        print(f"❌ Aucun fichier XML trouvé dans {dossier_path}")
        return pd.DataFrame()

    tous_dataframes = []
    stats = {"success": 0, "errors": 0, "total_rows": 0}

    print(f"🔄 Traitement de {len(fichiers_xml)} fichiers XML...")

    for fichier in fichiers_xml:
        nom_fichier = os.path.basename(fichier)
        print(f"   📄 {nom_fichier}...", end=" ")

        try:
            df = extraire_donnees_assemblee(fichier)
            if not df.empty:
                tous_dataframes.append(df)
                stats["success"] += 1
                stats["total_rows"] += len(df)
                print(f"✅ {len(df)} lignes")
            else:
                print("⚠️ Vide")

        except Exception as e:
            stats["errors"] += 1
            print(f"❌ Erreur: {str(e)}")

    print(f"\n📊 Statistiques:")
    print(f"   ✅ Fichiers traités avec succès: {stats['success']}")
    print(f"   ❌ Erreurs: {stats['errors']}")
    print(f"   📝 Total de lignes extraites: {stats['total_rows']}")

    if tous_dataframes:
        df_final = pd.concat(tous_dataframes, ignore_index=True)

        # Statistiques sur la répartition des sources
        if "Source_extraction" in df_final.columns:
            source_stats = df_final["Source_extraction"].value_counts()
            print(f"\n🎯 Répartition des sources:")
            for source, count in source_stats.items():
                print(
                    f"   {source}: {count} paragraphes ({count / len(df_final) * 100:.1f}%)"
                )

        return df_final
    else:
        return pd.DataFrame()


def analyser_extraction(df: pd.DataFrame):
    """
    Analyse les résultats de l'extraction pour identifier les différences.
    """
    if df.empty:
        print("❌ DataFrame vide")
        return

    print(f"\n📊 ANALYSE DE L'EXTRACTION")
    print(f"Total de paragraphes: {len(df)}")

    # Répartition par source
    if "Source_extraction" in df.columns:
        print(f"\n🔍 Répartition par source:")
        source_counts = df["Source_extraction"].value_counts()
        for source, count in source_counts.items():
            print(f"   {source}: {count} ({count / len(df) * 100:.1f}%)")

    # Paragraphes avec vs sans contexte de point
    if "Sujet_point" in df.columns:
        avec_point = df[df["Sujet_point"] != ""]
        sans_point = df[df["Sujet_point"] == ""]
        print(f"\n📝 Contexte des points:")
        print(f"   Avec sujet de point: {len(avec_point)}")
        print(f"   Sans sujet de point: {len(sans_point)}")

    # Types de codes grammaire les plus fréquents
    if "Code_grammaire" in df.columns:
        print(f"\n🏷️ Top 5 des codes grammaire:")
        top_codes = df["Code_grammaire"].value_counts().head()
        for code, count in top_codes.items():
            print(f"   {code or '(vide)'}: {count}")


# # Exemple d'utilisation
# if __name__ == "__main__":
#     # # Pour un seul fichier
#     # print("🚀 Test sur un fichier unique...")
#     # df = extraire_donnees_assemblee("CRSANR5L16S2024O1N220.xml")

#     # # Analyse des résultats
#     # analyser_extraction(df)

#     # # Sauvegarde
#     # if not df.empty:
#     #     df.to_csv("assemblee_debat_hybride_ameliore.csv",
#     #               index=False,
#     #               quoting=csv.QUOTE_ALL,
#     #               encoding='utf-8')
#     #     print(f"\n✅ Fichier CSV généré : assemblee_debat_hybride_ameliore.csv")

#     # Pour un dossier entier (décommenter si besoin)
#     df_complet = traiter_dossier_xml("../data/16-xml/compteRendu/")
#     analyser_extraction(df_complet)
#     df_complet.to_csv("df_complet.csv")
#     # print(f"\n✅ Export CSV : ({df_complet.shape[0]} lignes)")

# %%
df = traiter_dossier_xml("../data/raw/16-xml/compteRendu/")
analyser_extraction(df)
df.to_csv("../data/bis_extract_16.csv", index=False)
print(f"\n✅ Export CSV : ({df.shape[0]} lignes)")
# Out:
# 🔄 Traitement de 605 fichiers XML...
#    📄 CRSANR5L16S2023O1N173.xml... ✅ 633 lignes
#    📄 CRSANR5L16S2023O1N167.xml... ✅ 467 lignes
#    📄 CRSANR5L16S2023O1N198.xml... ✅ 402 lignes
#    📄 CRSANR5L16S2023E1N010.xml... ✅ 818 lignes
#    📄 CRSANR5L16S2024O1N117.xml... ✅ 678 lignes
#    📄 CRSANR5L16S2024O1N103.xml... ✅ 857 lignes
#    📄 CRSANR5L16S2023E1N004.xml... ✅ 646 lignes
#    📄 CRSANR5L16S2023O1N239.xml... ✅ 452 lignes
#    📄 CRSANR5L16S2023O1N205.xml... ✅ 118 lignes
#    📄 CRSANR5L16S2023O1N211.xml... ✅ 296 lignes
#    📄 CRSANR5L16S2024O1N088.xml... ✅ 403 lignes
#    📄 CRSANR5L16S2023O1N007.xml... ✅ 535 lignes
#    📄 CRSANR5L16S2023O1N013.xml... ✅ 808 lignes
#    📄 CRSANR5L16S2024O1N063.xml... ✅ 106 lignes
#    📄 CRSANR5L16S2024O1N077.xml... ✅ 760 lignes
#    📄 CRSANR5L16S2024O1N076.xml... ✅ 834 lignes
#    📄 CRSANR5L16S2024O1N062.xml... ✅ 322 lignes
#    📄 CRSANR5L16S2023O1N012.xml... ✅ 688 lignes
#    📄 CRSANR5L16S2023O1N006.xml... ✅ 430 lignes
#    📄 CRSANR5L16S2024O1N089.xml... ✅ 541 lignes
#    📄 CRSANR5L16S2023O1N210.xml... ✅ 625 lignes
#    📄 CRSANR5L16S2023O1N204.xml... ✅ 737 lignes
#    📄 CRSANR5L16S2023O1N238.xml... ✅ 373 lignes
#    📄 CRSANR5L16S2023E1N005.xml... ✅ 609 lignes
#    📄 CRSANR5L16S2024O1N102.xml... ✅ 207 lignes
#    📄 CRSANR5L16S2024O1N116.xml... ✅ 343 lignes
#    📄 CRSANR5L16S2023E1N011.xml... ✅ 432 lignes
#    📄 CRSANR5L16S2023O1N199.xml... ✅ 723 lignes
#    📄 CRSANR5L16S2023O1N166.xml... ✅ 285 lignes
#    📄 CRSANR5L16S2023O1N172.xml... ✅ 426 lignes
#    📄 CRSANR5L16S2023O1N158.xml... ✅ 181 lignes
#    📄 CRSANR5L16S2023O1N164.xml... ✅ 545 lignes
#    📄 CRSANR5L16S2023O1N170.xml... ✅ 526 lignes
#    📄 CRSANR5L16S2024O1N128.xml... ✅ 399 lignes
#    📄 CRSANR5L16S2024O1N100.xml... ✅ 434 lignes
#    📄 CRSANR5L16S2023E1N007.xml... ✅ 904 lignes
#    📄 CRSANR5L16S2023E1N013.xml... ✅ 626 lignes
#    📄 CRSANR5L16S2024O1N114.xml... ✅ 797 lignes
#    📄 CRSANR5L16S2023O1N212.xml... ✅ 684 lignes
#    📄 CRSANR5L16S2023O1N206.xml... ✅ 686 lignes
#    📄 CRSANR5L16S2023O1N038.xml... ✅ 455 lignes
#    📄 CRSANR5L16S2023O1N010.xml... ✅ 528 lignes
#    📄 CRSANR5L16S2023O1N004.xml... ✅ 462 lignes
#    📄 CRSANR5L16S2024O1N048.xml... ✅ 424 lignes
#    📄 CRSANR5L16S2024O1N074.xml... ✅ 246 lignes
#    📄 CRSANR5L16S2024O1N060.xml... ✅ 330 lignes
#    📄 CRSANR5L16S2024O1N061.xml... ✅ 721 lignes
#    📄 CRSANR5L16S2024O1N075.xml... ✅ 791 lignes
#    📄 CRSANR5L16S2024O1N049.xml... ✅ 208 lignes
#    📄 CRSANR5L16S2023O1N005.xml... ✅ 971 lignes
#    📄 CRSANR5L16S2023O1N011.xml... ✅ 243 lignes
#    📄 CRSANR5L16S2023O1N039.xml... ✅ 641 lignes
#    📄 CRSANR5L16S2023O1N207.xml... ✅ 808 lignes
#    📄 CRSANR5L16S2023O1N213.xml... ✅ 375 lignes
#    📄 CRSANR5L16S2024O1N115.xml... ✅ 300 lignes
#    📄 CRSANR5L16S2023E1N012.xml... ✅ 1178 lignes
#    📄 CRSANR5L16S2023E1N006.xml... ✅ 515 lignes
#    📄 CRSANR5L16S2024O1N101.xml... ✅ 875 lignes
#    📄 CRSANR5L16S2024O1N129.xml... ✅ 550 lignes
#    📄 CRSANR5L16S2023O1N171.xml... ✅ 609 lignes
#    📄 CRSANR5L16S2023O1N165.xml... ✅ 301 lignes
#    📄 CRSANR5L16S2023O1N159.xml... ✅ 578 lignes
#    📄 CRSANR5L16S2023O1N161.xml... ✅ 417 lignes
#    📄 CRSANR5L16S2023O1N175.xml... ✅ 812 lignes
#    📄 CRSANR5L16S2023O1N149.xml... ✅ 488 lignes
#    📄 CRSANR5L16S2024O1N105.xml... ✅ 43 lignes
#    📄 CRSANR5L16S2023E1N002.xml... ✅ 559 lignes
#    📄 CRSANR5L16S2023E1N016.xml... ✅ 843 lignes
#    📄 CRSANR5L16S2024O1N111.xml... ✅ 953 lignes
#    📄 CRSANR5L16S2024O1N139.xml... ✅ 527 lignes
#    📄 CRSANR5L16S2023O1N217.xml... ✅ 192 lignes
#    📄 CRSANR5L16S2023O1N203.xml... ✅ 114 lignes
#    📄 CRSANR5L16S2023O1N015.xml... ✅ 544 lignes
#    📄 CRSANR5L16S2023O1N001.xml... ✅ 257 lignes
#    📄 CRSANR5L16S2023O1N029.xml... ✅ 429 lignes
#    📄 CRSANR5L16S2024O1N071.xml... ✅ 19 lignes
#    📄 CRSANR5L16S2024O1N065.xml... ✅ 607 lignes
#    📄 CRSANR5L16S2024O1N059.xml... ✅ 664 lignes
#    📄 CRSANR5L16S2024O1N058.xml... ✅ 774 lignes
#    📄 CRSANR5L16S2024O1N064.xml... ✅ 202 lignes
#    📄 CRSANR5L16S2024O1N070.xml... ✅ 376 lignes
#    📄 CRSANR5L16S2023O1N028.xml... ✅ 737 lignes
#    📄 CRSANR5L16S2023O1N014.xml... ✅ 782 lignes
#    📄 CRSANR5L16S2023O1N202.xml... ✅ 682 lignes
#    📄 CRSANR5L16S2023O1N216.xml... ✅ 462 lignes
#    📄 CRSANR5L16S2024O1N138.xml... ✅ 245 lignes
#    📄 CRSANR5L16S2024O1N110.xml... ✅ 414 lignes
#    📄 CRSANR5L16S2023E1N017.xml... ✅ 1286 lignes
#    📄 CRSANR5L16S2023E1N003.xml... ✅ 1140 lignes
#    📄 CRSANR5L16S2024O1N104.xml... ✅ 680 lignes
#    📄 CRSANR5L16S2023O1N148.xml... ✅ 773 lignes
#    📄 CRSANR5L16S2023O1N174.xml... ✅ 533 lignes
#    📄 CRSANR5L16S2023O1N160.xml... ✅ 139 lignes
#    📄 CRSANR5L16S2023O1N176.xml... ✅ 475 lignes
#    📄 CRSANR5L16S2023O1N162.xml... ✅ 195 lignes
#    📄 CRSANR5L16S2023E1N015.xml... ✅ 645 lignes
#    📄 CRSANR5L16S2024O1N112.xml... ✅ 423 lignes
#    📄 CRSANR5L16S2024O1N106.xml... ✅ 748 lignes
#    📄 CRSANR5L16S2023E1N001.xml... ✅ 553 lignes
#    📄 CRSANR5L16S2023O1N189.xml... ✅ 1163 lignes
#    📄 CRSANR5L16S2023E1N029.xml... ✅ 828 lignes
#    📄 CRSANR5L16S2023O1N200.xml... ✅ 296 lignes
#    📄 CRSANR5L16S2023O1N214.xml... ✅ 680 lignes
#    📄 CRSANR5L16S2023O1N228.xml... ✅ 532 lignes
#    📄 CRSANR5L16S2023O1N002.xml... ✅ 290 lignes
#    📄 CRSANR5L16S2023O1N016.xml... ✅ 640 lignes
#    📄 CRSANR5L16S2024O1N099.xml... ✅ 484 lignes
#    📄 CRSANR5L16S2024O1N066.xml... ✅ 416 lignes
#    📄 CRSANR5L16S2024O1N072.xml... ✅ 247 lignes
#    📄 CRSANR5L16S2024O1N073.xml... ✅ 696 lignes
#    📄 CRSANR5L16S2024O1N067.xml... ✅ 1152 lignes
#    📄 CRSANR5L16S2024O1N098.xml... ✅ 237 lignes
#    📄 CRSANR5L16S2023O1N017.xml... ✅ 734 lignes
#    📄 CRSANR5L16S2023O1N003.xml... ✅ 813 lignes
#    📄 CRSANR5L16S2023O1N229.xml... ✅ 738 lignes
#    📄 CRSANR5L16S2023O1N215.xml... ✅ 933 lignes
#    📄 CRSANR5L16S2023O1N201.xml... ✅ 100 lignes
#    📄 CRSANR5L16S2023E1N028.xml... ✅ 1211 lignes
#    📄 CRSANR5L16S2023O1N188.xml... ✅ 1071 lignes
#    📄 CRSANR5L16S2024O1N107.xml... ✅ 479 lignes
#    📄 CRSANR5L16S2024O1N113.xml... ✅ 808 lignes
#    📄 CRSANR5L16S2023E1N014.xml... ✅ 667 lignes
#    📄 CRSANR5L16S2023O1N163.xml... ✅ 563 lignes
#    📄 CRSANR5L16S2023O1N177.xml... ✅ 581 lignes
#    📄 CRSANR5L16S2023O1N138.xml... ✅ 589 lignes
#    📄 CRSANR5L16S2023O1N110.xml... ✅ 435 lignes
#    📄 CRSANR5L16S2023O1N104.xml... ✅ 602 lignes
#    📄 CRSANR5L16S2024O1N148.xml... ✅ 481 lignes
#    📄 CRSANR5L16S2024O1N174.xml... ✅ 503 lignes
#    📄 CRSANR5L16S2024O1N160.xml... ✅ 980 lignes
#    📄 CRSANR5L16S2023O1N266.xml... ✅ 204 lignes
#    📄 CRSANR5L16S2023O1N272.xml... ✅ 744 lignes
#    📄 CRSANR5L16S2022E1N010.xml... ✅ 495 lignes
#    📄 CRSANR5L16S2022E1N004.xml... ✅ 798 lignes
#    📄 CRSANR5L16S2024O1N202.xml... ✅ 573 lignes
#    📄 CRSANR5L16S2024O1N216.xml... ✅ 936 lignes
#    📄 CRSANR5L16S2023O1N058.xml... ✅ 1215 lignes
#    📄 CRSANR5L16S2023O1N064.xml... ✅ 220 lignes
#    📄 CRSANR5L16S2023E2N007.xml... ✅ 792 lignes
#    📄 CRSANR5L16S2023O1N070.xml... ✅ 426 lignes
#    📄 CRSANR5L16S2024O1N028.xml... ✅ 342 lignes
#    📄 CRSANR5L16S2024O1N014.xml... ✅ 698 lignes
#    📄 CRSANR5L16S2024O1N015.xml... ✅ 360 lignes
#    📄 CRSANR5L16S2024O1N001.xml... ✅ 7 lignes
#    📄 CRSANR5L16S2024O1N029.xml... ✅ 452 lignes
#    📄 CRSANR5L16S2023E2N012.xml... ✅ 418 lignes
#    📄 CRSANR5L16S2023O1N071.xml... ✅ 450 lignes
#    📄 CRSANR5L16S2023E2N006.xml... ✅ 348 lignes
#    📄 CRSANR5L16S2023O1N065.xml... ✅ 502 lignes
#    📄 CRSANR5L16S2023O1N059.xml... ✅ 440 lignes
#    📄 CRSANR5L16S2024O1N217.xml... ✅ 534 lignes
#    📄 CRSANR5L16S2024O1N203.xml... ✅ 955 lignes
#    📄 CRSANR5L16S2022E1N005.xml... ✅ 577 lignes
#    📄 CRSANR5L16S2022E1N011.xml... ✅ 831 lignes
#    📄 CRSANR5L16S2023O1N273.xml... ✅ 541 lignes
#    📄 CRSANR5L16S2023O1N267.xml... ✅ 944 lignes
#    📄 CRSANR5L16S2024O1N161.xml... ✅ 286 lignes
#    📄 CRSANR5L16S2024O1N175.xml... ✅ 417 lignes
#    📄 CRSANR5L16S2024O1N149.xml... ✅ 777 lignes
#    📄 CRSANR5L16S2023O1N105.xml... ✅ 367 lignes
#    📄 CRSANR5L16S2023O1N111.xml... ✅ 436 lignes
#    📄 CRSANR5L16S2023O1N139.xml... ✅ 845 lignes
#    📄 CRSANR5L16S2024O1N188.xml... ✅ 404 lignes
#    📄 CRSANR5L16S2023O1N107.xml... ✅ 230 lignes
#    📄 CRSANR5L16S2023O1N113.xml... ✅ 642 lignes
#    📄 CRSANR5L16S2024O1N163.xml... ✅ 188 lignes
#    📄 CRSANR5L16S2024O1N177.xml... ✅ 554 lignes
#    📄 CRSANR5L16S2023O1N259.xml... ✅ 666 lignes
#    📄 CRSANR5L16S2022O1N170.xml... ✅ 28 lignes
#    📄 CRSANR5L16S2023O1N271.xml... ✅ 407 lignes
#    📄 CRSANR5L16S2023O1N265.xml... ✅ 197 lignes
#    📄 CRSANR5L16S2022E1N007.xml... ✅ 646 lignes
#    📄 CRSANR5L16S2024O1N229.xml... ✅ 466 lignes
#    📄 CRSANR5L16S2022E1N013.xml... ✅ 568 lignes
#    📄 CRSANR5L16S2024O1N215.xml... ✅ 459 lignes
#    📄 CRSANR5L16S2024O1N201.xml... ✅ 961 lignes
#    📄 CRSANR5L16S2021O1N144.xml... ✅ 224 lignes
#    📄 CRSANR5L16S2023O1N073.xml... ✅ 822 lignes
#    📄 CRSANR5L16S2023E2N010.xml... ✅ 715 lignes
#    📄 CRSANR5L16S2023O1N067.xml... ✅ 794 lignes
#    📄 CRSANR5L16S2023E2N004.xml... ✅ 578 lignes
#    📄 CRSANR5L16S2023O1N098.xml... ✅ 860 lignes
#    📄 CRSANR5L16S2024O1N017.xml... ✅ 996 lignes
#    📄 CRSANR5L16S2024O1N003.xml... ✅ 891 lignes
#    📄 CRSANR5L16S2024O1N002.xml... ✅ 444 lignes
#    📄 CRSANR5L16S2024O1N016.xml... ✅ 628 lignes
#    📄 CRSANR5L16S2023O1N099.xml... ✅ 563 lignes
#    📄 CRSANR5L16S2023E2N005.xml... ✅ 925 lignes
#    📄 CRSANR5L16S2023O1N066.xml... ✅ 135 lignes
#    📄 CRSANR5L16S2023E2N011.xml... ✅ 993 lignes
#    📄 CRSANR5L16S2023O1N072.xml... ✅ 341 lignes
#    📄 CRSANR5L16S2024O1N200.xml... ✅ 732 lignes
#    📄 CRSANR5L16S2024O1N214.xml... ✅ 607 lignes
#    📄 CRSANR5L16S2022E1N012.xml... ✅ 455 lignes
#    📄 CRSANR5L16S2024O1N228.xml... ✅ 575 lignes
#    📄 CRSANR5L16S2022E1N006.xml... ✅ 373 lignes
#    📄 CRSANR5L16S2023O1N264.xml... ✅ 553 lignes
#    📄 CRSANR5L16S2023O1N270.xml... ✅ 304 lignes
#    📄 CRSANR5L16S2023O1N258.xml... ✅ 755 lignes
#    📄 CRSANR5L16S2024O1N176.xml... ✅ 816 lignes
#    📄 CRSANR5L16S2024O1N162.xml... ✅ 392 lignes
#    📄 CRSANR5L16S2023O1N112.xml... ✅ 145 lignes
#    📄 CRSANR5L16S2023O1N106.xml... ✅ 259 lignes
#    📄 CRSANR5L16S2024O1N189.xml... ✅ 597 lignes
#    📄 CRSANR5L16S2023O1N102.xml... ✅ 773 lignes
#    📄 CRSANR5L16S2023O1N116.xml... ✅ 409 lignes
#    📄 CRSANR5L16S2024O1N199.xml... ✅ 1028 lignes
#    📄 CRSANR5L16S2024O1N166.xml... ✅ 609 lignes
#    📄 CRSANR5L16S2024O1N172.xml... ✅ 280 lignes
#    📄 CRSANR5L16S2023O1N274.xml... ✅ 555 lignes
#    📄 CRSANR5L16S2023O1N260.xml... ✅ 132 lignes
#    📄 CRSANR5L16S2023O1N248.xml... ✅ 701 lignes
#    📄 CRSANR5L16S2024O1N210.xml... ✅ 1104 lignes
#    📄 CRSANR5L16S2024O1N204.xml... ✅ 527 lignes
#    📄 CRSANR5L16S2022E1N002.xml... ✅ 411 lignes
#    📄 CRSANR5L16S2022E1N016.xml... ✅ 680 lignes
#    📄 CRSANR5L16S2023O1N076.xml... ✅ 250 lignes
#    📄 CRSANR5L16S2023O1N062.xml... ✅ 1422 lignes
#    📄 CRSANR5L16S2023E2N001.xml... ✅ 478 lignes
#    📄 CRSANR5L16S2024O1N012.xml... ✅ 698 lignes
#    📄 CRSANR5L16S2024O1N006.xml... ✅ 385 lignes
#    📄 CRSANR5L16S2023O1N089.xml... ✅ 417 lignes
#    📄 CRSANR5L16S2023O1N088.xml... ✅ 421 lignes
#    📄 CRSANR5L16S2024O1N007.xml... ✅ 540 lignes
#    📄 CRSANR5L16S2024O1N013.xml... ✅ 359 lignes
#    📄 CRSANR5L16S2023O1N063.xml... ✅ 335 lignes
#    📄 CRSANR5L16S2023O1N077.xml... ✅ 624 lignes
#    📄 CRSANR5L16S2022E1N017.xml... ✅ 448 lignes
#    📄 CRSANR5L16S2022E1N003.xml... ✅ 374 lignes
#    📄 CRSANR5L16S2024O1N205.xml... ✅ 526 lignes
#    📄 CRSANR5L16S2024O1N211.xml... ✅ 301 lignes
#    📄 CRSANR5L16S2023O1N249.xml... ✅ 1028 lignes
#    📄 CRSANR5L16S2023O1N261.xml... ✅ 649 lignes
#    📄 CRSANR5L16S2023O1N275.xml... ✅ 565 lignes
#    📄 CRSANR5L16S2024O1N173.xml... ✅ 217 lignes
#    📄 CRSANR5L16S2024O1N167.xml... ✅ 181 lignes
#    📄 CRSANR5L16S2024O1N198.xml... ✅ 713 lignes
#    📄 CRSANR5L16S2023O1N117.xml... ✅ 145 lignes
#    📄 CRSANR5L16S2023O1N103.xml... ✅ 881 lignes
#    📄 CRSANR5L16S2023O1N115.xml... ✅ 385 lignes
#    📄 CRSANR5L16S2023O1N101.xml... ✅ 394 lignes
#    📄 CRSANR5L16S2023O1N129.xml... ✅ 350 lignes
#    📄 CRSANR5L16S2024O1N171.xml... ✅ 197 lignes
#    📄 CRSANR5L16S2024O1N165.xml... ✅ 367 lignes
#    📄 CRSANR5L16S2024O1N159.xml... ✅ 472 lignes
#    📄 CRSANR5L16S2023O1N263.xml... ✅ 424 lignes
#    📄 CRSANR5L16S2023O1N277.xml... ✅ 508 lignes
#    📄 CRSANR5L16S2022E1N029.xml... ✅ 170 lignes
#    📄 CRSANR5L16S2024O1N207.xml... ✅ 519 lignes
#    📄 CRSANR5L16S2024O1N213.xml... ✅ 192 lignes
#    📄 CRSANR5L16S2022E1N015.xml... ✅ 1324 lignes
#    📄 CRSANR5L16S2023O1N288.xml... ✅ 832 lignes
#    📄 CRSANR5L16S2022E1N001.xml... ✅ 584 lignes
#    📄 CRSANR5L16S2023O1N061.xml... ✅ 924 lignes
#    📄 CRSANR5L16S2023E2N002.xml... ✅ 435 lignes
#    📄 CRSANR5L16S2023O1N075.xml... ✅ 489 lignes
#    📄 CRSANR5L16S2023O1N049.xml... ✅ 902 lignes
#    📄 CRSANR5L16S2024O1N005.xml... ✅ 634 lignes
#    📄 CRSANR5L16S2024O1N011.xml... ✅ 365 lignes
#    📄 CRSANR5L16S2024O1N039.xml... ✅ 566 lignes
#    📄 CRSANR5L16S2024O1N038.xml... ✅ 832 lignes
#    📄 CRSANR5L16S2024O1N010.xml... ✅ 601 lignes
#    📄 CRSANR5L16S2024O1N004.xml... ✅ 544 lignes
#    📄 CRSANR5L16S2023O1N048.xml... ✅ 663 lignes
#    📄 CRSANR5L16S2023O1N074.xml... ✅ 455 lignes
#    📄 CRSANR5L16S2023E2N003.xml... ✅ 867 lignes
#    📄 CRSANR5L16S2023O1N060.xml... ✅ 818 lignes
#    📄 CRSANR5L16S2023O1N289.xml... ✅ 525 lignes
#    📄 CRSANR5L16S2022E1N014.xml... ✅ 786 lignes
#    📄 CRSANR5L16S2024O1N212.xml... ✅ 399 lignes
#    📄 CRSANR5L16S2024O1N206.xml... ✅ 1038 lignes
#    📄 CRSANR5L16S2022E1N028.xml... ✅ 684 lignes
#    📄 CRSANR5L16S2023O1N276.xml... ✅ 577 lignes
#    📄 CRSANR5L16S2023O1N262.xml... ✅ 515 lignes
#    📄 CRSANR5L16S2024O1N158.xml... ✅ 813 lignes
#    📄 CRSANR5L16S2024O1N164.xml... ✅ 573 lignes
#    📄 CRSANR5L16S2024O1N170.xml... ✅ 628 lignes
#    📄 CRSANR5L16S2023O1N128.xml... ✅ 581 lignes
#    📄 CRSANR5L16S2023O1N100.xml... ✅ 707 lignes
#    📄 CRSANR5L16S2023O1N114.xml... ✅ 854 lignes
#    📄 CRSANR5L16S2023O1N119.xml... ✅ 551 lignes
#    📄 CRSANR5L16S2024O1N196.xml... ✅ 734 lignes
#    📄 CRSANR5L16S2023O1N131.xml... ✅ 739 lignes
#    📄 CRSANR5L16S2023O1N125.xml... ✅ 723 lignes
#    📄 CRSANR5L16S2024O1N182.xml... ✅ 270 lignes
#    📄 CRSANR5L16S2024O1N169.xml... ✅ 976 lignes
#    📄 CRSANR5L16S2024O1N155.xml... ✅ 335 lignes
#    📄 CRSANR5L16S2024O1N141.xml... ✅ 346 lignes
#    📄 CRSANR5L16S2023O1N247.xml... ✅ 481 lignes
#    📄 CRSANR5L16S2023O1N253.xml... ✅ 897 lignes
#    📄 CRSANR5L16S2022E1N031.xml... ✅ 257 lignes
#    📄 CRSANR5L16S2022E1N025.xml... ✅ 469 lignes
#    📄 CRSANR5L16S2024O1N223.xml... ✅ 548 lignes
#    📄 CRSANR5L16S2023O1N284.xml... ✅ 424 lignes
#    📄 CRSANR5L16S2023O1N290.xml... ✅ 559 lignes
#    📄 CRSANR5L16S2022E1N019.xml... ✅ 1015 lignes
#    📄 CRSANR5L16S2023O1N079.xml... ✅ 607 lignes
#    📄 CRSANR5L16S2023O1N045.xml... ✅ 361 lignes
#    📄 CRSANR5L16S2023O1N051.xml... ✅ 447 lignes
#    📄 CRSANR5L16S2024O1N009.xml... ✅ 376 lignes
#    📄 CRSANR5L16S2023O1N086.xml... ✅ 401 lignes
#    📄 CRSANR5L16S2024O1N021.xml... ✅ 625 lignes
#    📄 CRSANR5L16S2024O1N035.xml... ✅ 785 lignes
#    📄 CRSANR5L16S2023O1N092.xml... ✅ 700 lignes
#    📄 CRSANR5L16S2023O1N093.xml... ✅ 954 lignes
#    📄 CRSANR5L16S2024O1N034.xml... ✅ 417 lignes
#    📄 CRSANR5L16S2024O1N020.xml... ✅ 925 lignes
#    📄 CRSANR5L16S2023O1N087.xml... ✅ 837 lignes
#    📄 CRSANR5L16S2024O1N008.xml... ✅ 751 lignes
#    📄 CRSANR5L16S2023O1N050.xml... ✅ 1255 lignes
#    📄 CRSANR5L16S2023O1N044.xml... ✅ 231 lignes
#    📄 CRSANR5L16S2023O1N078.xml... ✅ 738 lignes
#    📄 CRSANR5L16S2022E1N018.xml... ✅ 810 lignes
#    📄 CRSANR5L16S2023O1N291.xml... ✅ 563 lignes
#    📄 CRSANR5L16S2023O1N285.xml... ✅ 835 lignes
#    📄 CRSANR5L16S2024O1N222.xml... ✅ 890 lignes
#    📄 CRSANR5L16S2022E1N024.xml... ✅ 1128 lignes
#    📄 CRSANR5L16S2022E1N030.xml... ✅ 444 lignes
#    📄 CRSANR5L16S2023O1N252.xml... ✅ 463 lignes
#    📄 CRSANR5L16S2023O1N246.xml... ✅ 838 lignes
#    📄 CRSANR5L16S2024O1N140.xml... ✅ 708 lignes
#    📄 CRSANR5L16S2024O1N154.xml... ✅ 734 lignes
#    📄 CRSANR5L16S2024O1N168.xml... ✅ 664 lignes
#    📄 CRSANR5L16S2024O1N183.xml... ✅ 305 lignes
#    📄 CRSANR5L16S2023O1N124.xml... ✅ 97 lignes
#    📄 CRSANR5L16S2023O1N130.xml... ✅ 109 lignes
#    📄 CRSANR5L16S2024O1N197.xml... ✅ 599 lignes
#    📄 CRSANR5L16S2023O1N118.xml... ✅ 183 lignes
#    📄 CRSANR5L16S2023O1N126.xml... ✅ 423 lignes
#    📄 CRSANR5L16S2024O1N181.xml... ✅ 375 lignes
#    📄 CRSANR5L16S2024O1N195.xml... ✅ 566 lignes
#    📄 CRSANR5L16S2023O1N132.xml... ✅ 472 lignes
#    📄 CRSANR5L16S2024O1N142.xml... ✅ 367 lignes
#    📄 CRSANR5L16S2024O1N156.xml... ✅ 918 lignes
#    📄 CRSANR5L16S2023O1N278.xml... ✅ 976 lignes
#    📄 CRSANR5L16S2023O1N250.xml... ✅ 446 lignes
#    📄 CRSANR5L16S2023O1N244.xml... ✅ 494 lignes
#    📄 CRSANR5L16S2024O1N208.xml... ✅ 699 lignes
#    📄 CRSANR5L16S2022E1N026.xml... ✅ 229 lignes
#    📄 CRSANR5L16S2022E1N032.xml... ✅ 403 lignes
#    📄 CRSANR5L16S2023O1N293.xml... ✅ 195 lignes
#    📄 CRSANR5L16S2024O1N234.xml... ✅ 785 lignes
#    📄 CRSANR5L16S2024O1N220.xml... ✅ 242 lignes
#    📄 CRSANR5L16S2023O1N287.xml... ✅ 421 lignes
#    📄 CRSANR5L16S2023O1N052.xml... ✅ 406 lignes
#    📄 CRSANR5L16S2023O1N046.xml... ✅ 376 lignes
#    📄 CRSANR5L16S2024O1N036.xml... ✅ 403 lignes
#    📄 CRSANR5L16S2023O1N091.xml... ✅ 515 lignes
#    📄 CRSANR5L16S2023O1N085.xml... ✅ 788 lignes
#    📄 CRSANR5L16S2024O1N022.xml... ✅ 246 lignes
#    📄 CRSANR5L16S2024O1N023.xml... ✅ 275 lignes
#    📄 CRSANR5L16S2023O1N084.xml... ✅ 215 lignes
#    📄 CRSANR5L16S2023O1N090.xml... ✅ 970 lignes
#    📄 CRSANR5L16S2024O1N037.xml... ✅ 690 lignes
#    📄 CRSANR5L16S2023O1N047.xml... ✅ 486 lignes
#    📄 CRSANR5L16S2023O1N053.xml... ✅ 681 lignes
#    📄 CRSANR5L16S2023O1N286.xml... ✅ 493 lignes
#    📄 CRSANR5L16S2024O1N221.xml... ✅ 662 lignes
#    📄 CRSANR5L16S2024O1N235.xml... ✅ 510 lignes
#    📄 CRSANR5L16S2023O1N292.xml... ✅ 358 lignes
#    📄 CRSANR5L16S2022E1N027.xml... ✅ 73 lignes
#    📄 CRSANR5L16S2024O1N209.xml... ✅ 1196 lignes
#    📄 CRSANR5L16S2023O1N245.xml... ✅ 934 lignes
#    📄 CRSANR5L16S2023O1N251.xml... ✅ 938 lignes
#    📄 CRSANR5L16S2023O1N279.xml... ✅ 517 lignes
#    📄 CRSANR5L16S2024O1N157.xml... ✅ 216 lignes
#    📄 CRSANR5L16S2024O1N143.xml... ✅ 193 lignes
#    📄 CRSANR5L16S2023O1N133.xml... ✅ 178 lignes
#    📄 CRSANR5L16S2024O1N194.xml... ✅ 424 lignes
#    📄 CRSANR5L16S2024O1N180.xml... ✅ 633 lignes
#    📄 CRSANR5L16S2023O1N127.xml... ✅ 175 lignes
#    📄 CRSANR5L16S2023O1N123.xml... ✅ 797 lignes
#    📄 CRSANR5L16S2024O1N184.xml... ✅ 511 lignes
#    📄 CRSANR5L16S2024O1N190.xml... ✅ 208 lignes
#    📄 CRSANR5L16S2023O1N137.xml... ✅ 495 lignes
#    📄 CRSANR5L16S2024O1N147.xml... ✅ 548 lignes
#    📄 CRSANR5L16S2024O1N153.xml... ✅ 512 lignes
#    📄 CRSANR5L16S2023O1N255.xml... ✅ 662 lignes
#    📄 CRSANR5L16S2023O1N241.xml... ✅ 914 lignes
#    📄 CRSANR5L16S2023O1N269.xml... ✅ 897 lignes
#    📄 CRSANR5L16S2024O1N231.xml... ✅ 823 lignes
#    📄 CRSANR5L16S2024O1N225.xml... ✅ 386 lignes
#    📄 CRSANR5L16S2023O1N282.xml... ✅ 531 lignes
#    📄 CRSANR5L16S2022E1N023.xml... ✅ 814 lignes
#    📄 CRSANR5L16S2024O1N219.xml... ✅ 543 lignes
#    📄 CRSANR5L16S2023O1N057.xml... ✅ 501 lignes
#    📄 CRSANR5L16S2023O1N043.xml... ✅ 478 lignes
#    📄 CRSANR5L16S2023E2N008.xml... ✅ 916 lignes
#    📄 CRSANR5L16S2024O1N033.xml... ✅ 564 lignes
#    📄 CRSANR5L16S2023O1N094.xml... ✅ 580 lignes
#    📄 CRSANR5L16S2023O1N080.xml... ✅ 783 lignes
#    📄 CRSANR5L16S2024O1N027.xml... ✅ 783 lignes
#    📄 CRSANR5L16S2024O1N026.xml... ✅ 454 lignes
#    📄 CRSANR5L16S2023O1N081.xml... ✅ 372 lignes
#    📄 CRSANR5L16S2023O1N095.xml... ✅ 387 lignes
#    📄 CRSANR5L16S2024O1N032.xml... ✅ 733 lignes
#    📄 CRSANR5L16S2023E2N009.xml... ✅ 496 lignes
#    📄 CRSANR5L16S2023O1N042.xml... ✅ 815 lignes
#    📄 CRSANR5L16S2023O1N056.xml... ✅ 393 lignes
#    📄 CRSANR5L16S2024O1N218.xml... ✅ 472 lignes
#    📄 CRSANR5L16S2022E1N022.xml... ✅ 1055 lignes
#    📄 CRSANR5L16S2023O1N283.xml... ✅ 897 lignes
#    📄 CRSANR5L16S2024O1N224.xml... ✅ 952 lignes
#    📄 CRSANR5L16S2024O1N230.xml... ✅ 628 lignes
#    📄 CRSANR5L16S2023O1N268.xml... ✅ 430 lignes
#    📄 CRSANR5L16S2023O1N240.xml... ✅ 178 lignes
#    📄 CRSANR5L16S2022O1N169.xml... ✅ 31 lignes
#    📄 CRSANR5L16S2023O1N254.xml... ✅ 744 lignes
#    📄 CRSANR5L16S2024O1N152.xml... ✅ 384 lignes
#    📄 CRSANR5L16S2024O1N146.xml... ✅ 1078 lignes
#    📄 CRSANR5L16S2023O1N136.xml... ✅ 882 lignes
#    📄 CRSANR5L16S2024O1N191.xml... ✅ 674 lignes
#    📄 CRSANR5L16S2024O1N185.xml... ✅ 222 lignes
#    📄 CRSANR5L16S2023O1N122.xml... ✅ 399 lignes
#    📄 CRSANR5L16S2024O1N193.xml... ✅ 843 lignes
#    📄 CRSANR5L16S2023O1N134.xml... ✅ 822 lignes
#    📄 CRSANR5L16S2023O1N120.xml... ✅ 432 lignes
#    📄 CRSANR5L16S2024O1N187.xml... ✅ 124 lignes
#    📄 CRSANR5L16S2023O1N108.xml... ✅ 198 lignes
#    📄 CRSANR5L16S2024O1N150.xml... ✅ 557 lignes
#    📄 CRSANR5L16S2024O1N144.xml... ✅ 788 lignes
#    📄 CRSANR5L16S2024O1N178.xml... ✅ 449 lignes
#    📄 CRSANR5L16S2023O1N242.xml... ✅ 424 lignes
#    📄 CRSANR5L16S2023O1N256.xml... ✅ 161 lignes
#    📄 CRSANR5L16S2024O1N226.xml... ✅ 676 lignes
#    📄 CRSANR5L16S2023O1N281.xml... ✅ 433 lignes
#    📄 CRSANR5L16S2022E1N008.xml... ✅ 466 lignes
#    📄 CRSANR5L16S2024O1N232.xml... ✅ 466 lignes
#    📄 CRSANR5L16S2022E1N020.xml... ✅ 232 lignes
#    📄 CRSANR5L16S2023O1N040.xml... ✅ 1035 lignes
#    📄 CRSCGR5L16S2024O1N001.xml... ✅ 77 lignes
#    📄 CRSANR5L16S2023O1N054.xml... ✅ 385 lignes
#    📄 CRSANR5L16S2023O1N068.xml... ✅ 885 lignes
#    📄 CRSANR5L16S2023O1N083.xml... ✅ 459 lignes
#    📄 CRSANR5L16S2024O1N024.xml... ✅ 155 lignes
#    📄 CRSANR5L16S2024O1N030.xml... ✅ 646 lignes
#    📄 CRSANR5L16S2023O1N097.xml... ✅ 462 lignes
#    📄 CRSANR5L16S2024O1N018.xml... ✅ 481 lignes
#    📄 CRSANR5L16S2024O1N019.xml... ✅ 519 lignes
#    📄 CRSANR5L16S2023O1N096.xml... ✅ 642 lignes
#    📄 CRSANR5L16S2024O1N031.xml... ✅ 322 lignes
#    📄 CRSANR5L16S2024O1N025.xml... ✅ 522 lignes
#    📄 CRSANR5L16S2023O1N082.xml... ✅ 443 lignes
#    📄 CRSANR5L16S2023O1N069.xml... ✅ 380 lignes
#    📄 CRSANR5L16S2023O1N055.xml... ✅ 680 lignes
#    📄 CRSANR5L16S2023O1N041.xml... ✅ 269 lignes
#    📄 CRSANR5L16S2022E1N021.xml... ✅ 467 lignes
#    📄 CRSANR5L16S2024O1N233.xml... ✅ 359 lignes
#    📄 CRSANR5L16S2022E1N009.xml... ✅ 835 lignes
#    📄 CRSANR5L16S2023O1N280.xml... ✅ 859 lignes
#    📄 CRSANR5L16S2024O1N227.xml... ✅ 472 lignes
#    📄 CRSANR5L16S2023O1N257.xml... ✅ 447 lignes
#    📄 CRSANR5L16S2023O1N243.xml... ✅ 951 lignes
#    📄 CRSANR5L16S2024O1N179.xml... ✅ 271 lignes
#    📄 CRSANR5L16S2024O1N145.xml... ✅ 376 lignes
#    📄 CRSANR5L16S2024O1N151.xml... ✅ 448 lignes
#    📄 CRSANR5L16S2023O1N109.xml... ✅ 509 lignes
#    📄 CRSANR5L16S2024O1N186.xml... ✅ 534 lignes
#    📄 CRSANR5L16S2023O1N121.xml... ✅ 700 lignes
#    📄 CRSANR5L16S2023O1N135.xml... ✅ 434 lignes
#    📄 CRSANR5L16S2024O1N192.xml... ✅ 382 lignes
#    📄 CRSANR5L16S2023O1N152.xml... ✅ 407 lignes
#    📄 CRSANR5L16S2023O1N146.xml... ✅ 963 lignes
#    📄 CRSANR5L16S2023E1N019.xml... ✅ 579 lignes
#    📄 CRSANR5L16S2024O1N136.xml... ✅ 280 lignes
#    📄 CRSANR5L16S2023O1N191.xml... ✅ 436 lignes
#    📄 CRSANR5L16S2023O1N185.xml... ✅ 552 lignes
#    📄 CRSANR5L16S2023E1N025.xml... ✅ 961 lignes
#    📄 CRSANR5L16S2024O1N122.xml... ✅ 458 lignes
#    📄 CRSANR5L16S2023O1N218.xml... ✅ 650 lignes
#    📄 CRSANR5L16S2023O1N224.xml... ✅ 453 lignes
#    📄 CRSANR5L16S2023O1N230.xml... ✅ 720 lignes
#    📄 CRSANR5L16S2023O1N026.xml... ✅ 405 lignes
#    📄 CRSANR5L16S2024O1N081.xml... ✅ 326 lignes
#    📄 CRSANR5L16S2024O1N095.xml... ✅ 136 lignes
#    📄 CRSANR5L16S2023O1N032.xml... ✅ 387 lignes
#    📄 CRSANR5L16S2024O1N042.xml... ✅ 541 lignes
#    📄 CRSANR5L16S2024O1N056.xml... ✅ 456 lignes
#    📄 CRSANR5L16S2024O1N057.xml... ✅ 446 lignes
#    📄 CRSANR5L16S2024O1N043.xml... ✅ 388 lignes
#    📄 CRSANR5L16S2023O1N033.xml... ✅ 846 lignes
#    📄 CRSANR5L16S2024O1N094.xml... ✅ 750 lignes
#    📄 CRSANR5L16S2024O1N080.xml... ✅ 352 lignes
#    📄 CRSANR5L16S2023O1N027.xml... ✅ 423 lignes
#    📄 CRSANR5L16S2023O1N231.xml... ✅ 427 lignes
#    📄 CRSANR5L16S2023O1N225.xml... ✅ 201 lignes
#    📄 CRSANR5L16S2023O1N219.xml... ✅ 365 lignes
#    📄 CRSANR5L16S2024O1N123.xml... ✅ 976 lignes
#    📄 CRSANR5L16S2023E1N024.xml... ✅ 887 lignes
#    📄 CRSANR5L16S2023O1N184.xml... ✅ 869 lignes
#    📄 CRSANR5L16S2023O1N190.xml... ✅ 670 lignes
#    📄 CRSANR5L16S2024O1N137.xml... ✅ 1278 lignes
#    📄 CRSANR5L16S2023E1N018.xml... ✅ 771 lignes
#    📄 CRSANR5L16S2023O1N147.xml... ✅ 511 lignes
#    📄 CRSANR5L16S2023O1N153.xml... ✅ 835 lignes
#    📄 CRSANR5L16S2023O1N179.xml... ✅ 777 lignes
#    📄 CRSANR5L16S2023O1N145.xml... ✅ 443 lignes
#    📄 CRSANR5L16S2023O1N151.xml... ✅ 905 lignes
#    📄 CRSANR5L16S2024O1N109.xml... ✅ 782 lignes
#    📄 CRSANR5L16S2023O1N186.xml... ✅ 671 lignes
#    📄 CRSANR5L16S2023E1N026.xml... ✅ 540 lignes
#    📄 CRSANR5L16S2024O1N121.xml... ✅ 789 lignes
#    📄 CRSANR5L16S2024O1N135.xml... ✅ 871 lignes
#    📄 CRSANR5L16S2023O1N192.xml... ✅ 354 lignes
#    📄 CRSANR5L16S2023O1N233.xml... ✅ 569 lignes
#    📄 CRSANR5L16S2023O1N227.xml... ✅ 724 lignes
#    📄 CRSANR5L16S2023O1N019.xml... ✅ 485 lignes
#    📄 CRSANR5L16S2024O1N096.xml... ✅ 325 lignes
#    📄 CRSANR5L16S2023O1N031.xml... ✅ 627 lignes
#    📄 CRSANR5L16S2023O1N025.xml... ✅ 488 lignes
#    📄 CRSANR5L16S2024O1N082.xml... ✅ 216 lignes
#    📄 CRSANR5L16S2024O1N069.xml... ✅ 929 lignes
#    📄 CRSANR5L16S2024O1N055.xml... ✅ 444 lignes
#    📄 CRSANR5L16S2024O1N041.xml... ✅ 492 lignes
#    📄 CRSANR5L16S2024O1N040.xml... ✅ 215 lignes
#    📄 CRSANR5L16S2024O1N054.xml... ✅ 485 lignes
#    📄 CRSANR5L16S2024O1N068.xml... ✅ 659 lignes
#    📄 CRSANR5L16S2024O1N083.xml... ✅ 708 lignes
#    📄 CRSANR5L16S2023O1N024.xml... ✅ 881 lignes
#    📄 CRSANR5L16S2023O1N030.xml... ✅ 425 lignes
#    📄 CRSANR5L16S2024O1N097.xml... ✅ 245 lignes
#    📄 CRSANR5L16S2023O1N018.xml... ✅ 450 lignes
#    📄 CRSANR5L16S2023O1N226.xml... ✅ 106 lignes
#    📄 CRSANR5L16S2023O1N232.xml... ✅ 575 lignes
#    📄 CRSANR5L16S2023O1N193.xml... ✅ 199 lignes
#    📄 CRSANR5L16S2024O1N134.xml... ✅ 225 lignes
#    📄 CRSANR5L16S2024O1N120.xml... ✅ 207 lignes
#    📄 CRSANR5L16S2023E1N027.xml... ✅ 949 lignes
#    📄 CRSANR5L16S2023O1N187.xml... ✅ 570 lignes
#    📄 CRSANR5L16S2024O1N108.xml... ✅ 188 lignes
#    📄 CRSANR5L16S2023O1N150.xml... ✅ 1013 lignes
#    📄 CRSANR5L16S2023O1N144.xml... ✅ 650 lignes
#    📄 CRSANR5L16S2023O1N178.xml... ✅ 521 lignes
#    📄 CRSANR5L16S2023O1N140.xml... ✅ 353 lignes
#    📄 CRSANR5L16S2023O1N154.xml... ✅ 1165 lignes
#    📄 CRSANR5L16S2023O1N168.xml... ✅ 182 lignes
#    📄 CRSANR5L16S2023O1N183.xml... ✅ 421 lignes
#    📄 CRSANR5L16S2023E1N023.xml... ✅ 592 lignes
#    📄 CRSANR5L16S2024O1N124.xml... ✅ 141 lignes
#    📄 CRSANR5L16S2024O1N130.xml... ✅ 104 lignes
#    📄 CRSANR5L16S2023O1N197.xml... ✅ 618 lignes
#    📄 CRSANR5L16S2024O1N118.xml... ✅ 528 lignes
#    📄 CRSANR5L16S2023O1N236.xml... ✅ 1021 lignes
#    📄 CRSANR5L16S2023O1N222.xml... ✅ 607 lignes
#    📄 CRSANR5L16S2024O1N093.xml... ✅ 219 lignes
#    📄 CRSANR5L16S2023O1N034.xml... ✅ 370 lignes
#    📄 CRSANR5L16S2023O1N020.xml... ✅ 702 lignes
#    📄 CRSANR5L16S2024O1N087.xml... ✅ 343 lignes
#    📄 CRSANR5L16S2023O1N008.xml... ✅ 586 lignes
#    📄 CRSANR5L16S2024O1N050.xml... ✅ 885 lignes
#    📄 CRSANR5L16S2024O1N044.xml... ✅ 653 lignes
#    📄 CRSANR5L16S2024O1N078.xml... ✅ 720 lignes
#    📄 CRSANR5L16S2024O1N079.xml... ✅ 1080 lignes
#    📄 CRSANR5L16S2024O1N045.xml... ✅ 462 lignes
#    📄 CRSANR5L16S2024O1N051.xml... ✅ 584 lignes
#    📄 CRSANR5L16S2023O1N009.xml... ✅ 230 lignes
#    📄 CRSANR5L16S2024O1N086.xml... ✅ 152 lignes
#    📄 CRSANR5L16S2023O1N021.xml... ✅ 330 lignes
#    📄 CRSANR5L16S2023O1N035.xml... ✅ 664 lignes
#    📄 CRSANR5L16S2024O1N092.xml... ✅ 758 lignes
#    📄 CRSANR5L16S2023O1N223.xml... ✅ 1001 lignes
#    📄 CRSANR5L16S2023O1N237.xml... ✅ 503 lignes
#    📄 CRSANR5L16S2024O1N119.xml... ✅ 569 lignes
#    📄 CRSANR5L16S2023O1N196.xml... ✅ 1010 lignes
#    📄 CRSANR5L16S2024O1N131.xml... ✅ 409 lignes
#    📄 CRSANR5L16S2024O1N125.xml... ✅ 116 lignes
#    📄 CRSANR5L16S2023E1N022.xml... ✅ 717 lignes
#    📄 CRSANR5L16S2023O1N182.xml... ✅ 611 lignes
#    📄 CRSANR5L16S2023O1N169.xml... ✅ 851 lignes
#    📄 CRSANR5L16S2023O1N155.xml... ✅ 1026 lignes
#    📄 CRSANR5L16S2023O1N141.xml... ✅ 909 lignes
#    📄 CRSANR5L16S2023O1N157.xml... ✅ 97 lignes
#    📄 CRSANR5L16S2023O1N143.xml... ✅ 498 lignes
#    📄 CRSANR5L16S2024O1N133.xml... ✅ 351 lignes
#    📄 CRSANR5L16S2023O1N194.xml... ✅ 813 lignes
#    📄 CRSANR5L16S2023O1N180.xml... ✅ 651 lignes
#    📄 CRSANR5L16S2023E1N020.xml... ✅ 712 lignes
#    📄 CRSANR5L16S2024O1N127.xml... ✅ 680 lignes
#    📄 CRSANR5L16S2023E1N008.xml... ✅ 858 lignes
#    📄 CRSANR5L16S2023O1N221.xml... ✅ 382 lignes
#    📄 CRSANR5L16S2023O1N235.xml... ✅ 503 lignes
#    📄 CRSANR5L16S2023O1N209.xml... ✅ 190 lignes
#    📄 CRSANR5L16S2023O1N023.xml... ✅ 403 lignes
#    📄 CRSANR5L16S2024O1N084.xml... ✅ 189 lignes
#    📄 CRSANR5L16S2024O1N090.xml... ✅ 274 lignes
#    📄 CRSANR5L16S2023O1N037.xml... ✅ 564 lignes
#    📄 CRSANR5L16S2024O1N047.xml... ✅ 343 lignes
#    📄 CRSANR5L16S2024O1N053.xml... ✅ 388 lignes
#    📄 CRSANR5L16S2024O1N052.xml... ✅ 622 lignes
#    📄 CRSANR5L16S2024O1N046.xml... ✅ 974 lignes
#    📄 CRSANR5L16S2023O1N036.xml... ✅ 987 lignes
#    📄 CRSANR5L16S2024O1N091.xml... ✅ 362 lignes
#    📄 CRSANR5L16S2024O1N085.xml... ✅ 109 lignes
#    📄 CRSANR5L16S2023O1N022.xml... ✅ 681 lignes
#    📄 CRSANR5L16S2023O1N208.xml... ✅ 626 lignes
#    📄 CRSANR5L16S2023O1N234.xml... ✅ 901 lignes
#    📄 CRSANR5L16S2023O1N220.xml... ✅ 517 lignes
#    📄 CRSANR5L16S2023E1N009.xml... ✅ 475 lignes
#    📄 CRSANR5L16S2024O1N126.xml... ✅ 222 lignes
#    📄 CRSANR5L16S2023E1N021.xml... ✅ 528 lignes
#    📄 CRSANR5L16S2023O1N181.xml... ✅ 586 lignes
#    📄 CRSANR5L16S2023O1N195.xml... ✅ 259 lignes
#    📄 CRSANR5L16S2024O1N132.xml... ✅ 567 lignes
#    📄 CRSANR5L16S2023O1N142.xml... ✅ 243 lignes
#    📄 CRSANR5L16S2023O1N156.xml... ✅ 208 lignes
#
# 📊 Statistiques:
#    ✅ Fichiers traités avec succès: 605
#    ❌ Erreurs: 0
#    📝 Total de lignes extraites: 337030
#
# 🎯 Répartition des sources:
#    point: 335789 paragraphes (99.6%)
#    global: 1241 paragraphes (0.4%)
#
# 📊 ANALYSE DE L'EXTRACTION
# Total de paragraphes: 337030
#
# 🔍 Répartition par source:
#    point: 335789 (99.6%)
#    global: 1241 (0.4%)
#
# 📝 Contexte des points:
#    Avec sujet de point: 118907
#    Sans sujet de point: 218123
#
# 🏷️ Top 5 des codes grammaire:
#    PAROLE_GENERIQUE: 184905
#    INTERRUPTION_1_10: 89793
#    DISC_ARTICLES_3_1: 11531
#    REJET_ADT: 6073
#    DISC_ARTICLES_3_9_1: 3018
#
# ✅ Export CSV : (337030 lignes)

# %%
df.shape
# Out:
# (337030, 32)

# %%
# Pour aller vérifier à la mano dans des petits :
#    📄 CRSANR5L16S2022O1N169.xml... ✅ 31 lignes
#    📄 CRSANR5L16S2024O1N001.xml... ✅ 7 lignes
