# %%
import pandas as pd

df = pd.read_csv(
    "../data/data_cleaning.csv", low_memory=False, dtype={"ID_orateur": str}
)

# %%
df.shape
# Out:
# (129769, 59)

# %%
# Trouver les personnes (ID_orateur) qui n'ont jamais de groupe renseigné
tmp = df[df["groupeAbrev"].isna()]
ids_sans_groupe = tmp["ID_orateur"].unique()
print(f"Nombre de personnes sans groupe : {len(ids_sans_groupe)}")
print("Liste des ID_orateur sans groupe :")
print(ids_sans_groupe)
# Out:
# Nombre de personnes sans groupe : 97
# Liste des ID_orateur sans groupe :
# ['PA791656' 'PA773443' 'PA791652' 'PA429846' 'PA643210' 'PA791648'
#  'PA801864' 'PA312976' 'PA-125389' 'PA-125399' 'PA-125409' 'PA794514'
#  'PA801862' 'PA791654' 'PA791646' 'PA429862' 'PA801870' 'PA801872'
#  'PA791650' 'PA801874' 'PA801866' 'PA702191' 'PA-125549' 'PA-125559'
#  'PA-125569' 'PA-121449' 'PA791658' 'PA-125249' 'PA-125259' 'PA-125269'
#  'PA-125279' 'PA-125289' 'PA-125299' 'PA-125429' 'PA-125449' 'PA-125439'
#  'PA-125019' nan 'PA-125309' 'PA-125319' 'PA-125339' 'PA-125349'
#  'PA833735' 'PA717163' 'PA717157' 'PA-122409' 'PA-124459' 'PA-125619'
#  'PA-125629' 'PA-125639' 'PA-125659' 'PA-125649' 'PA0' 'PA-125669'
#  'PA-125679' 'PA-125689' 'PA-125699' 'PA-125709' 'PA-125719' 'PA-125729'
#  'PA-125739' 'PA-125749' 'PA-125759' 'PA387829' 'PA-125159' 'PA-125769'
#  'PA-125779' 'PA-122379' 'PA-124629' 'PA-124309' 'PA-122369' 'PA-122049'
#  'PA-124169' 'PA-124779' 'PA-124769' 'PA-121669' 'PA-125419' 'PA-125379'
#  'PA-125359' 'PA-125369' 'PA-125489' 'PA-125479' 'PA-125499' 'PA-125509'
#  'PA-125579' 'PA-125589' 'PA-125599' 'PA-125609' 'PA-125529' 'PA-125519'
#  'PA-125539' 'PA-125169' 'PA-125219' 'PA-125229' 'PA-125239' 'PA-125199'
#  'PA-125209']

# %% [markdown]
# Les PA- = des gens auditionnés ? vérif les autres mais en gros membres gouv sans mandats.

# %%
tmp["ID_orateur"].isna().sum()
# Out:
# 23

# %%
df.columns
# Out:
# Index(['UID', 'SeanceRef', 'SessionRef', 'DateSeance', 'DateSeanceJour',
#        'NumSeanceJour', 'NumSeance', 'TypeAssemblee', 'Legislature', 'Session',
#        'NomFichierJO', 'President', 'Titre_general', 'Sous_titre',
#        'Contexte_hierarchique', 'Section_courante', 'Sujet_point',
#        'Valeur_ODJ', 'Point_ID', 'Point_type', 'ID_paragraphe', 'Ordre_seance',
#        'Code_grammaire', 'Code_style', 'Code_parole', 'Role_debat',
#        'Nom_orateur', 'Qualite_orateur', 'ID_orateur', 'stime', 'Texte',
#        'Source_extraction', 'len_dirtytext', 'legislatureLast', 'civ', 'nom',
#        'prenom', 'villeNaissance', 'naissance', 'age', 'groupe', 'groupeAbrev',
#        'departementNom', 'departementCode', 'circo', 'datePriseFonction',
#        'job', 'mail', 'twitter', 'facebook', 'website', 'nombreMandats',
#        'experienceDepute', 'scoreParticipation',
#        'scoreParticipationSpecialite', 'scoreLoyaute', 'scoreMajorite',
#        'active', 'dateMaj'],
#       dtype='object')

# %%
df_ids_sans_groupe = df[df["ID_orateur"].isin(ids_sans_groupe)][
    ["Nom_orateur", "Qualite_orateur", "ID_orateur"]
]
df_ids_sans_groupe
# Out:
#                  Nom_orateur                         Qualite_orateur  \
# 279     Mme Charlotte Caubel  secrétaire d’État chargée de l’enfance
# 286     Mme Charlotte Caubel                       secrétaire d’État
# 287     Mme Charlotte Caubel                       secrétaire d’État
# 292     Mme Charlotte Caubel                       secrétaire d’État
# 301     Mme Charlotte Caubel                       secrétaire d’État
# ...                      ...                                     ...
# 129748   M. Didier Quercioli                                     NaN
# 129749  Mme Catherine Perret                                     NaN
# 129751   M. Didier Quercioli                                     NaN
# 129752     M. Martial Crance                                     NaN
# 129753  Mme Catherine Perret                                     NaN
#
#        ID_orateur
# 279      PA791656
# 286      PA791656
# 287      PA791656
# 292      PA791656
# 301      PA791656
# ...           ...
# 129748  PA-125239
# 129749  PA-125199
# 129751  PA-125239
# 129752  PA-125209
# 129753  PA-125199
#
# [9418 rows x 3 columns]

# %%
df_ids_sans_groupe_large = df_ids_sans_groupe.drop_duplicates()
df_ids_sans_groupe_large  # garde quand change de fonction
# Out:
#                      Nom_orateur  \
# 279         Mme Charlotte Caubel
# 286         Mme Charlotte Caubel
# 608       M. Éric Dupond-Moretti
# 612       M. Éric Dupond-Moretti
# 908     Mme Amélie Oudéa-Castéra
# ...                          ...
# 129727      Mme Catherine Perret
# 129729      Mme Catherine Perret
# 129730         M. Martial Crance
# 129733       M. Didier Quercioli
# 129735         M. Martial Crance
#
#                                           Qualite_orateur ID_orateur
# 279                secrétaire d’État chargée de l’enfance   PA791656
# 286                                     secrétaire d’État   PA791656
# 608              garde des sceaux, ministre de la justice   PA773443
# 612                                      garde des sceaux   PA773443
# 908     ministre de l’éducation nationale, de la jeune...   PA791652
# ...                                                   ...        ...
# 129727  secrétaire confédérale de la CGT chargée des q...  PA-125199
# 129729                                                NaN  PA-125199
# 129730  membre de la direction de l’UFFA-CFDT de la fo...  PA-125209
# 129733                                                NaN  PA-125239
# 129735                                                NaN  PA-125209
#
# [198 rows x 3 columns]

# %%
import csv

df_ids_sans_groupe_large.to_csv(
    "../data/df_plusdinfo_pour_completer.csv", index=False, quoting=csv.QUOTE_ALL
)

# %%
df_ids_sans_groupe_strict = df_ids_sans_groupe_large.drop_duplicates(
    subset="ID_orateur"
)
df_ids_sans_groupe_strict
# Out:
#                      Nom_orateur  \
# 279         Mme Charlotte Caubel
# 608       M. Éric Dupond-Moretti
# 908     Mme Amélie Oudéa-Castéra
# 1010         M. Christophe Béchu
# 1728        M. Sébastien Lecornu
# ...                          ...
# 129674          M. André Bouchut
# 129675   Mme Catherine Delgoulet
# 129726       M. Didier Quercioli
# 129727      Mme Catherine Perret
# 129730         M. Martial Crance
#
#                                           Qualite_orateur ID_orateur
# 279                secrétaire d’État chargée de l’enfance   PA791656
# 608              garde des sceaux, ministre de la justice   PA773443
# 908     ministre de l’éducation nationale, de la jeune...   PA791652
# 1010    ministre de la transition écologique et de la ...   PA429846
# 1728                                  ministre des armées   PA643210
# ...                                                   ...        ...
# 129674          représentant de la Confédération paysanne  PA-125219
# 129675  professeure au Conservatoire national des arts...  PA-125229
# 129726  secrétaire général de la Mutualité Fonction Pu...  PA-125239
# 129727  secrétaire confédérale de la CGT chargée des q...  PA-125199
# 129730  membre de la direction de l’UFFA-CFDT de la fo...  PA-125209
#
# [97 rows x 3 columns]

# %%
import csv

df_ids_sans_groupe_strict.to_csv(
    "../data/df_a_completer_info.csv", index=False, quoting=csv.QUOTE_ALL
)

# %% [markdown]
# Honnêtement, quasi juste que des membres du gouv sans mandat, le reste (avec un - dedans) sont des gens auditionnés.
# - Se contenter d'un GOUV (mais alors retourner aussi ça pour les autres concernés membre de gouv mais encien mandant ? pense pas)
# - préciser une affiliation si existe ailleurs (genre être maire rép sans être député et donc sort pas dans la base assemblée ?)
# - ou alors encore juste mettre l'affiliation maj de leur gouv.
# - Si vraiment pb, créer une catégorie non-affilié (qui existe peut-être ailleurs ?
# - Mais ils sont 27, pas un drame (même si beaucoup d'interventions)
